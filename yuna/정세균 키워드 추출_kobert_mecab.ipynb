# %%
import json # import json module

# with statement
with open('정세균.json') as json_file:
    json_data = json.load(json_file)
    print(json_data[0])
# Out:
# {'url': 'https://blog.naver.com/PostView.nhn?blogId=ywkimd&logNo=220260025459&from=search&redirect=Log&widgetTypeCall=true&topReferer=https%3A%2F%2Fsearch.naver.com%2Fsearch.naver%3Fdate_from%3D20150202%26date_option%3D8%26date_to%3D20150202%26dup_remove%3D1%26nso%3Dso%253Add%252Cp%253Afrom20150202to20150202%26post_blogurl%3D%26post_blogurl_without%3D%26query%3D%25EC%25A0%2595%25EC%2584%25B8%25EA%25B7%25A0%2520%25EC%259D%2598%25EC%259B%2590%26sm%3Dtab_pge%26srchby%3Dall%26st%3Ddate%26where%3Dpost%26start%3D1&directAccess=false', 'author': 'ywkimd', 'date': '2015. 2. 2. 10:32', 'title': '미리 본 김용판 회고록 정치는 삼류 수준', 'content': '‘국정원 여직원 댓글 사건’ 수사를 은폐·축소한 혐의로 기소돼 29일 대법원에서 무죄가 확정된 김용판(57) 전 서울경찰청장은 지난 2년 1개월 동안 수사·재판 과정의 소회를 담은 회고록을 조만간 출간할 예정이다. ‘나는 왜 청문회 선서를 거부했는가’라는 제목의 회고록은 A4 용지 150쪽 분량으로 국정원 여직원 댓글 사건의 실체와 재판 과정, 김 전 청장의 경찰 생활이 담겨 있다. 본지가 단독으로 입수한 회고록에서 김 전 청장은 검찰을 향해 “집단적인 도덕 불감증에 빠졌다”고 했고, 국회에서 대해선 “삼류에 불과하다”며 강하게 비판했다. 사건 당시 수서경찰서 수사과장으로 댓글 사건 수사 은폐·축소를 폭로한 새정치민주연합 권은희 의원에 대한 비판도 상당 부분 할애했다. 그는 권 의원이 경찰을 그만두자 민주당 정세균 의원이 트위터에 ‘김용판 같은 자가 엄벌에 처해지는 것이 상식인 나라, 권은희 과장처럼 정의감 투철한 공무원이 보호받고 존경받을 수 있어야 정상적인 나라’라고 쓴 것을 보고 책을 집필하게 됐다고 했다. 그는 “누가 자신의 책무를 다했고, 누가 정치적 행동을 했는지, 누가 진실을 이야기했고, 누가 거짓으로 일관했는지를 밝혀야한다는 사명감이 들었다”고 적었다. 김용판 전 서울경찰청장. 그는 회고록에서 “국정원 댓글사건은 일부 언론, 단체, 기관, 사람들의 선입견으로 진실은 묻히고 거짓과 위증만이 난무한 사건”이라고 규정했다. 이어 “한 경찰관의 헛된 욕망에 찬 허무맹랑한 폭로에 의해 정치권은 물론 인터넷, 언론, 보수진영과 진보진영, 나아가 좌익진영 등이 총출동해 격한 논란과 상대에 대한 공격이 벌어졌고 국가를 일대 혼란에 빠뜨렸다”고 했다. 1심부터 대법원까지 무죄 선고가 난 데 대해서는 “애당초 야권이 무리한 고발을 하지 않고, 검찰이 냉정하게 판단했다면 재판은 처음부터 이뤄지지 않았을 것”이라며 “증인으로 출석한 한 명의 경찰관이 실체적 진실과 전혀 다른 모순된 폭로와 증언을 하지 않았다면 사건이 이렇게 왜곡되지도 않았을 것”이라고 했다. 김 전 청장은 회고록 제목처럼 2013년 8월 댓글사
’는 부정평가는 0.2%p 하락한 49.6%(‘매우 잘못함’ 31.9% + ‘잘못하는 편’ 17.7%)로 조사됐다. 긍정평가와 부정평가의 격차는 2.0%p 좁혀진 -4.8%p를 기록했다. ‘모름/무응답’은 7.1%p. 지역별로 보면 특히 경기·인천(40.1%→51.1%▲), 부산·경남·울산(47.1%→50.3%▲), 대구·경북(59.6%→63.1%▲)에서 상승폭이 컸고, 연령별로는 20대(19.1%→23.6%▲)와 30대(24.0%→29.9%▲)에서 회복세가 컸다. 성별로는 여성(42.1%→48.4%▲)이, 직업별로는 가정주부(54.3%→63.6%▲), 노동직(52.8%→62.5%▲), 학생(20.8%→31.1%▲) 층에서, 지지정당별로는 무당층(18.7%→25.6%▲)과 새누리당 지지층(83.6%→85.1%▲), 이념성향별로는 중도(32.2%→35.3%▲) 및 보수(70.5%→71.9%▲) 성향에서 올랐다. 반면 대전·충청·세종(50.0%→36.8%▼), 서울(39.7%→38.0%▼) 지역, 50대(56.3%→55.4%▼), 남성(44.0%→41.2%▼), 사무직(30.2%→26.2%▼)과 농림어업(65.0%→45.5%▼), 새정치연합 지지층(13.1%→11.2%▼), 진보성향(23.6%→15.4%▼)에서는 하락한 것으로 조사됐다. 일간으로 보면 박 대통령의 지지율은 29일(월) 42.9%로 출발, 30일(화) 43.5%, 31일(수)45.4%를 거쳐 1월 2일(금) 46.0%까지 지속적으로 상승했는데, 남북 정상 신년사 발표, 대통령 신년 인사회 등에 따른 남북관계 개선을 비롯한, 2015년 국정에 대한 긍정적 기대감이 작용한 것으로 보인다. 한편 2014년 박근혜 대통령의 주간 기준 최고 지지율은 세월호 사고 직후 박 대통령이 사고 현장을 방문해 유가족들과 사고대책을 논의하는 장면이 보도된 4월 3주차 64.7%, 최저 지지율은 ‘비선실세’ 국정개입 의혹 청와대 문건 유출 사건으로 인해 검찰 수사가 본격화된 12월 2주차 39.7%로 기록됐다.\xa0\xa0\xa0 정당지지도에서는 새누리당이 40.3%, 새정치민주연합이 23.9%, 정의당이 5.6%의 지지율로 2014년을 마감했다. 새누리당은 전 주 대비 0.3%p 하락한 반면, 새정치연합과 정의당은 각각 1.2%p, 1.1%p 상승했다. 새누리당과 새정치연합의 격차는 16.4%p로 1.5%p 좁혀졌고, 무당층은 1.4%p 줄어든 29.5%로 조사됐다. 새누리당은 서울과 대전·충청·세종, 50대 이상, 남성, 사무직·노동직·농림어업, 보수·중도 성향의 유권자 층에서 오른 반면, 경기·인천, 20대와 40대, 여성, 가정주부에서는 내렸다. 새정치연합은 주로 서울과 대전·충청·세종, 50대와 30대, 남성, 자영업, 진보·중도 성향에서 올랐다. 2014년 새누리당의 주간 기준 최고 지지율은 세월호 사고 직후인 4월 3주차 53.4%, 최저 지지율은 세월호 유족들의 청와대 항의 방문이 있었던 5월 1주차 38.1%였다. 새정치연합의 최고 지지율은 창당 후 두 번째 주인 4월 1주차 33.4%, 최저 지지율은 세월호법과 관련해 당내 갈등이 증폭되었던 9월 4주차 18.0%로 집계됐다. 정의당의 2014년 최고 지지율은 7·30 재보궐 선거 직전인 7월 4주차 6.3%, 최저 지지율은 3월 4주차와 4월 1주차 0.8%로 나타났다.\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 여야 차기 대선주자 지지도에서는 새정치연합 박원순 서울시장이 1위, 새정치연합 문재인 의원이 2위, 새누리당 김무성 대표가 3위로 2014년을 마감했다. 박원순 시장은 전 주 대비 3.5%p 반등하며 18.1%로 문재인 의원을 밀어내고 1주 만에 다시 1위로 올라섰다. 박원순 시장의 지지율은 거의 전 계층에서 올랐는데, 서울(15.6%→23.2%▲), 경기·인천(14.8%→17.7%▲), 30대(14.9%→24.3%▲)와 20대(21.4%→29.2%▲), 사무직(16.5%→26.5%▲), 무당층(15.6%→22.7%▲), 진보성향(18.1%→32.8%▲) 유권자 층에서 상승폭이 컸다. 성소수자 차별 발언에 대한 실수 인정, 세월호 유가족 위로 방문, 채무 감축을 통한 서울시 재정건전성 향상 보도 등이 지지율 상승에 긍정적 영향을 미쳤고, 특히 지난주 문재인 의원을 지지했던 진보성향의 저연령대 유권자 일부가 이탈해 박원순 시장으로 결집한 것으로 분석된다.\xa0\xa0\xa0 지난주 박 시장을 제치고 1위에 올랐던 문재인 의원은 0.1%p 하락한 16.2%로 1주 만에 다시 2위로 내려앉았다. 문재인 의원의 지지율 하락은 서울(19.2%→17.2%▼), 20대(30.4%→20.2%▼)와 30대(24.8%→22.6%▼), 여성(16.4%→15.5%▼), 사무직(26.5%→19.1%▼), 무당층(19.7%→14.9%▼), 진보성향(32.1%→26.9%▼)의 유권자 층에서 상대적으로 컸다. 이어 김무성 대표는 0.5%p 하락한 12.2%로, 문재인 의원과 4.0%p 격차로 3위를 유지했다. 중위권에서는 정부·여당의 구속 재벌 가석방 분위기 조성을 비판한 홍준표 지사가 7.4%를 기록, 0.1%p 하락했지만 안철수 전 대표를 밀어내고 조사 이래 처음으로 4위로 올라섰다. 다음으로 김문수 위원장이 0.5%p 하락한 7.1%로 5위를 유지했고, 안철수 전 대표는 1.3%p 하락한 6.4%로 4위에서 6위로 두 계단 내려앉았다.\xa0\xa0\xa0\xa0 하위권에서는 안희정 지사가 0.8%p 상승한 4.4%로 두 계단 뛰어올라 7위를 차지했고, 정몽준 전 대표는 0.7%p 하락하며 4.3%를 기록, 8위로 한 계단 내려앉았다. 마지막으로 남경필 지사가 0.2%p 내린 3.8%로 9위를 기록했다. ‘모름/무응답’은 1.1%p 감소한 19.9%.\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 여권 차기주자 지지도에서는 김무성 대표가 0.4%p 하락한 13.8%를 기록했으나 25주째 선두를 유지했고, 김문수 위원장 또한 0.7%p 하락한 9.4%로 2위를 유지했다. 다음으로 홍준표 지사가 8.6%로 0.6%p 하락했지만 3주 연속 3위 자리를 지켰고, 정몽준 전 대표는 0.5%p 하락한 6.8%로 4위를 기록했다. 이어 남경필 지사는 0.9%p 상승한 5.7%로 3주 연속 5위를 유지했고, 이완구 원내대표는 0.1%p 오른 4.1%로 6위로 한 계단 올라섰다. 이어 원희룡 지사는 1.3%p 하락한 3.4%로 7위, 유정복 시장은 1.1%로
이다는 행위를 공인으로 아무렇지도 않게 자행했다”고 비판했다. 김 전 청장은 박근혜 대통령의 지역구였던 달성군 경찰서장이 아닌 달서경찰서장을 지냈다. 김용판 전 서울경찰청장이 지난 29일 대법원에서 무죄를 확정받은 직후 본지 기자에게 소회를 밝히고 있다. /석남준 기자 자신을 기소한 검찰에 대해서는 “집단적 도덕 불감증에 빠져 있다”며 “검찰이 책무의 관점이 아니라 권력·권한의 관점에 서 있는 게 독선적 형태가 나타난 이유”라고 했다. 정치권에 대해서는 “삼류 수준”이라고 평가절하했다. “한 기업 총수가 ‘대한민국 경제는 이류, 행정은 삼류, 정치는 사류’라고 해 파문을 일으켰다. 2014년 대한민국 정치는 몇류일까. 아무리 점수를 높게 줘도 삼류 이상 되지 못한다”고 했다. 시민단체에 대해서는 “권력을 가지고 있다고 생각하는 것이 문제다. 본래의 목적은 상실하고, 정치화되어 혼란을 부추긴다”고 썼다. 이어 “권력이 싫어서 정부로부터 독립한 시민단체가 권력을 추구하는 행태는 모순”이라고 했다. 노무현 정부 때인 2003년 발생한 ‘천성산 터널 도롱뇽 사건’과 이명박 정부 때 ‘광우병 파동’을 시민단체 해악의 대표 사례로 들었다. 김 전 청장은 ‘A는 왜 편견에 가득 찬 허위 진술을 했을까?’라며 권은희 의원을 정면으로 비판했다. 그는 “검찰과 야권이 A의 허무맹랑한 폭로를 무조건 믿었다. 재판이 처음부터 A라는 한 사람의 허위 증언에 의해 증폭되었다는 점을 많은 국민이 알지 못했다는 점이 아쉬웠다”고 적었다. 그러면서 “A가 증인으로 나와 줄기차게 허위 진술을 했는데 그 허위 진술이 오히려 진실을 밝혀내는 데 큰 도움이 됐다”고 했다. 그는 “국정원 여직원 댓글 사건 초기 ‘수서경찰서의 A가 상황을 잘 파악하고 있더라’고 칭찬을 했고, 격려 전화한 게 외압으로 둔갑했다”고 했다. 김 전 청장이 1심에서 무죄를 선고받자 항소심에서 권 의원은 증언을 일부 바꿨다. 김 전 청장은 “위증을 하는 사람들이 일반적으로 자신의 주장에 설득력을 가미하기 위해 점차 살을 덧붙여 가면서 진술이 오히려 구체화되어 간다는 전형적인 사례와 너무나 일치되고 있음은 과연 우연일까. 정말 소가 웃을 말”이라고 했다.'

# %%
from konlpy.tag import Kkma
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import normalize
import numpy as np
import re
from konlpy.tag import Mecab

# %%
class SentenceTokenizer(object):
    def __init__(self):
        self.kkma = Kkma()
        self.okt  = Okt()
        self.mecab = Mecab()
        self.stopwords = ['중인' ,'만큼', '마찬가지', '꼬집었', "연합뉴스", "데일리", "동아일보", "중앙일보", "조선일보", "기자"
        ,"아", "휴", "아이구", "아이쿠", "아이고", "어", "나", "우리", "저희", "따라", "의해", "을", "를", "에", "의", "가",]

    import re
    def pre_process(self, text):
        # 이메일 등장하면, 그 뒷문장 모두 삭제 
        text = re.sub(r'[\n\r\t]', '', str(text))
        text = re.sub('[^ ㄱ-ㅣ가-힣 0-9 A-Z a-z]+', '', str(text))
        text = re.sub("[a-zA-Z0-9]+\@[a-zA-Z0-9]+\.[a-z]{1,3}.[a-z]{1,3}.+",'',text).strip()
        text = re.sub('\(.+?연합뉴스\)','',text).strip() # (서울=연합뉴스)
        text = re.sub('\(.+?연합인포맥스\)','',text).strip()
        text = re.sub('\(.+?이데일리\)','',text).strip()
        text = re.sub('\(.+?조선일보\)','',text).strip()
        text = re.sub('\(.+?뉴시스\)','',text).strip()
        text = re.sub('\(.+?뉴스1\)','',text).strip()
        text = re.sub('\(.+?SBS\)','',text).strip()
        text = re.sub('\(.+?오마이뉴스\)','',text).strip()
        text = re.sub('\(.+?중앙일보\)','',text).strip()
        text = re.sub('\(.+?매일경제\)','',text).strip()
        text = re.sub('\(.+?문화일보\)','',text).strip()
        text = re.sub('\(.+?세계일보\)','',text).strip()
        text = re.sub('\(.+?머니투데이\)','',text).strip()
        text = re.sub('\(.+?서울경제\)','',text).strip()
        text = re.sub('\(.+?데일리안\)','',text).strip()
        text = re.sub('\(.+?KBS\)','',text).strip()
        text = re.sub('\(.+?MBN\)','',text).strip()
        text = re.sub('\(.+?YTN\)','',text).strip()
        text = re.sub('\(.+?프레시안\)','',text).strip()
        text = re.sub('\(.+?디지털타임즈\)','',text).strip()
        text = re.sub('\(.+?국민일보(과거)\)','',text).strip()
        text = re.sub('\(.+?국민일보\)','',text).strip()
        text = re.sub('\(.+?헤드럴경제\)','',text).strip()
        text = re.sub('\(.+?한국일보\)','',text).strip()
        text = re.sub('\(.+?아이뉴스24\)','',text).strip()
        text = re.sub('\(.+?노컷뉴스\)','',text).strip()
        text = re.sub('\(.+?연합뉴스TV\)','',text).strip()
        text = re.sub('\(.+?서울일보\)','',text).strip()
        text = re.sub('\(.+?동아일보\)','',text).strip()
        text = re.sub('\(.+?한국경제\)','',text).strip()
        text = re.sub('\(.+?미디어오늘(과거)\)','',text).strip()
        text = re.sub('\(.+?미디어오늘\)','',text).strip()
        text = re.sub('\(.+?조세일보\)','',text).strip()
        text = re.sub('\(.+?파이낸셜뉴스\)','',text).strip()
        text = re.sub('\(.+?경향신문\)','',text).strip()
        text = re.sub('\(.+?채널A\)','',text).strip()
        text = re.sub('\(.+?머니S\)','',text).strip()
        text = re.sub('\(.+?TVCHOSUN\)','',text).strip()
        text = re.sub('\(.+?한겨례\)','',text).strip()
        text = re.sub('\(.+?전자신문\)','',text).strip()
        text = re.sub('\(.+?SBSCNBC\)','',text).strip()
        text = re.sub('\(.+?한국경제TV\)','',text).strip()
        text = re.sub('\(.+?조선비즈\)','',text).strip()
        text = re.sub('\(.+?ZDNetKorea\)','',text).strip()
        text = re.sub('\[.+?\]','',text).strip()
        text = re.sub('\(사진.+?\)','',text).strip()
        # 신문사 이름 삭제 
        text = re.sub('조선일보|뉴시스|아시아경제|이데일리|뉴스1|SBS|오마이뉴스|중앙일보|매일경제|문화일보|세계일보|머니투데이|서울경제|데일리안|KBS|MBN|YTN|프레시안|디지털타임스|국민일보(과거)|국민일보|헤럴드경제|한국일보|아이뉴스24|노컷뉴스|연합뉴스TV|서울일보|동아일보|한국경제|미디어오늘(과거)|미디어오늘|조세일보|파이낸셜뉴스|경향신문|채널A|머니S|TVCHOSUN|한겨례|전자신문|SBSCNBC|한국경제TV|조선비즈|ZDNetKorea','',text).strip()
        # 000 기자, 000  가자, 000기자 삭제
        text = re.sub('[ㄱ-힑]+ 기자|[ㄱ-힑]+  기자|[ㄱ-힑]+기자','',text).strip()    
        # 특수기호 삭제
        text = re.sub('[^a-zA-Z0-9ㄱ-힗.,”“"% ]','',text).strip()
        text = re.sub('[0-9]{1,4}.[0-9]{1,2}.[0-9]{1,2}.','',text).strip()
        return text

    def text2sentences(self, text):
        # KoNLPy 중 꼬꼬마(Kkma) 분석기 함수 중 문장을 추출하는 sentences()라는 함수를 이용하여 문장을 분리
        sentences = []
        
        sentences.append(self.pre_process(text)[:int(len(self.pre_process(text))/2)])
        sentences.append(self.pre_process(text)[int(len(self.pre_process(text))/2):])
        return sentences
    

    def get_nouns(self, sentences):
        stopwords = ['중인' ,'만큼', '마찬가지', '꼬집었', "연합뉴스", "데일리", "동아일보", "중앙일보", "조선일보", "기자"
        ,"아", "휴", "아이구", "아이쿠", "아이고", "어", "나", "우리", "저희", "따라", "의해", "을", "를", "에", "의", "가", '대표', '의원', '총선', '의원', '대표', '정치' ]
        nouns = []
        for sentence in sentences:
            if sentence is not '':
                nouns.append(' '.join([noun for noun in self.mecab.nouns(str(sentence))
                    if noun not in self.stopwords and len(noun) > 1]))
        return nouns

# %%
class GraphMatrix(object):
    def __init__(self):
        self.tfidf = TfidfVectorizer()
        self.cnt_vec = CountVectorizer()
        self.graph_sentence = []
        
    # 명사로 이루어진 문장을 입력받아 sklearn의 TfidfVectorizer.fit_transform을 이용하여 tfidf matrix를 만든 후 Sentence graph를 return 
    def build_sent_graph(self, sentence):
        tfidf_mat = self.tfidf.fit_transform(sentence).toarray()
        self.graph_sentence = np.dot(tfidf_mat, tfidf_mat.T)
        return self.graph_sentence
    
    # 명사로 이루어진 문장을 입력받아 sklearn의 CountVectorizer.fit_transform을 이용하여 matrix를 만든 후 word graph와 {idx: word}형태의 dictionary를 return
    def build_words_graph(self, sentence):
        cnt_vec_mat = normalize(self.cnt_vec.fit_transform(sentence).toarray().astype(float), axis=0)
        vocab = self.cnt_vec.vocabulary_
        return np.dot(cnt_vec_mat.T, cnt_vec_mat), {vocab[word] : word for word in vocab}

# %%
class Rank(object):
    def get_ranks(self, graph, d=0.85): # d = damping factor
        A = graph
        matrix_size = A.shape[0]
        for id in range(matrix_size):
            A[id, id] = 0 # diagonal 부분을 0으로
            link_sum = np.sum(A[:,id]) # A[:, id] = A[:][id]
            if link_sum != 0:
                A[:, id] /= link_sum
            A[:, id] *= -d
            A[id, id] = 1
    
        B = (1-d) * np.ones((matrix_size, 1))
        ranks = np.linalg.solve(A, B) # 연립방정식 Ax = b
        return {idx: r[0] for idx, r in enumerate(ranks)}

# %%
class TextRank(object):
    def __init__(self, num):
        self.sent_tokenize = SentenceTokenizer()

#         text = clean_str(content_list[num])
        text = content_list[num]
        self.sentences = self.sent_tokenize.text2sentences(text)
    
        self.nouns = self.sent_tokenize.get_nouns(self.sentences)
        
        self.graph_matrix = GraphMatrix()
        self.sent_graph = self.graph_matrix.build_sent_graph(self.nouns)
        self.words_graph, self.idx2word = self.graph_matrix.build_words_graph(self.nouns)
        
        self.rank = Rank()
        self.sent_rank_idx = self.rank.get_ranks(self.sent_graph)
        self.sorted_sent_rank_idx = sorted(self.sent_rank_idx, key=lambda k: self.sent_rank_idx[k], reverse=True)
        
        self.word_rank_idx = self.rank.get_ranks(self.words_graph)
        self.sorted_word_rank_idx = sorted(self.word_rank_idx, key=lambda k: self.word_rank_idx[k], reverse=True)
    
    def summarize(self, sent_num=3):
        summary = []
        index=[]
        for idx in self.sorted_sent_rank_idx[:sent_num]:
            index.append(idx)
        
        index.sort()
        for idx in index:
            summary.append(self.sentences[idx])
        return summary
    
    def keywords(self, word_num=10):
        rank = Rank()
        rank_idx = rank.get_ranks(self.words_graph)
        sorted_rank_idx = sorted(rank_idx, key=lambda k: rank_idx[k], reverse=True)
        
        keywords = []
        index=[]
        for idx in sorted_rank_idx[:word_num]:
            index.append(idx)
        #index.sort()
    
        for idx in index:
            keywords.append(self.idx2word[idx])
        return keywords

# %%
num = 0
textrank = TextRank(num)

for row in textrank.summarize(3):
    print(row)
    print()

print('keywords :',textrank.keywords())
# Out:
# 국정원 여직원 댓글 사건 수사를 은폐축소한 혐의로 기소돼 29일 대법원에서 무죄가 확정된 김용판57 전 서울경찰청장은 지난 2년 1개월 동안 수사재판 과정의 소회를 담은 회고록을 조만간 출간할 예정이다 나는 왜 청문회 선서를 거부했는가라는 제목의 회고록은 A4 용지 150쪽 분량으로 국정원 여직원 댓글 사건의 실체와 재판 과정 김 전 청장의 경찰 생활이 담겨 있다 본지가 단독으로 입수한 회고록에서 김 전 청장은 검찰을 향해 집단적인 도덕 불감증에 빠졌다고 했고 국회에서 대해선 삼류에 불과하다며 강하게 비판했다 사건 당시 수서경찰서 수사과장으로 댓글 사건 수사 은폐축소를 폭로한 새정치민주연합 권은희 의원에 대한 비판도 상당 부분 할애했다 그는 권 의원이 경찰을 그만두자 민주당 정세균 의원이 트위터에 김용판 같은 자가 엄벌에 처해지는 것이 상식인 나라 권은희 과장처럼 정의감 투철한 공무원이 보호받고 존경받을 수 있어야 정상적인 나라라고 쓴 것을 보고 책을 집필하게 됐다고 했다 그는 누가 자신의 책무를 다했고 누가 정치적 행동을 했는지 누가 진실을 이야기했고 누가 거짓으로 일관했는지를 밝혀야한다는 사명감이 들었다고 적었다 김용판 전 서울경찰청장 그는 회고록에서 국정원 댓글사건은 일부 언론 단체 기관 사람들의 선입견으로 진실은 묻히고 거짓과 위증만이 난무한 사건이라고 규정했다 이어 한 경찰관의 헛된 욕망에 찬 허무맹랑한 폭로에 의해 정치권은 물론 인터넷 언론 보수진영과 진보진영 나아가 좌익진영 등이 총출동해 격한 논란과 상대에 대한 공격이 벌어졌고 국가를 일대 혼란에 빠뜨렸다고 했다 1심
이상 되지 못한다고 했다 시민단체에 대해서는 권력을 가지고 있다고 생각하는 것이 문제다 본래의 목적은 상실하고 정치화되어 혼란을 부추긴다고 썼다 이어 권력이 싫어서 정부로부터 독립한 시민단체가 권력을 추구하는 행태는 모순이라고 했다 노무현 정부 때인 2003년 발생한 천성산 터널 도롱뇽 사건과 이명박 정부 때 광우병 파동을 시민단체 해악의 대표 사례로 들었다 김 전 청장은 A는 왜 편견에 가득 찬 허위 진술을 했을까라며 권은희 의원을 정면으로 비판했다 그는 검찰과 야권이 A의 허무맹랑한 폭로를 무조건 믿었다 재판이 처음부터 A라는 한 사람의 허위 증언에 의해 증폭되었다는 점을 많은 국민이 알지 못했다는 점이 아쉬웠다고 적었다 그러면서 A가 증인으로 나와 줄기차게 허위 진술을 했는데 그 허위 진술이 오히려 진실을 밝혀내는 데 큰 도움이 됐다고 했다 그는 국정원 여직원 댓글 사건 초기 수서경찰서의 A가 상황을 잘 파악하고 있더라고 칭찬을 했고 격려 전화한 게 외압으로 둔갑했다고 했다 김 전 청장이 1심에서 무죄를 선고받자 항소심에서 권 의원은 증언을 일부 바꿨다 김 전 청장은 위증을 하는 사람들이 일반적으로 자신의 주장에 설득력을 가미하기 위해 점차 살을 덧붙여 가면서 진술이 오히려 구체화되어 간다는 전형적인 사례와 너무나 일치되고 있음은 과연 우연일까 정말 소가 웃을 말이라고 했다
#
# keywords : ['책무', '예정', '무죄', '불감증', '일부', '이야기', '처음', '국민', '적극', '정치']

# %%
num = 1
textrank = TextRank(num)

for row in textrank.summarize(3):
    print(row)
    print()

print('keywords :',textrank.keywords())
# Out:
# 국립518민주묘지에서 새정치민주연합 당 대표에 출마한 박지원 박주선 주승용 최고의원 출마자 국립518민주묘지에서 새정치민주연합 당 대표에 출마한 박지원 박주선 이인영 의원이 참배 국립518민주묘지에서 새정치민주연합 당 대표에 출마한 박지원 국립 518민주묘지에서 가운데 당대표 후보로 나선 박지원 의원을 가운데 두고 주승용왼쪽의원과 정세균오른쪽의원 박주선의원  국립518민주묘지에서 새정치민주연합 당 대표에 출마한 박지원 국립 518민주묘지 참배를 마치고 가운데 당대표 후보로 나선 박지원 의원을 가운
#
# 데 두고 장병완왼쪽의원과정세균오른쪽 의원 사진클릭민주묘지 여자들이 좋아하는 선물 단체 선물 답례품 선물 추석선물 명절선물 직원선물 회사선물 효도선물 부모님선물  서 서 잡기 행보 이날 박지원 의원오른쪽 사진 가운데은 당 대표 출마를 선언한 이인영왼쪽 박주선 의원오른쪽과 함께 눈 내리는  북구 국립518민주묘지에서 참배했다     종합뉴스 3민주묘지 한국신과학협회 검색 상단사진 클릭 추석설명절선물부모님선물조카 수험생선물 보실수 있어요 한국신과학협회 검색 민주묘지 출처 이글은 인터냇서 인용한 글입니다
#
# keywords : ['왼쪽', '오른쪽', '이인영', '묘지', '뉴스', '사진', '종합', '추석', '북구', '상단']

# %%
# summarize_sentences = []
key_words = []

from tqdm.notebook import tqdm

for num in tqdm(range(len(content_list))):
    try:
        textrank = TextRank(num)
    except:
        pass 

#     for row in textrank.summarize(3):
#         summarize_sentences.append(row)
# #     print(row)
# #     print()

    key_words.append(textrank.keywords())
# Out:
# HBox(children=(IntProgress(value=0, max=2242), HTML(value='')))

# %%
def key_count(key_words):
    list_key = []
    for i in range(len(key_words)):
        list_key.extend(key_words[i])
#     print(list_key)
    from collections import Counter
    
    try:
        result = Counter(list_key)
    except:
        pass
    
    print("---Top 10 Keywords---")
    top = result.most_common(10)
    for top_key in top:
        print('#',top_key[0])
    print('\n')  
    
    print("---Counter()---") 
    print(result)

# %%
key_count(key_words)
# Out:
# ---Top 10 Keywords---
# # 의원
# # 정세균
# # 대표
# # 민주
# # 후보
# # 연합
# # 새정치
# # 서울
# # 민주당
# # 총선
#
#
# ---Counter()---
# Counter({'의원': 461, '정세균': 302, '대표': 239, '민주': 182, '후보': 152, '연합': 148, '새정치': 138, '서울': 134, '민주당': 133, '총선': 129, '지역': 126, '국회의원': 124, '위해': 113, '국민': 105, '종로': 102, '국회': 98, '대한': 97, '정치': 97, '문재인': 94, '대해': 93, '선거': 91, '종로구': 90, '새누리당': 89, '지난': 82, '출마': 79, '생각': 74, '문제': 73, '위원장': 71, '이번': 70, '정부': 69, '위원회': 69, '사람': 68, '관련': 67, '참석': 67, '대통령': 66, '야당': 66, '위원': 65, '때문': 60, '인사': 60, '경제': 59, '오늘': 59, '혁신': 54, '통해': 53, '시작': 52, '행사': 52, '공천': 51, '주민': 51, '결정': 51, '지금': 50, '모두': 49, '정책': 48, '사실': 48, '오세훈': 48, '라며': 47, '자신': 47, '가장': 47, '경우': 46, '대선': 46, '발표': 46, '강조': 45, '안철수': 45, '박근혜': 44, '주장': 44, '사진': 43, '승리': 42, '다른': 42, '결과': 42, '시장': 41, '대한민국': 41, '사회': 40, '지지': 40, '비판': 39, '서울시장': 39, '노무현': 38, '상황': 38, '당내': 37, '통합': 37, '예비': 37, '오후': 37, '요구': 37, '기사': 36, '청년': 36, '여당': 36, '오전': 35, '한국': 35, '여야': 35, '내년': 35, '지원': 35, '국민의당': 35, '당선': 34, '대상': 33, '지역구': 33, '자리': 32, '선언': 32, '진행': 32, '국가': 32, '야권': 32, '뉴스': 31, '방문': 31, '내용': 31, '이상': 31, '가능성': 31, '하나': 31, '이야기': 30, '정권': 30, '다시': 30, '과정': 30, '회장': 30, '문화': 30, '교수': 29, '사업': 29, '비롯': 29, '당시': 28, '가운데': 28, '부산': 28, '가지': 28, '분열': 28, '노력': 28, '개최': 28, '또한': 28, '활동': 28, '이후': 27, '호남': 27, '정치인': 27, '이제': 27, '미래': 27, '최근': 27, '시민': 27, '참여': 27, '회의': 27, '추진': 27, '중앙': 27, '설명': 26, '당원': 26, '교육': 26, '모든': 26, '예정': 26, '기념': 26, '세력': 25, '박지원': 25, '최고': 25, '중진': 25, '바로': 25, '발전': 25, '대책': 25, '서울시': 25, '개소식': 25, '김종인': 25, '정당': 24, '조사': 24, '김한길': 24, '원내대표': 24, '제정': 24, '현재': 23, '얘기': 23, '계파': 23, '지
#     print(list_key)
    from collections import Counter
    
    try:
        result = Counter(list_key)
    except:
        pass
    
    return result

# %%
result = result(key_words)
result
# Out:
# Counter({'책무': 2,
#          '예정': 29,
#          '무죄': 1,
#          '불감증': 1,
#          '일부': 17,
#          '이야기': 31,
#          '처음': 14,
#          '국민': 148,
#          '적극': 17,
#          '정치': 253,
#          '왼쪽': 16,
#          '오른쪽': 3,
#          '이인영': 9,
#          '묘지': 3,
#          '뉴스': 45,
#          '사진': 44,
#          '종합': 12,
#          '추석': 1,
#          '북구': 2,
#          '상단': 1,
#          '불출마': 14,
#          '결론': 4,
#          '대표': 263,
#          '비노': 15,
#          '전쟁': 4,
#          '사람': 71,
#          '출마': 74,
#          '가능': 54,
#          '결심': 4,
#          '의원': 494,
#          '무당': 1,
#          '리얼미터': 1,
#          '마지막': 21,
#          '유가족': 2,
#          '주일': 2,
#          '창당': 14,
#          '집계': 6,
#          '사무직': 1,
#          '여성': 12,
#          '보도': 7,
#          '박지': 1,
#          '원표': 2,
#          '지역': 136,
#          '지지': 40,
#          '총선': 135,
#          '극복': 4,
#          '혁명': 3,
#          '혁신': 52,
#          '지도자': 5,
#          '당권': 10,
#          '당시': 32,
#          '박세일': 1,
#          '입장': 22,
#          '지사': 11,
#          '이낙연': 3,
#          '후보': 171,
#          '경우': 46,
#          '블로그': 7,
#          '도전': 13,
#          '모진': 1,
#          '득표': 4,
#          '선행': 1,
#          '메시지': 10,
#          '기대': 20,
#          '박지원': 33,
#          '연설': 7,
#          '구청장': 13,
#          '김영종': 9,
#          '안전': 7,
#          '종로': 106,
#          '도시': 25,
#          '사회': 53,
#          '기본': 6,
#          '단계': 3,
#          '맞춤': 2,
#          '세력': 27,
#          '본선': 4,
#          '전망': 21,
#          '관측': 10,
#          '캐스팅': 2,
#          '보트': 3,
#          '주자': 14,
#          '금지': 4,
#          '컷오프': 8,
#          '대오': 1,
#          '이날': 100,
#          '사단': 3,
#          '육군': 1,
#          '임무': 1,
#          '정세균': 295,
#          '장병': 1,
#          '수행': 3,
#          '오전': 31,
#          '방문': 25,
#          '연합': 156,
#          '설명': 24,
#          '역대': 2,
#          '박관현': 1,
#          '국회의원': 134,
#          '선거': 108,
#          '차량': 1,
#          '자료': 14,
#          '격전': 1,
#          '위원': 54,
#          '최고': 21,
#          '승리': 50,
#          '대통령': 89,
#          '관람객': 2,
#          '매도': 2,
#          '절망': 2,
#          '정부': 72,
#          '시대': 16,
#          '참사': 2,
#          '선동이': 1,
#          '극장가': 1,
#          '이용': 7,
#          '전통': 5,
#          '이름': 8,
#          '권력': 8,
#          '당직자': 6,
#          '학생': 10,
#          '정청래': 14,
#          '보좌': 4,
#          '김영춘': 2,
#          '실무': 1,
#          '정당': 53,
#          '분위기': 11,
#          '그분': 5,
#          '교체': 16,
#          '별개': 2,
#          '장사': 2,
#          '누리': 93,
#          '자연': 5,
#          '운동': 26,
#          '자리': 38,
#          '조사': 45,
#          '선두': 1,
#          '김무성': 16,
#          '계단': 1,
#          '차기': 8,
#          '하락': 4,
#          '주간': 1,
#          '공감': 10,
#          '문재인': 65,
#          '자성': 1,
#          '거드름': 1,
#          '존립': 1,
#          '선언': 32,
#          '충남': 7,
#          '간담회': 8,
#          '기초': 3,
#          '경선': 27,
#          '선출': 8,
#          '재선': 7,
#          '유일': 3,
#          '상태': 12,
#          '등록': 13,
#          '박원순': 16,
#          '손학규': 9,
#          '김두관': 2,
#          '발표': 47,
#          '노무현': 39,
#          '부산': 20,
#          '당원': 36,
#          '안철수': 52,
#          '필요': 42,
#          '원장': 13,
#          '청장': 6,
#          '국장': 7,
#          '정보': 9,
#          '고용': 15,
#          '복지': 19,
#          '위원회': 85,
#          '대구': 20,
#          '경북': 4,
#          '국사': 3,
#          '국가': 34,
#          '연예계': 1,
#          '법조': 3,
#          '경영': 6,
#          '바깥': 2,
#          '경쟁': 16,
#          '관리': 12,
#          '평가': 17,
#          '단일': 7,
#          '행보': 11,
#          '중진': 28,
#          '당내': 43,
#          '옛날': 1,
#          '준비': 21,
#          '고심': 2,
#          '공천': 51,
#          '이번': 78,
#          '문재': 40,
#          '생각': 75,
#          '대권': 20,
#          '시도': 6,
#          '여론': 31,
#          '과반': 2,
#          '이후': 38,
#          '관련': 60,
#          '대회': 29,
#          '교수': 27,
#          '패권': 1,
#          '숙주': 1,
#          '연출': 5,
#          '잔여': 1,
#          '전당': 17,
#          '문제': 75,
#          '전북': 15,
#          '호남': 26,
#          '권리': 1,
#          '인터뷰': 25,
#          '민주': 184,
#          '대신': 8,
#          '변경': 3,
#          '고위급': 1,
#          '정치인': 23,
#          '호소': 20,
#          '지방': 14,
#          '출신': 22,
#          '정권': 36,
#          '도민': 2,
#          '말씀': 17,
#          '관심': 31,
#          '대선': 42,
#          '비판': 42,
#          '정책': 53,
#          '기사': 31,
#          '지적': 27,
#          '싸움': 13,
#          '제기': 11,
#          '감동': 5,
#          '전대': 8,
#          '갈등': 24,
#          '흥행': 3,
#          '계파': 26,
#          '대책': 29,
#          '부의장': 5,
#          '본부': 10,
#          '유대운': 1,
#          '이사': 6,
#          '희망': 17,
#          '조직': 6,
#          '대중': 4,
#          '모습': 25,
#          '부작용': 1,
#          '스포트라이트': 1,
#          '전국': 22,
#          '관계자': 21,
#          '지난해': 15,
#          '구체': 4,
#          '겨냥': 3,
#          '강조': 47,
#          '동지': 5,
#          '세종': 7,
#          '참석': 63,
#          '여러분': 19,
#          '이것': 11,
#          '김부겸': 13,
#          '공약': 20,
#          '기존': 5,
#          '사설': 6,
#          '비서관': 7,
#          '합의': 13,
#          '이미지': 7,
#          '최경환': 4,
#          '걱정': 15,
#          '분석': 22,
#          '공연': 6,
#          '이화여대': 1,
#          '현악': 1,
#          '시작': 52,
#          '오케스트라': 1,
#          '중주': 1,
#          '학장': 1,
#          '통일': 7,
#          '상생': 4,
#          '포럼': 10,
#          '과정': 30,
#          '진행': 31,
#          '리더십': 4,
#          '최고위': 2,
#          '동국': 2,
#          '졸업식': 5,
#          '대학': 13,
#          '국회': 127,
#          '귀빈': 2,
#          '시상식': 8,
#          '손인춘': 1,
#          '식당': 2,
#          '선정': 15,
#          '의정': 9,
#          '무엇': 15,
#          '터널': 1,
#          '졸속': 1,
#          '주민': 56,
#          '가치': 20,
#          '복원': 5,
#          '사직단': 3,
#          '문화재청': 1,
#          '계획': 19,
#          '토론회': 11,
#          '서민': 8,
#          '부분': 12,
#          '모양': 3,
#          '사과': 13,
#          '청와대': 22,
#          '고려대': 3,
#          '미래': 31,
#          '선택': 18,
#          '때문': 78,
#          '인천': 13,
#          '탈락': 5,
#          '예상': 16,
#          '광주': 21,
#          '봉승': 1,
#          '얼리': 4,
#          '나라': 29,
#          '영상': 10,
#          '전문': 9,
#          '산업': 26,
#          '시장': 82,
#          '축사': 11,
#          '경기도지사': 1,
#          '위원장': 90,
#          '이사장': 11,
#          '기획': 13,
#          '동네': 12,
#          '야당': 68,
#          '김상옥': 1,
#          '동경': 1,
#          '공훈': 1,
#          '금연': 5,
#          '애국선열': 2,
#          '등지': 1,
#          '결사대': 1,
#          '교회': 11,
#          '생산': 6,
#          '건배': 1,
#          '신년': 6,
#          '설치': 9,
#          '이강배': 1,
#          '종로구': 83,
#          '밸리': 1,
#          '소집': 2,
#          '심재득': 1,
#          '쓰레기통': 1,
#          '아침': 10,
#          '그때': 8,
#          '모두': 9,
#          '하나': 30,
#          '무리': 4,
#          '대안': 13,
#          '기도': 5,
#          '합심': 1,
#          '한국': 43,
#          '조찬': 2,
#          '기독': 1,
#          '기도회': 1,
#          '상황': 39,
#          '구성': 13,
#          '지금': 17,
#          '실패': 10,
#          '외면': 4,
#          '인정': 4,
#          '타전': 1,
#          '전남': 15,
#          '김동신': 1,
#          '그룹': 9,
#          '김창식': 1,
#          '김승규': 1,
#          '대법원장': 1,
#          '박광태': 1,
#          '새해': 8,
#          '개최': 25,
#          '분야': 7,
#          '어상': 1,
#          '박근': 1,
#          '윤제균': 1,
#          '단체': 13,
#          '대상': 28,
#          '이상': 34,
#          '홍문종': 1,
#          '문화': 28,
#          '미디': 3,
#          '양강': 1,
#          '적임자': 1,
#          '당초': 2,
#          '인물': 10,
#          '구도': 14,
#          '유승민': 12,
#          '안방': 1,
#          '우위': 2,
#          '박근혜': 53,
#          '반영': 6,
#          '여기': 10,
#          '시선': 3,
#          '확보': 9,
#          '상임': 20,
#          '위협': 2,
#          '추진': 32,
#          '당명': 1,
#          '민주당': 126,
#          '표현': 4,
#          '상실': 2,
#          '통합': 43,
#          '사심': 2,
#          '용서': 2,
#          '경험': 5,
#          '존재감': 2,
#          '지원': 43,
#          '올해': 20,
#          '노가': 1,
#          '재편': 4,
#          '이유': 21,
#          '현실': 15,
#          '안정': 6,
#          '안희정': 11,
#          '미소': 3,
#          '언급': 14,
#          '방향': 9,
#          '선회': 1,
#          '포위망': 1,
#          '화순': 1,
#          '연설회': 1,
#          '결과': 52,
#          '야가': 1,
#          '박수현': 1,
#          '위기': 18,
#          '약속': 7,
#          '협상': 2,
#          '특별': 14,
#          '승부': 7,
#          '자신': 44,
#          '인사': 69,
#          '단독': 3,
#          '고민': 12,
#          '공동': 39,
#          '무게': 2,
#          '장담': 1,
#          '도움': 15,
#          '비주류': 12,
#          '신경전': 1,
#          '영입': 8,
#          '양상': 5,
#          '당대': 2,
#          '분리': 2,
#          '응수': 1,
#          '여야': 38,
#          '겁니다': 3,
#          '거기': 7,
#          '경남': 11,
#          '수진': 1,
#          '자기': 10,
#          '분당': 8,
#          '협력': 7,
#          '전화': 7,
#          '과거': 13,
#          '시민': 34,
#          '응답': 6,
#          '고문': 20,
#          '구실': 1,
#          '누구': 15,
#          '가운데': 30,
#          '아이': 11,
#          '멘토': 1,
#          '인생': 6,
#          '세상': 12,
#          '애벌레': 1,
#          '약식': 5,
#          '공명선거': 1,
#          '오후': 37,
#          '일정': 17,
#          '접촉': 1,
#          '재래': 3,
#          '젊은이': 1,
#          '변수': 7,
#          '정리': 8,
#          '파전': 1,
#          '향후': 3,
#          '인방': 2,
#          '쇄신': 10,
#          '실장': 10,
#          '배분': 1,
#          '비서': 8,
#          '서창훈': 1,
#          '세종문화회관': 5,
#          '인상': 10,
#          '수회': 1,
#          '사회장': 1,
#          '재경': 2,
#          '밀알': 1,
#          '결핍': 1,
#          '임명': 5,
#          '측면': 6,
#          '생활': 8,
#          '정국': 6,
#          '부여': 4,
#          '도당': 2,
#          '경륜': 3,
#          '당제': 1,
#          '명분': 6,
#          '측근': 9,
#          '진보': 9,
#          '담집': 1,
#          '조경태': 2,
#          '면담': 2,
#          '개별': 3,
#          '초청': 4,
#          '을미': 2,
#          '기념사업': 2,
#          '회장': 21,
#          '송일국': 1,
#          '보훈': 3,
#          '양당': 3,
#          '확장': 2,
#          '재정': 3,
#          '본인': 11,
#          '소속': 27,
#          '요구': 34,
#          '각종': 7,
#          '의사': 9,
#          '경제': 86,
#          '내년': 30,
#          '박주선': 6,
#          '콩나물': 1,
#          '합류': 2,
#          '지향': 2,
#          '김근태': 4,
#          '음모': 1,
#          '지도부': 27,
#          '포기': 5,
#          '사생결단': 1,
#          '송년': 1,
#          '김대중': 15,
#          '강서': 5,
#          '뭔지': 1,
#          '변화': 14,
#          '그간': 2,
#          '검찰': 13,
#          '강원도': 2,
#          '대사': 6,
#          '제안': 23,
#          '의문': 3,
#          '상대': 13,
#          '충청': 3,
#          '충북': 5,
#          '주요': 21,
#          '방법': 11,
#          '가치관': 1,
#          '사살': 1,
#          '정신': 6,
#          '재조명': 1,
#          '민생': 12,
#          '실현': 7,
#          '공안': 2,
#          '역할': 14,
#          '강경': 1,
#          '관계': 13,
#          '내부': 10,
#          '대다수': 5,
#          '대략': 1,
#          '남북': 8,
#          '개인': 16,
#          '결국': 14,
#          '주장': 44,
#          '전체': 17,
#          '음력': 1,
#          '사주': 2,
#          '기운': 5,
#          '등장': 11,
#          '도지사': 4,
#          '봄빛': 1,
#          '주승용': 4,
#          '참배': 4,
#          '국립': 2,
#          '그것': 25,
#          '학부모': 2,
#          '교육': 18,
#          '노원': 18,
#          '예산': 11,
#          '우원식': 2,
#          '부문': 7,
#          '당장': 4,
#          '김현숙': 1,
#          '정의': 13,
#          '강화': 10,
#          '입지': 5,
#          '행사': 50,
#          '유력': 3,
#          '최근': 37,
#          '시기': 4,
#          '관점': 2,
#          '등등': 4,
#          '노력': 39,
#          '뭔가': 2,
#          '마음': 22,
#          '신뢰': 7,
#          '해결': 12,
#          '회복': 6,
#          '성공': 15,
#          '우윤근': 6,
#          '원내대표': 25,
#          '비대위': 11,
#          '노비': 1,
#          '도로': 5,
#          '탈당': 18,
#          '정동영': 10,
#          '해체': 1,
#          '반대': 32,
#          '서울': 185,
#          '조우': 1,
#          '인권': 7,
#          '일본': 14,
#          '업적': 2,
#          '의혹': 15,
#          '경기도': 9,
#          '해석': 9,
#          '당선': 36,
#          '내외': 3,
#          '정원': 2,
#          '추천': 7,
#          '평판': 1,
#          '연구회': 4,
#          '부인회': 1,
#          '연구원': 11,
#          '중앙': 25,
#          '연구': 18,
#          '박진우': 1,
#          '개혁': 16,
#          '심포지엄': 2,
#          '포함': 7,
#          '배제': 16,
#          '감정': 4,
#          '이탈': 2,
#          '연대': 26,
#          '분열': 28,
#          '노사모': 1,
#          '논쟁': 2,
#          '정서': 5,
#          '이주영': 1,
#          '이종걸': 9,
#          '원혜영': 7,
#          '김기준': 5,
#          '강창일': 1,
#          '민병두': 4,
#          '박맹우': 1,
#          '맹비난': 1,
#          '간디': 1,
#          '부각': 1,
#          '김일성': 1,
#          '내용': 41,
#          '네티즌': 3,
#          '존경': 4,
#          '방식': 13,
#          '결정': 43,
#          '경기장': 1,
#          '조종': 1,
#          '시간': 37,
#          '사이': 15,
#          '규칙': 1,
#          '입력': 6,
#          '중도': 2,
#          '언제': 2,
#          '재보': 4,
#          '지지자': 12,
#          '변질': 1,
#          '난무': 2,
#          '자인': 1,
#          '자유': 11,
#          '탈환': 3,
#          '수단': 3,
#          '합산': 1,
#          '행동': 6,
#          '혈안': 1,
#          '감안': 3,
#          '금요일': 1,
#          '이강래': 2,
#          '해머': 1,
#          '상임위': 1,
#          '저녁': 6,
#          '파행': 1,
#          '전병헌': 6,
#          '발언': 24,
#          '체제': 10,
#          '학점': 1,
#          '일산동': 1,
#          '정의당': 8,
#          '김장실': 1,
#          '선고': 3,
#          '재판': 2,
#          '폭로': 1,
#          '행태': 2,
#          '거짓': 4,
#          '트위터': 4,
#          '위증': 1,
#          '미디어': 6,
#          '수상': 8,
#          '대한민국': 35,
#          '대학생': 7,
#          '사인': 1,
#          '원회': 1,
#          '발전': 30,
#          '주문': 2,
#          '누가': 17,
#          '투표': 17,
#          '위상': 1,
#          '잠재': 5,
#          '시험대': 1,
#          '보선': 4,
#          '대립': 3,
#          '지지층': 7,
#          '전면전': 3,
#          '비상': 10,
#          '수정': 5,
#          '야권': 35,
#          '영향': 6,
#          '기간': 6,
#          '아래': 9,
#          '지정': 3,
#          '인터넷': 3,
#          '주의자': 1,
#          '참가': 4,
#          '제재': 2,
#          '방침': 7,
#          '신임': 11,
#          '사업': 19,
#          '각하': 1,
#          '중소기업': 7,
#          '개소': 2,
#          '개정안': 9,
#          '세대': 4,
#          '부족': 3,
#          '비정규직': 4,
#          '유승희': 5,
#          '오영식': 6,
#          '박우섭': 1,
#          '순서': 3,
#          '김영록': 3,
#          '캠프': 2,
#          '분류': 5,
#          '대변인': 11,
#          '정비': 3,
#          '확정': 15,
#          '협의': 3,
#          '이전': 4,
#          '예방': 4,
#          '이희호': 3,
#          '인선': 2,
#          '개정': 9,
#          '압도': 3,
#          '동안': 26,
#          '막바지': 2,
#          '김한길': 25,
#          '드라마': 1,
#          '근처': 4,
#          '도착': 3,
#          '매력': 3,
#          '언어': 2,
#          '리얼리즘': 1,
#          '대로': 3,
#          '의장': 38,
#          '취임': 5,
#          '참여': 36,
#          '기부': 1,
#          '기업': 34,
#          '라이스': 1,
#          '챌린지': 1,
#          '캠페인': 8,
#          '버킷': 1,
#          '방촌': 1,
#          '난동': 2,
#          '사건': 13,
#          '비준': 1,
#          '국민행동본부': 1,
#          '쇠망치': 1,
#          '파괴': 1,
#          '화합': 3,
#          '비교': 6,
#          '발휘': 5,
#          '윷점': 1,
#          '장소': 4,
#          '제례': 1,
#          '종사자': 1,
#          '공단': 13,
#          '이외': 1,
#          '시위': 3,
#          '촛불': 1,
#          '민노당': 4,
#          '전단': 1,
#          '홍성기': 1,
#          '김정일': 4,
#          '노인': 7,
#          '센터': 19,
#          '지역구': 32,
#          '구기동': 5,
#          '구민': 13,
#          '목사': 9,
#          '특별기': 1,
#          '교구': 1,
#          '압박': 10,
#          '사무총장': 8,
#          '영웅': 1,
#          '자민련': 1,
#          '권역': 5,
#          '한나라당': 13,
#          '이완구': 3,
#          '청문회': 5,
#          '동반': 3,
#          '회견': 12,
#          '사실': 25,
#          '원로': 4,
#          '상의': 1,
#          '주목': 15,
#          '책임': 21,
#          '예비': 31,
#          '승자': 2,
#          '울산': 3,
#          '집중력': 1,
#          '비즈니스': 1,
#          '협회': 14,
#          '휠라': 1,
#          '경기': 26,
#          '세계': 16,
#          '후원': 12,
#          '후원금': 1,
#          '쌍용': 1,
#          '일화': 1,
#          '한미': 1,
#          '온라인': 9,
#          '노총': 2,
#          '동북공정': 1,
#          '대란': 1,
#          '민국': 1,
#          '얘기': 23,
#          '속도': 5,
#          '비유': 1,
#          '국수': 2,
#          '북부': 5,
#          '촉구': 20,
#          '해소': 11,
#          '부동산': 3,
#          '공사': 6,
#          '박계': 6,
#          '선관위': 4,
#          '낭비': 2,
#          '의견': 20,
#          '제출': 6,
#          '서북': 4,
#          '공유': 3,
#          '신분당선': 5,
#          '노선': 4,
#          '교통': 8,
#          '지지율': 11,
#          '다음': 25,
#          '골머리': 1,
#          '번호': 2,
#          '조선': 5,
#          '투기': 2,
#          '일반': 10,
#          '여부': 10,
#          '김현목': 2,
#          '세균': 20,
#          '결산': 3,
#          '산업자원부': 7,
#          '전정': 1,
#          '강동원': 5,
#          '보좌관': 5,
#          '자영업': 2,
#          '구축': 6,
#          '뿌리': 3,
#          '소장': 9,
#          '플랫': 1,
#          '진심': 3,
#          '창립': 4,
#          '강의': 6,
#          '발의': 8,
#          '표준': 3,
#          '정도': 14,
#          '기관': 14,
#          '가난': 3,
#          '물품': 3,
#          '마련': 22,
#          '과장': 4,
#          '마을': 7,
#          '세부': 2,
#          '부모': 6,
#          '교통난': 2,
#          '성향': 5,
#          '김수행': 1,
#          '계몽주의': 1,
#          '구상': 2,
#          '시스템': 4,
#          '옥상': 1,
#          '출범': 8,
#          '농사': 2,
#          '도시농업포럼': 2,
#          '감사': 37,
#          '황소': 1,
#          '외교': 19,
#          '역사': 31,
#          '출석': 6,
#          '셔먼': 1,
#          '차관': 8,
#          '실업': 8,
#          '청년층': 5,
#          '체감': 2,
#          '취업': 4,
#          '청년': 45,
#          '극해': 1,
#          '김기식': 3,
#          '김태환': 1,
#          '김현': 1,
#          '백재현': 1,
#          '항의': 5,
#          '표명': 2,
#          '답변': 4,
#          '접근': 2,
#          '외교부': 2,
#          '마크': 2,
#          '주한': 2,
#          '리퍼트': 1,
#          '미국': 16,
#          '가게': 6,
#          '불상사': 1,
#          '경계': 2,
#          '균열': 1,
#          '미관': 1,
#          '낙선': 4,
#          '의무': 1,
#          '반대표': 1,
#          '어린이집': 3,
#          '규정': 12,
#          '검증': 7,
#          '지난달': 6,
#          '공부': 1,
#          '과학': 4,
#          '김재호': 1,
#          '김해성': 1,
#          '두산': 1,
#          '서울시': 25,
#          '이두아': 1,
#          '박범계': 2,
#          '명단': 5,
#          '결자': 1,
#          '김제남': 5,
#          '나성린': 1,
#          '김태원': 2,
#          '박민식': 1,
#          '임금': 12,
#          '모임': 6,
#          '사망': 1,
#          '법원': 6,
#          '법원장': 1,
#          '철거민': 1,
#          '고회': 2,
#          '감수': 1,
#          '대화': 8,
#          '인구': 2,
#          '교정': 1,
#          '김용판': 1,
#          '편견': 1,
#          '그리스': 1,
#          '고백': 1,
#          '질문': 10,
#          '부처': 3,
#          '장악력': 1,
#          '장관': 26,
#          '공직자': 4,
#          '심화': 2,
#          '지목': 2,
#          '혐의': 3,
#          '후진': 1,
#          '수석': 11,
#          '위치': 8,
#          '재산': 3,
#          '해당': 6,
#          '폭력': 5,
#          '성격': 1,
#          '방송': 22,
#          '공원': 10,
#          '구립': 1,
#          '경치': 1,
#          '계곡': 2,
#          '옥인동': 1,
#          '개월': 13,
#          '고학력': 2,
#          '일자리': 17,
#          '신세': 1,
#          '통계청': 2,
#          '구직자': 1,
#          '커피': 3,
#          '최저': 2,
#          '주인': 3,
#          '공개': 20,
#          '단어': 2,
#          '시절': 7,
#          '국정': 32,
#          '대통': 2,
#          ...})

# %%
count_list = dict(result)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf', background_color='white', width=1200, height=1000).generate_from_frequencies(count_list) 
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud) 
plt.axis("off") 
plt.show()

# %%
site.getsitepackages()
# Out:
# ['C:\\Users\\yuna1\\AppData\\Local\\Continuum\\anaconda3',
#  'C:\\Users\\yuna1\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages']

# %%
C:\Users\yuna1\AppData\Local\Continuum\anaconda3\lib\site-packages
