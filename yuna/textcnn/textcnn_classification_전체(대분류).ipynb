# %% [markdown]
# # 환경설정

# %%
# !git clone https://github.com/kakao/khaiii.git
# !pip install cmake
# !mkdir build
# !cd build && cmake /content/khaiii
# !cd /content/build/ && make all
# !cd /content/build/ && make resource
# !cd /content/build && make install
# !cd /content/build && make package_python
# !pip install /content/build/package_python

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/fininsight/21대 총선분석/Text Classification/TextCNN/cnn-text-classification-tf
# Out:
# /content/drive/My Drive/fininsight/21대 총선분석/Text Classification/TextCNN/cnn-text-classification-tf

# %% [markdown]
# # 데이터 생성

# %%
import pandas as pd

df = pd.read_csv('전체.csv')
df.head(3)
# Out:
#                                                  url category1  ... want sad
# 0  https://news.naver.com/main/read.nhn?mode=LS2D...        정치  ...  NaN NaN
# 1  https://news.naver.com/main/read.nhn?mode=LS2D...        정치  ...  NaN NaN
# 2  https://news.naver.com/main/read.nhn?mode=LS2D...        정치  ...  NaN NaN
#
# [3 rows x 17 columns]

# %%
print(df.shape)
df =df.dropna(subset=['content']) 
print(df.shape)
# Out:
# (410392, 17)
# (410374, 17)

# %%
df['category1'].unique()
# Out:
# array(['정치', '생활/문화', '사회', '경제', 'IT/과학'], dtype=object)

# %% [markdown]
# 데이터 축소

# %%
df1 = df.loc[df['category1']=='정치'].iloc[:int(df.loc[df['category1']=='정치'].shape[0]/3),:]
df2 = df.loc[df['category1']=='생활/문화'].iloc[:int(df.loc[df['category1']=='생활/문화'].shape[0]/3),:]
df3 = df.loc[df['category1']=='사회'].iloc[:int(df.loc[df['category1']=='사회'].shape[0]/3),:]
df4 = df.loc[df['category1']=='경제'].iloc[:int(df.loc[df['category1']=='경제'].shape[0]/3),:]
df5 = df.loc[df['category1']=='IT/과학'].iloc[:int(df.loc[df['category1']=='IT/과학'].shape[0]/3),:]

df = pd.concat([df1, df2])
df = pd.concat([df, df3])
df = pd.concat([df, df4])
df = pd.concat([df, df5])
df.shape
# Out:
# (136789, 17)

# %%
import re
def pre_fx(text):
    # 이메일 등장하면, 그 뒷문장 모두 삭제 
    text = re.sub("[a-zA-Z0-9]+\@[a-zA-Z0-9]+\.[a-z]{1,3}.[a-z]{1,3}.+",'',text).strip()
    text = re.sub('\(.+?연합뉴스\)','',text).strip() # (서울=연합뉴스)
    text = re.sub('\(.+?연합인포맥스\)','',text).strip()
    text = re.sub('\(.+?이데일리\)','',text).strip()
    text = re.sub('\(.+?조선일보\)','',text).strip()
    text = re.sub('\(.+?뉴시스\)',' ',text).strip()
    text = re.sub('\(.+?뉴스1\)','',text).strip()
    text = re.sub('\(.+?SBS\)','',text).strip()
    text = re.sub('\(.+?오마이뉴스\)','',text).strip()
    text = re.sub('\(.+?중앙일보\)','',text).strip()
    text = re.sub('\(.+?매일경제\)','',text).strip()
    text = re.sub('\(.+?문화일보\)','',text).strip()
    text = re.sub('\(.+?세계일보\)','',text).strip()
    text = re.sub('\(.+?머니투데이\)','',text).strip()
    text = re.sub('\(.+?서울경제\)','',text).strip()
    text = re.sub('\(.+?데일리안\)','',text).strip()
    text = re.sub('\(.+?KBS\)','',text).strip()
    text = re.sub('\(.+?MBN\)','',text).strip()
    text = re.sub('\(.+?YTN\)','',text).strip()
    text = re.sub('\(.+?프레시안\)','',text).strip()
    text = re.sub('\(.+?디지털타임즈\)','',text).strip()
    text = re.sub('\(.+?국민일보(과거)\)','',text).strip()
    text = re.sub('\(.+?국민일보\)','',text).strip()
    text = re.sub('\(.+?헤드럴경제\)','',text).strip()
    text = re.sub('\(.+?한국일보\)','',text).strip()
    text = re.sub('\(.+?아이뉴스24\)','',text).strip()
    text = re.sub('\(.+?노컷뉴스\)','',text).strip()
    text = re.sub('\(.+?연합뉴스TV\)','',text).strip()
    text = re.sub('\(.+?서울일보\)','',text).strip()
    text = re.sub('\(.+?동아일보\)','',text).strip()
    text = re.sub('\(.+?한국경제\)','',text).strip()
    text = re.sub('\(.+?미디어오늘(과거)\)','',text).strip()
    text = re.sub('\(.+?미디어오늘\)','',text).strip()
    text = re.sub('\(.+?조세일보\)','',text).strip()
    text = re.sub('\(.+?파이낸셜뉴스\)','',text).strip()
    text = re.sub('\(.+?경향신문\)','',text).strip()
    text = re.sub('\(.+?채널A\)','',text).strip()
    text = re.sub('\(.+?머니S\)','',text).strip()
    text = re.sub('\(.+?TVCHOSUN\)','',text).strip()
    text = re.sub('\(.+?한겨례\)','',text).strip()
    text = re.sub('\(.+?전자신문\)','',text).strip()
    text = re.sub('\(.+?SBSCNBC\)','',text).strip()
    text = re.sub('\(.+?한국경제TV\)','',text).strip()
    text = re.sub('\(.+?조선비즈\)','',text).strip()
    text = re.sub('\(.+?ZDNetKorea\)','',text).strip()
    text = re.sub('\[.+?\]','',text).strip()
    text = re.sub('\(사진.+?\)','',text).strip()
    # 신문사 이름 삭제 
    text = re.sub('조선일보|뉴시스|아시아경제|이데일리|뉴스1|SBS|오마이뉴스|중앙일보|매일경제|문화일보|세계일보|머니투데이|서울경제|데일리안|KBS|MBN|YTN|프레시안|디지털타임스|국민일보(과거)|국민일보|헤럴드경제|한국일보|아이뉴스24|노컷뉴스|연합뉴스TV|서울일보|동아일보|한국경제|미디어오늘(과거)|미디어오늘|조세일보|파이낸셜뉴스|경향신문|채널A|머니S|TVCHOSUN|한겨례|전자신문|SBSCNBC|한국경제TV|조선비즈|ZDNetKorea','',text).strip()
    # 000 기자, 000  가자, 000기자 삭제
    text = re.sub('[ㄱ-힑]+ 기자|[ㄱ-힑]+  기자|[ㄱ-힑]+기자','',text).strip()    
    text = re.sub('[a-zA-Z0-9]{1,20}\@[a-zA-Z0-9]{1,20}\.[a-z]{1,20}.+','',text).strip()    

    return text

df['content'] = df['content'].map(lambda x : pre_fx(x))

# %%
#기존 클렌징으로 부족한 부분
import re
def filter(s):
  hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글과 띄어쓰기를 제외한 모든 글자
  result = hangul.sub('', s) # 한글과 띄어쓰기를 제외한 모든 부분을 제거
  return result

df['content'] = df['content'].apply(filter)
df.head(3)
# Out:
#                                                  url category1  ... want sad
# 0  https://news.naver.com/main/read.nhn?mode=LS2D...        정치  ...  NaN NaN
# 1  https://news.naver.com/main/read.nhn?mode=LS2D...        정치  ...  NaN NaN
# 2  https://news.naver.com/main/read.nhn?mode=LS2D...        정치  ...  NaN NaN
#
# [3 rows x 17 columns]

# %% [markdown]
# ## mecab 토큰화

# %%
! git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# fatal: destination path 'Mecab-ko-for-Google-Colab' already exists and is not an empty directory.

# %%
 cd Mecab-ko-for-Google-Colab
# Out:
# /content/drive/My Drive/fininsight/21대 총선분석/Text Classification/TextCNN/cnn-text-classification-tf/Mecab-ko-for-Google-Colab

# %%
! bash install_mecab-ko_on_colab190912.sh

# %%
## 명사 형용사만 추출
from konlpy.tag import Mecab 
mecab = Mecab() 

def mecab_nouns(sentence):
  pos = mecab.pos(sentence) 
  morphs = [x[0] for x in pos if x[1] in ['NNG', 'NNP', 'NNB', 'NR', 'NP', 'VA'] and len(x[0]) >1 ]
  return morphs

df['mecan_token'] = df['content'].apply(mecab_nouns)
df.head(3)
# Out:
#                                                  url  ...                                        mecan_token
# 0  https://news.naver.com/main/read.nhn?mode=LS2D...  ...  [오류, 우회, 함수, 추가, 북미, 실무, 협상, 합의, 트럼프, 밤사이, 심경,...
# 1  https://news.naver.com/main/read.nhn?mode=LS2D...  ...  [오류, 우회, 함수, 추가, 성윤모, 산업, 통상, 자원, 장관, 종시, 정부세종...
# 2  https://news.naver.com/main/read.nhn?mode=LS2D...  ...  [오류, 우회, 함수, 추가, 미국, 방문, 문희상, 국회, 의장, 오른쪽, 현지,...
#
# [3 rows x 18 columns]

# %%
# from konlpy.tag import Mecab 
# mecab = Mecab() 

# def mecab_nouns(sentence):
#   nouns = mecab.nouns(sentence) 
#   return nouns

# df['mecan_token'] = df['content'].apply(mecab_nouns)
# df.head(3)
# Out:
#                                                  url  ...                                        mecan_token
# 0  https://news.naver.com/main/read.nhn?mode=LS2D...  ...  [오류, 우회, 함수, 추가, 북미, 간, 실무, 협상, 합의, 것, 트럼프, 밤사...
# 1  https://news.naver.com/main/read.nhn?mode=LS2D...  ...  [오류, 우회, 함수, 추가, 성윤모, 산업, 통상, 자원, 부, 장관, 일, 종시...
# 2  https://news.naver.com/main/read.nhn?mode=LS2D...  ...  [오류, 우회, 함수, 추가, 미국, 방문, 중, 문희상, 국회, 의장, 오른쪽, ...
#
# [3 rows x 18 columns]

# %%
def joini(x):
  y = []
  for xx in x:
    if xx != '':
      y.append(xx)

  return ' '.join(y)

df['tokens'] = df['mecan_token'].apply(joini)

# %%
df =df.dropna(subset=['tokens']) 
df['data'] = df['tokens'] +',' + df['category1']
df.head(3)
# Out:
#                                                  url  ...                                               data
# 0  https://news.naver.com/main/read.nhn?mode=LS2D...  ...  오류 우회 함수 추가 북미 실무 협상 합의 트럼프 밤사이 심경 변화 볼턴 악역 영변...
# 1  https://news.naver.com/main/read.nhn?mode=LS2D...  ...  오류 우회 함수 추가 성윤모 산업 통상 자원 장관 종시 정부세종청사 산업 통상 자원...
# 2  https://news.naver.com/main/read.nhn?mode=LS2D...  ...  오류 우회 함수 추가 미국 방문 문희상 국회 의장 오른쪽 현지 시간 워싱턴 국회 사...
#
# [3 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split
train, dev = train_test_split(df, test_size=0.33, random_state=42)

# %%
x = list(df['category1'].unique())
x
# Out:
# ['정치', '생활/문화', '사회', '경제', 'IT/과학']

# %%
cd /content/drive/My Drive/fininsight/21대 총선분석/Text Classification/TextCNN/cnn-text-classification-tf/data
# Out:
# /content/drive/My Drive/fininsight/21대 총선분석/Text Classification/TextCNN/cnn-text-classification-tf/data

# %%
f = open("cls.txt" , 'w')
for i in range(len(list(df['category1'].unique()))):
  try:
    f.write(list(df['category1'].unique())[i])
    f.write('\n')
  except:
    pass
f.close()

# %%
f = open("train.txt" , 'w')
for i in range(len(train['data'])):
  try:
    f.write(train['data'][i])
    f.write('\n')
  except:
    pass
f.close()

# %%
f = open("dev.txt" , 'w')
for i in range(len(dev['data'])):
  try:
    f.write(dev['data'][i])
    f.write('\n')
  except:
    pass
f.close()

# %% [markdown]
# # Train

# %%
cd /content/drive/My Drive/fininsight/21대 총선분석/Text Classification/TextCNN/cnn-text-classification-tf
# Out:
# /content/drive/My Drive/fininsight/21대 총선분석/Text Classification/TextCNN/cnn-text-classification-tf

# %%
# from google.colab import files
# files.upload()
# Out:
#      <input type="file" id="files-55a379d6-5f48-4261-8ae5-5aab282c44fa" name="files[]" multiple disabled />
#      <output id="result-55a379d6-5f48-4261-8ae5-5aab282c44fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving categorical_vocabulary.py to categorical_vocabulary.py
# {'categorical_vocabulary.py': b'# Copyright 2016 The TensorFlow Authors. All Rights Reserved.\n#\n# Licensed under the Apache License, Version 2.0 (the "License");\n# you may not use this file except in compliance with the License.\n# You may obtain a copy of the License at\n#\n#     http://www.apache.org/licenses/LICENSE-2.0\n#\n# Unless required by applicable law or agreed to in writing, software\n# distributed under the License is distributed on an "AS IS" BASIS,\n# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.\n# See the License for the specific language governing permissions and\n# limitations under the License.\n# ==============================================================================\n\n"""Categorical vocabulary classes to map categories to indexes.\n\nCan be used for categorical variables, sparse variables and words.\n"""\n\nfrom __future__ import absolute_import\nfrom __future__ import division\nfrom __future__ import print_function\n\nimport collections\nimport six\n\n\nclass CategoricalVocabulary(object):\n  """Categorical variables vocabulary class.\n\n  Accumulates and provides mapping from classes to indexes.\n  Can be easily used for words.\n  """\n\n  def __init__(self, unknown_token="<UNK>", support_reverse=True):\n    self._unknown_token = unknown_token\n    self._mapping = {unknown_token: 0}\n    self._support_reverse = support_reverse\n    if support_reverse:\n      self._reverse_mapping = [unknown_token]\n    self._freq = collections.defaultdict(int)\n    self._freeze = False\n\n  def __len__(self):\n    """Returns total count of mappings. Including unknown token."""\n    return len(self._mapping)\n\n  def freeze(self, freeze=True):\n    """Freezes the vocabulary, after which new words return unknown token id.\n\n    Args:\n      freeze: True to freeze, False to unfreeze.\n    """\n    self._freeze = freeze\n\n  def get(self, category):\n    """Returns word\'s id in the vocabulary.\n\n    If category is new, creates a new id for it.\n\n    Args:\n      category: string or integer to lookup in vocabulary.\n\n    Returns:\n      interger, id in the vocabulary.\n    """\n    if category not in self._mapping:\n      if self._freeze:\n        return 0\n      self._mapping[category] = len(self._mapping)\n      if self._support_reverse:\n        self._reverse_mapping.append(category)\n    return self._mapping[category]\n\n  def add(self, category, count=1):\n    """Adds count of the category to the frequency table.\n\n    Args:\n      category: string or integer, category to add frequency to.\n      count: optional integer, how many to add.\n    """\n    category_id = self.get(category)\n    if category_id <= 0:\n      return\n    self._freq[category] += count\n\n  def trim(self, min_frequency, max_frequency=-1):\n    """Trims vocabulary for minimum frequency.\n\n    Remaps ids from 1..n in sort frequency order.\n    where n - number of elements left.\n\n    Args:\n      min_frequency: minimum frequency to keep.\n      max_frequency: optional, maximum frequency to keep.\n        Useful to remove very frequent categories (like stop words).\n    """\n    # Sort by alphabet then reversed frequency.\n    self._freq = sorted(\n        sorted(\n            six.iteritems(self._freq),\n            key=lambda x: (isinstance(x[0], str), x[0])),\n        key=lambda x: x[1],\n        reverse=True)\n    self._mapping = {self._unknown_token: 0}\n    if self._support_reverse:\n      self._reverse_mapping = [self._unknown_token]\n    idx = 1\n    for category, count in self._freq:\n      if max_frequency > 0 and count >= max_frequency:\n        continue\n      if count <= min_frequency:\n        break\n      self._mapping[category] = idx\n      idx += 1\n      if self._support_reverse:\n        self._reverse_mapping.append(category)\n    self._freq = dict(self._freq[:idx - 1])\n\n  def reverse(self, class_id):\n    """Given class id reverse to original class name.\n\n    Args:\n      class_id: I ...

# %%
! python train.py
# Out:
# Parameters:
# ALLOW_SOFT_PLACEMENT=<absl.flags._flag.BooleanFlag object at 0x7f3fd4954710>
# ALSOLOGTOSTDERR=<absl.flags._flag.BooleanFlag object at 0x7f3fe8f2f390>
# BATCH_SIZE=<absl.flags._flag.Flag object at 0x7f3fd4954470>
# CHECKPOINT_EVERY=<absl.flags._flag.Flag object at 0x7f3fd49546d8>
# CLASS_DATA_FILE=<absl.flags._flag.Flag object at 0x7f3fd49549b0>
# DEV_DATA_FILE=<absl.flags._flag.Flag object at 0x7f3fd4954940>
# DROPOUT_KEEP_PROB=<absl.flags._flag.Flag object at 0x7f3fd4954390>
# EMBEDDING_DIM=<absl.flags._flag.Flag object at 0x7f40283b8160>
# EVALUATE_EVERY=<absl.flags._flag.Flag object at 0x7f3fd4954630>
# FILTER_SIZES=<absl.flags._flag.Flag object at 0x7f3fd4940eb8>
# L2_REG_LAMBDA=<absl.flags._flag.Flag object at 0x7f3fd4954438>
# LOG_DEVICE_PLACEMENT=<absl.flags._flag.BooleanFlag object at 0x7f3fd49547b8>
# LOG_DIR=<absl.flags._flag.Flag object at 0x7f3fe8f2f438>
# LOGTOSTDERR=<absl.flags._flag.BooleanFlag object at 0x7f3fe8f1ffd0>
# NUM_EPOCHS=<absl.flags._flag.Flag object at 0x7f3fd4954588>
# NUM_FILTERS=<absl.flags._flag.Flag object at 0x7f3fd4954208>
# ONLY_CHECK_ARGS=<absl.flags._flag.BooleanFlag object at 0x7f3fe8f2fc18>
# OP_CONVERSION_FALLBACK_TO_WHILE_LOOP=<absl.flags._flag.BooleanFlag object at 0x7f3fe69e4978>
# PDB_POST_MORTEM=<absl.flags._flag.BooleanFlag object at 0x7f3fe944e518>
# PROFILE_FILE=<absl.flags._flag.Flag object at 0x7f3fe8f2fb70>
# RUN_WITH_PDB=<absl.flags._flag.BooleanFlag object at 0x7f3fe944e320>
# RUN_WITH_PROFILING=<absl.flags._flag.BooleanFlag object at 0x7f3fe8f2fac8>
# SHOWPREFIXFORINFO=<absl.flags._flag.BooleanFlag object at 0x7f3fe8f2f6a0>
# STDERRTHRESHOLD=<absl.logging._StderrthresholdFlag object at 0x7f3fe8f2f588>
# TEST_RANDOM_SEED=<absl.flags._flag.Flag object at 0x7f3fdda8b198>
# TEST_RANDOMIZE_ORDERING_SEED=<absl.flags._flag.Flag object at 0x7f3fdda14278>
# TEST_SRCDIR=<absl.flags._flag.Flag object at 0x7f3fdda8b2e8>
# TEST_TMPDIR=<absl.flags._flag.Flag object at 0x7f3fdda8b4e0>
# TRAIN_DATA_FILE=<absl.flags._flag.Flag object at 0x7f3fd49548d0>
# USE_CPROFILE_FOR_PROFILING=<absl.flags._flag.BooleanFlag object at 0x7f3fe8f2fba8>
# V=<absl.logging._VerbosityFlag object at 0x7f3fe8f2f4a8>
# VERBOSITY=<absl.logging._VerbosityFlag object at 0x7f3fe8f2f4a8>
# XML_OUTPUT_FILE=<absl.flags._flag.Flag object at 0x7f3fdda14c18>
#
# Loading data...
# Vocabulary Size: 79662
# Train/Dev split: 34498/6566
# WARNING:tensorflow:From train.py:62: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:65: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03
I tensorflow/core/common_runtime/bfc_allocator.cc:914]      Summary of in-use Chunks by size:
# 2020-03-24 11:04:36.326760: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 38 Chunks of size 256 totalling 9.5KiB
# 2020-03-24 11:04:36.326773: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 13 Chunks of size 512 totalling 6.5KiB
# 2020-03-24 11:04:36.326784: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 1280 totalling 1.2KiB
# 2020-03-24 11:04:36.326796: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 5 Chunks of size 7680 totalling 37.5KiB
# 2020-03-24 11:04:36.326807: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 52736 totalling 51.5KiB
# 2020-03-24 11:04:36.326818: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 131328 totalling 128.2KiB
# 2020-03-24 11:04:36.326827: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 4 Chunks of size 196608 totalling 768.0KiB
# 2020-03-24 11:04:36.326837: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 4 Chunks of size 262144 totalling 1.00MiB
# 2020-03-24 11:04:36.326846: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 2 Chunks of size 327680 totalling 640.0KiB
# 2020-03-24 11:04:36.326856: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 578304 totalling 564.8KiB
# 2020-03-24 11:04:36.326867: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 626688 totalling 612.0KiB
# 2020-03-24 11:04:36.326878: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 8148983808 totalling 7.59GiB
# 2020-03-24 11:04:36.326888: I tensorflow/core/common_runtime/bfc_allocator.cc:921] Sum Total of in-use chunks: 7.59GiB
# 2020-03-24 11:04:36.326898: I tensorflow/core/common_runtime/bfc_allocator.cc:923] total_region_allocated_bytes_: 9134145536 memory_limit_: 15956161332 available bytes: 6822015796 curr_region_allocation_bytes_: 8589934592
# 2020-03-24 11:04:36.326913: I tensorflow/core/common_runtime/bfc_allocator.cc:929] Stats:
# Limit:                 15956161332
# InUse:                  8152919296
# MaxInUse:               8152919296
# NumAllocs:                   11693
# MaxAllocSize:           8148983808
#
# 2020-03-24 11:04:36.326931: W tensorflow/core/common_runtime/bfc_allocator.cc:424] ******************************************************************************************_________*
# 2020-03-24 11:04:36.326979: W tensorflow/core/framework/op_kernel.cc:1651] OP_REQUIRES failed at conv_ops.cc:500 : Resource exhausted: OOM when allocating tensor with shape[6566,128,2420,1] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# Traceback (most recent call last):
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py", line 1365, in _do_call
#     return fn(*args)
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py", line 1350, in _run_fn
#     target_list, run_metadata)
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py", line 1443, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted: OOM when allocating tensor with shape[6566,128,2422,1] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node conv-maxpool-3/conv}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[accuracy/accuracy/_127]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#   (1) Resource exhausted: OOM when allocating tensor with shape[6566,128,2422,1] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node conv-maxpool-3/conv}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 0 successful operations.
# 0 derived errors ignored.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "train.py", line 169, in <module>
#     dev_step(x_dev, y_dev, writer=dev_summary_writer)
#   File "train.py", line 153, in dev_step
#     feed_dict)
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py", line 956, in run
#     run_metadata_ptr)
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py", line 1180, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py", line 1359, in _do_run
#     run_metadata)
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py", line 1384, in _do_call
#     raise type(e)(node_def, op, message)
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted: OOM when allocating tensor with shape[6566,128,2422,1] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node conv-maxpool-3/conv (defined at /tensorflow-1.15.0/python3.6/tensorflow_core/python/framework/ops.py:1748) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[accuracy/accuracy/_127]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#   (1) Resource exhausted: OOM when allocating tensor with shape[6566,128,2422,1] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node conv-maxpool-3/conv (defined at /tensorflow-1.15.0/python3.6/tensorflow_core/python/framework/ops.py:1748) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 0 successful operations.
# 0 derived errors ignored.
#
# Original stack trace for 'conv-maxpool-3/conv':
#   File "train.py", line 74, in <module>
#     l2_reg_lambda=FLAGS.l2_reg_lambda)
#   File "/content/drive/My Drive/fininsight/21대 총선분석/Text Classification/TextCNN/cnn-text-classification-tf/text_cnn.py", line 43, in __init__
#     name="conv")
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/nn_ops.py", line 2010, in conv2d
#     name=name)
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/gen_nn_ops.py", line 1071, in conv2d
#     data_format=data_format, dilations=dilations, name=name)
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/framework/op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/framework/ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/framework/ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/framework/ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()

# %%
! python eval.py
# Out:
# Parameters:
# ALLOW_SOFT_PLACEMENT=<absl.flags._flag.BooleanFlag object at 0x7f94c441d198>
# ALSOLOGTOSTDERR=<absl.flags._flag.BooleanFlag object at 0x7f94d87f3a20>
# BATCH_SIZE=<absl.flags._flag.Flag object at 0x7f9517ded5f8>
# CHECKPOINT_DIR=<absl.flags._flag.Flag object at 0x7f94c4409da0>
# CLASS_DATA_FILE=<absl.flags._flag.Flag object at 0x7f94c441d438>
# DEV_DATA_FILE=<absl.flags._flag.Flag object at 0x7f94c441d358>
# EVAL_TRAIN=<absl.flags._flag.BooleanFlag object at 0x7f94c441d048>
# LOG_DEVICE_PLACEMENT=<absl.flags._flag.BooleanFlag object at 0x7f94c441d240>
# LOG_DIR=<absl.flags._flag.Flag object at 0x7f94d87f3ac8>
# LOGTOSTDERR=<absl.flags._flag.BooleanFlag object at 0x7f94d87ea6a0>
# ONLY_CHECK_ARGS=<absl.flags._flag.BooleanFlag object at 0x7f94d87fc2e8>
# OP_CONVERSION_FALLBACK_TO_WHILE_LOOP=<absl.flags._flag.BooleanFlag object at 0x7f94d64ad8d0>
# PDB_POST_MORTEM=<absl.flags._flag.BooleanFlag object at 0x7f94d8d0db38>
# PROFILE_FILE=<absl.flags._flag.Flag object at 0x7f94d87fc240>
# RUN_WITH_PDB=<absl.flags._flag.BooleanFlag object at 0x7f94d8d0d940>
# RUN_WITH_PROFILING=<absl.flags._flag.BooleanFlag object at 0x7f94d87fc198>
# SHOWPREFIXFORINFO=<absl.flags._flag.BooleanFlag object at 0x7f94d87f3d30>
# STDERRTHRESHOLD=<absl.logging._StderrthresholdFlag object at 0x7f94d87f3c18>
# TEST_RANDOM_SEED=<absl.flags._flag.Flag object at 0x7f94cd553128>
# TEST_RANDOMIZE_ORDERING_SEED=<absl.flags._flag.Flag object at 0x7f94cd4dc208>
# TEST_SRCDIR=<absl.flags._flag.Flag object at 0x7f94cd553278>
# TEST_TMPDIR=<absl.flags._flag.Flag object at 0x7f94cd553470>
# TRAIN_DATA_FILE=<absl.flags._flag.Flag object at 0x7f94c441d3c8>
# USE_CPROFILE_FOR_PROFILING=<absl.flags._flag.BooleanFlag object at 0x7f94d87fc278>
# V=<absl.logging._VerbosityFlag object at 0x7f94d87f3b38>
# VERBOSITY=<absl.logging._VerbosityFlag object at 0x7f94d87f3b38>
# XML_OUTPUT_FILE=<absl.flags._flag.Flag object at 0x7f94cd4dcba8>
#
#
# Evaluating...
#
# WARNING:tensorflow:From eval.py:62: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From eval.py:65: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-24 10:57:01.737561: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-03-24 10:57:01.737915: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2984bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-24 10:57:01.737953: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-24 10:57:01.739884: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-24 10:57:01.852664: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-24 10:57:01.853797: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2984d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-24 10:57:01.853858: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-03-24 10:57:01.854120: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-24 10:57:01.855234: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-24 10:57:01.855618: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-24 10:57:01.857640: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-24 10:57:01.859465: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-24 10:57:01.859871: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-24 10:57:01.861615: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-24 10:57:01.862434: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-24 10:57:01.866189: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-24 10:57:01.866311: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-24 10:57:01.867183: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-24 10:57:01.867979: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-24 10:57:01.868037: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-24 10:57:01.869281: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-24 10:57:01.869308: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-24 10:57:01.869317: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-24 10:57:01.869425: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-24 10:57:01.870246: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-24 10:57:01.870994: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-03-24 10:57:01.871035: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From eval.py:68: The name tf.train.import_meta_graph is deprecated. Please use tf.compat.v1.train.import_meta_graph instead.
#
# Traceback (most recent call last):
#   File "eval.py", line 68, in <module>
#     saver = tf.train.import_meta_graph("{}.meta".format(checkpoint_file))
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/training/saver.py", line 1453, in import_meta_graph
#     **kwargs)[0]
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/training/saver.py", line 1467, in _import_meta_graph_with_return_elements
#     meta_graph_def = meta_graph.read_meta_graph_file(meta_graph_or_file)
#   File "/tensorflow-1.15.0/python3.6/tensorflow_core/python/framework/meta_graph.py", line 636, in read_meta_graph_file
#     raise IOError("File %s does not exist." % filename)
# OSError: File None.meta does not exist.

# %%
import pandas as pd
pd.read_csv('prediction.csv')
