# %%
modelpath = "../../model/"
filepath = "../../data/"
category = "정치"

# %%
import pickle
from konlpy.tag import Mecab
import pandas as pd
import unicodedata

def generate_dict_from_WPM(modelpath, modelname) :
    def combine_tokens(tokens, pos = "NNP") :
        return ''.join([t[0] for t in tokens]), pos
    
    filename = "{}{}-vocab.txt".format(modelpath, modelname)
    vocabs = open(filename, 'r') .read().split('\n')
    vocabs = [unicodedata.normalize('NFC',vocab.replace("##","")) for vocab in vocabs]

    mecab = Mecab()
    words = []
    dic = []

    for vocab in vocabs :    
        word = pos = ""
        tokens = mecab.pos(vocab)

        if len(tokens) == 1 : #기존 Mecab 사전에 등록되어있는 경우 제외
            continue
        elif len(tokens) >1 : #기존 Mecab 사전에 등록되어있지 않은 경우
            pos_list = [t[1][0] for t in tokens]
            if ('SY' in [t[1] for t in tokens]) | ('UNKNOWN' in [t[1] for t in tokens]) :
                continue
            elif "의" in vocab[-1] : # "~의" 경우 처리
                if vocab[-2:] in ["들의", "과의", "와의"] :
                    tokens = mecab.pos(vocab[:-2])
                    vocab = vocab[:-2]
                elif vocab[-2:] == "주주의" :
                    tokens = mecab.pos(vocab[:-1])
                    vocab = vocab[:-1]
                elif vocab[-2:] == "회의" :
                    word, pos = combine_tokens(tokens)         
                else :
                    tokens = mecab.pos(vocab[:-1])
                    if (len(tokens) == 1) : #Mecab에 이미 등록되어있는 사전 제외
                        continue
            elif list(set(pos_list)) == ["N"] : #사전에서 분리한 토큰 목록이 전부 명사이면 복합명사로 판단
                pass     
            elif (tokens[-1][1] in ["NNG", "NNP"]) : #마지막 토큰이 명사인 경우 복합명사로 판단
                pos = tokens[-1][1]
            elif ('N' in pos_list ) & (len(pos_list) > 3) : #토큰 중 하나이상이 명사이고 
                continue
            elif 'N' not in pos_list : #명사중 토큰이 하나도 없는 경우
                continue    
            else :            
                continue 

            word, pos = combine_tokens(tokens)
            if (len(word) > 0) & (word not in words) :
                words.append(word)
                dic.append(((word, pos), tokens))
    return dic

# %%
import collections
from itertools import takewhile
from collections import defaultdict

def generate_dict_by_category(modelpath, categories=['정치', '경제', '사회', 'IT과학', '생활문화']) :
    compound_dict = defaultdict()
    for cate in categories :
        compound_dict[cate] = generate_dict_from_WPM(modelpath, cate)
        
    vocabs_total = [v[0] for k in compound_dict.keys() for v in compound_dict[k]]
    counter = collections.Counter(vocabs_total) #ngram을 빈도별로 집계
    stopwords = dict(takewhile(lambda i: i[1] == len(compound_dict.keys()), counter.most_common())) #빈도 cutoff 이상 ngram 추출
    stopwords = [k for k in stopwords.keys()]
    
    for cate in categories :
        compound_dict[cate] = [w for w in compound_dict[cate] if w[0] not in stopwords]
        
    pickle_out = open("{}compound_dict.pickle".format(modelpath),"wb")
    pickle.dump(compound_dict, pickle_out)
    pickle_out.close()
    
    return vocabs

compound_dict = generate_dict_by_category(modelpath)

# %%
import pickle

pickle_in = open("{}compound_dict.pickle".format(modelpath),"rb")
compound_dict = pickle.load(pickle_in)
compound_dict
# Out:
# defaultdict(None,
#             {'정치': [(('한국당', 'NNP'), [('한국', 'NNP'), ('당', 'NNG')]),
#               (('바른미래', 'NNP'), [('바른', 'VA+ETM'), ('미래', 'NNG')]),
#               (('사일', 'NNP'), [('사', 'NR'), ('일', 'NNBC')]),
#               (('최고위원', 'NNP'), [('최고', 'NNG'), ('위원', 'NNG')]),
#               (('패스트트랙', 'NNP'), [('패스트', 'NNP'), ('트랙', 'NNG')]),
#               (('미더뉴스', 'NNP'), [('미', 'NNG'), ('더', 'MAG'), ('뉴스', 'NNG')]),
#               (('공수처', 'NNP'), [('공', 'NNG'), ('수처', 'NNG')]),
#               (('인사청', 'NNP'), [('인사', 'NNG'), ('청', 'NNG')]),
#               (('민주평화', 'NNP'), [('민주', 'NNG'), ('평화', 'NNG')]),
#               (('한국당은', 'NNP'), [('한국', 'NNP'), ('당은', 'NNP+JX')]),
#               (('컷뉴스', 'NNP'), [('컷', 'NNG'), ('뉴스', 'NNG')]),
#               (('지소미아', 'NNP'), [('지소', 'NNG'), ('미아', 'NNG')]),
#               (('주가시', 'NNP'), [('주가', 'NNG'), ('시', 'NNG')]),
#               (('모두발언', 'NNP'), [('모두', 'MAG'), ('발언', 'NNG')]),
#               (('검찰개혁', 'NNP'), [('검찰', 'NNG'), ('개혁', 'NNG')]),
#               (('의원회', 'NNP'), [('의원', 'NNG'), ('회', 'NNG')]),
#               (('비례대표', 'NNP'), [('비례', 'NNG'), ('대표', 'NNG')]),
#               (('인사청문회', 'NNP'), [('인사', 'NNG'), ('청문회', 'NNG')]),
#               (('북미정상회담', 'NNP'),
#                [('북미', 'NNP'), ('정상', 'NNG'), ('회담', 'NNG')]),
#               (('의원총', 'NNP'), [('의원', 'NNG'), ('총', 'NNG')]),
#               (('국가안보', 'NNP'), [('국가', 'NNG'), ('안보', 'NNG')]),
#               (('특별위원회', 'NNP'), [('특별', 'NNG'), ('위원회', 'NNG')]),
#               (('홈페이', 'NNP'), [('홈', 'NNG'), ('페이', 'NNP')]),
#               (('근혜', 'NNP'), [('근', 'MM'), ('혜', 'NNG')]),
#               (('인사청문', 'NNP'), [('인사', 'NNG'), ('청문', 'NNG')]),
#               (('정안전', 'NNP'), [('정안', 'NNG'), ('전', 'NNG')]),
#               (('국무위원장', 'NNP'), [('국무', 'NNG'), ('위원장', 'NNG')]),
#               (('개특위', 'NNP'), [('개', 'NNG'), ('특위', 'NNG')]),
#               (('민정수석', 'NNP'), [('민정', 'NNG'), ('수석', 'NNG')]),
#               (('조선중앙', 'NNP'), [('조선', 'NNP'), ('중앙', 'NNG')]),
#               (('섭단체', 'NNP'), [('섭', 'NNG'), ('단체', 'NNG')]),
#               (('도미사일', 'NNP'), [('도', 'JX'), ('미사일', 'NNG')]),
#               (('수출규제', 'NNP'), [('수출', 'NNG'), ('규제', 'NNG')]),
#               (('주한미', 'NNP'), [('주한', 'NNG'), ('미', 'NNG')]),
#               (('실무협상', 'NNP'), [('실무', 'NNG'), ('협상', 'NNG')]),
#               (('사법개혁', 'NNP'), [('사법', 'NNG'), ('개혁', 'NNG')]),
#               (('고위공직자', 'NNP'), [('고위', 'NNG'), ('공직자', 'NNG')]),
#               (('정책위', 'NNP'), [('정책', 'NNG'), ('위', 'NNG')]),
#               (('신속처리', 'NNP'), [('신속', 'NNG'), ('처리', 'NNG')]),
#               (('페이오', 'NNP'), [('페이', 'NNP'), ('오', 'NNP')]),
#               (('주한미군', 'NNP'), [('주한', 'NNG'), ('미군', 'NNG')]),
#               (('정상회의', 'NNP'), [('정상', 'NNG'), ('회의', 'NNG')]),
#               (('산업통', 'NNP'), [('산업', 'NNG'), ('통', 'NNG')]),
#               (('북핵', 'NNP'), [('북', 'NNP'), ('핵', 'NNG')]),
#               (('의원', 'NNP'), [('의원', 'NNG')]),
#               (('수수색', 'NNP'), [('수수', 'NNG'), ('색', 'NNG')]),
#               (('상자원', 'NNP'), [('상', 'NNG'), ('자원', 'NNG')]),
#               (('필리버스터', 'NNP'), [('필리', 'NNP'), ('버스터', 'NNP')]),
#               (('원내대책', 'NNP'), [('원내', 'NNG'), ('대책', 'NNG')]),
#               (('당대표', 'NNP'), [('당', 'NNG'), ('대표', 'NNG')]),
#               (('승민', 'NNP'), [('승', 'NNG'), ('민', 'NNG')]),
#               (('국회의장', 'NNP'), [('국회', 'NNG'), ('의장', 'NNG')]),
#               (('신속처리안건', 'NNP'),
#                [('신속', 'NNG'), ('처리', 'NNG'), ('안건', 'NNG')]),
#               (('마이뉴스', 'NNP'), [('마이', 'MAG'), ('뉴스', 'NNG')]),
#               (('공수처법', 'NNP'), [('공', 'NNG'), ('수처', 'NNG'), ('법', 'NNG')]),
#               (('고승민', 'NNP'), [('고승', 'NNP'), ('민', 'NNP')]),
#               (('남북관계', 'NNP'), [('남북', 'NNP'), ('관계', 'NNG')]),
#               (('법제사법', 'NNP'), [('법제', 'NNG'), ('사법', 'NNG')]),
#               (('대북제재', 'NNP'), [('대북', 'NNG'), ('제재', 'NNG')]),
#               (('3당', 'NNP'), [('3', 'SN'), ('당', 'NNG')]),
#               (('로벌', 'NNP'), [('로', 'JKB'), ('벌', 'NNG')]),
#               (('정보보호', 'NNP'), [('정보', 'NNG'), ('보호', 'NNG')]),
#               (('탄도미사일', 'NNP'), [('탄도', 'NNG'), ('미사일', 'NNG')]),
#               (('강제징용', 'NNP'), [('강제', 'NNG'), ('징용', 'NNG')]),
#               (('비공개', 'NNP'), [('비', 'XPN'), ('공개', 'NNG')]),
#               (('에어파', 'NNP'), [('에', 'IC'), ('어파', 'NNG')]),
#               (('노동신문', 'NNP'), [('노동', 'NNG'), ('신문', 'NNG')]),
#               (('조선중앙통신', 'NNP'),
#                [('조선', 'NNP'), ('중앙', 'NNG'), ('통신', 'NNG')]),
#               (('수사처', 'NNP'), [('수사', 'NNG'), ('처', 'NNG')]),
#               (('한미동맹', 'NNP'), [('한미', 'NNG'), ('동맹', 'NNG')]),
#               (('싱가포', 'NNP'), [('싱', 'NNP'), ('가포', 'NNG')]),
#               (('과학기술정보', 'NNP'),
#                [('과학', 'NNG'), ('기술', 'NNG'), ('정보', 'NNG')]),
#               (('스냅타임', 'NNP'), [('스냅', 'NNG'), ('타임', 'NNG')]),
#               (('청춘뉘', 'NNP'), [('청춘', 'NNG'), ('뉘', 'NNG')]),
#               (('말씀드', 'NNP'), [('말씀', 'NNG'), ('드', 'NNG')]),
#               (('여론조사', 'NNP'), [('여론', 'NNG'), ('조사', 'NNG')]),
#               (('개성공단', 'NNP'), [('개성', 'NNG'), ('공단', 'NNG')]),
#               (('홍준', 'NNP'), [('홍', 'NNP'), ('준', 'NNP')]),
#               (('정치개혁', 'NNP'), [('정치', 'NNG'), ('개혁', 'NNG')]),
#               (('협의체', 'NNP'), [('협의', 'NNG'), ('체', 'NNG')]),
#               (('림픽', 'NNP'), [('림', 'NNG'), ('픽', 'NNG')]),
#               (('정보보호협정', 'NNP'),
#                [('정보', 'NNG'), ('보호', 'NNG'), ('협정', 'NNG')]),
#               (('5당', 'NNP'), [('5', 'SN'), ('당', 'NNG')]),
#               (('경제부총리', 'NNP'), [('경제', 'NNG'), ('부총리', 'NNG')]),
#               (('대정부', 'NNP'), [('대', 'XPN'), ('정부', 'NNG')]),
#               (('국방장관', 'NNP'), [('국방', 'NNG'), ('장관', 'NNG')]),
#               (('특별대표', 'NNP'), [('특별', 'NNG'), ('대표', 'NNG')]),
#               (('오마이뉴스', 'NNP'), [('오마이', 'NNG'), ('뉴스', 'NNG')]),
#               (('무단복제', 'NNP'), [('무단', 'NNG'), ('복제', 'NNG')]),
#               (('법무부장관', 'NNP'), [('법무부', 'NNG'), ('장관', 'NNG')]),
#               (('궐선거', 'NNP'), [('궐선', 'NNP'), ('거', 'NNB')]),
#               (('향신문', 'NNP'), [('향신', 'NNG'), ('문', 'NNG')]),
#               (('문화체육', 'NNP'), [('문화', 'NNG'), ('체육', 'NNG')]),
#               (('외교장관', 'NNP'), [('외교', 'NNG'), ('장관', 'NNG')]),
#               (('화이트리스트', 'NNP'), [('화이트', 'NNP'), ('리스트', 'NNP')]),
#               (('경제보복', 'NNP'), [('경제', 'NNG'), ('보복', 'NNG')]),
#               (('무소속', 'NNP'), [('무', 'XPN'), ('소속', 'NNG')]),
#               (('전당대회', 'NNP'), [('전당', 'NNG'), ('대회', 'NNG')]),
#               (('비서실장', 'NNP'), [('비서', 'NNG'), ('실장', 'NNG')]),
#               (('사개특위', 'NNP'), [('사개', 'NNG'), ('특위', 'NNG')]),
#               (('보궐선거', 'NNP'), [('보궐', 'NNG'), ('선거', 'NNG')]),
#               (('공직선거', 'NNP'), [('공직', 'NNG'), ('선거', 'NNG')]),
#               (('렌드', 'NNP'), [('렌', 'NNG'), ('드', 'NNG')]),
#               (('mbc뉴스', 'NNP'), [('mbc', 'SL'), ('뉴스', 'NNG')]),
#               (('정무수석', 'NNP'), [('정무', 'NNG'), ('수석', 'NNG')]),
#               (('제1야', 'NNP'), [('제', 'XPN'), ('1', 'SN'), ('야', 'NNG')]),
#               (('대안신', 'NNP'), [('대안', 'NNG'), ('신', 'NNG')]),
#               (('임시국회', 'NNP'), [('임시', 'NNG'), ('국회', 'NNG')]),
#               (('김원장', 'NNP'), [('김', 'NNP'), ('원장', 'NNG')]),
#               (('전체회의', 'NNP'), [('전체', 'NNG'), ('회의', 'NNG')]),
#               (('범죄수사처', 'NNP'), [('범죄', 'NNG'), ('수사', 'NNG'), ('처', 'NNG')]),
#               (('대북정책', 'NNP'), [('대북', 'NNG'), ('정책', 'NNG')]),
#               (('고위공직자범죄수사처', 'NNP'),
#                [('고위', 'NNG'),
#                 ('공직자', 'NNG'),
#                 ('범죄', 'NNG'),
#                 ('수사', 'NNG'),
#                 ('처', 'NNG')]),
#               (('헌법재판', 'NNP'), [('헌법', 'NNG'), ('재판', 'NNG')]),
#               (('친박', 'NNP'), [('친', 'NNP'), ('박', 'NNP')]),
#               (('세월호', 'NNP'), [('세월', 'NNG'), ('호', 'NNG')]),
#               (('훈처', 'NNP'), [('훈', 'NNG'), ('처', 'NNG')]),
#               (('중소벤처기업부', 'NNP'),
#                [('중소', 'NNG'), ('벤처', 'NNG'), ('기업', 'NNG'), ('부', 'NNG')]),
#               (('부위원장', 'NNP'), [('부', 'XPN'), ('위원장', 'NNG')]),
#               (('검찰총장', 'NNP'), [('검찰', 'NNG'), ('총장', 'NNG')]),
#               (('공직선거법', 'NNP'), [('공직', 'NNG'), ('선거법', 'NNG')]),
#               (('과학기술정보통신', 'NNP'),
#                [('과학', 'NNG'), ('기술', 'NNG'), ('정보', 'NNG'), ('통신', 'NNG')]),
#               (('한미일', 'NNP'), [('한', 'MM'), ('미일', 'NNG')]),
#               (('검찰총', 'NNP'), [('검찰', 'NNG'), ('총', 'NNG')]),
#               (('엠비', 'NNP'), [('엠', 'NNG'), ('비', 'NNG')]),
#               (('대안신당', 'NNP'), [('대안', 'NNG'), ('신', 'XPN'), ('당', 'NNG')]),
#               (('엠빅', 'NNP'), [('엠', 'NNG'), ('빅', 'NNG')]),
#               (('부적절', 'NNP'), [('부적', 'NNG'), ('절', 'NNG')]),
#               (('대정부질', 'NNP'), [('대정', 'NNG'), ('부질', 'NNG')]),
#               (('울산시', 'NNP'), [('울산', 'NNP'), ('시', 'NNG')]),
#               (('국무장관', 'NNP'), [('국무', 'NNG'), ('장관', 'NNG')]),
#               (('재확인', 'NNP'), [('재', 'XPN'), ('확인', 'NNG')]),
#               (('비상대책', 'NNP'), [('비상', 'NNG'), ('대책', 'NNG')]),
#               (('국가주석', 'NNP'), [('국가', 'NNG'), ('주석', 'NNG')]),
#               (('법제사법위원회', 'NNP'),
#                [('법제', 'NNG'), ('사법', 'NNG'), ('위원회', 'NNG')]),
#               (('f포럼', 'NNP'), [('f', 'SL'), ('포럼', 'NNG')]),
#               (('진상규', 'NNP'), [('진상', 'NNG'), ('규', 'NNG')]),
#               (('특별정상회의', 'NNP'),
#                [('특별', 'NNG'), ('정상', 'NNG'), ('회의', 'NNG')]),
#               (('예산결산', 'NNP'), [('예산', 'NNG'), ('결산', 'NNG')]),
#               (('부대표', 'NNP'), [('부', 'XPN'), ('대표', 'NNG')]),
#               (('선거제도', 'NNP'), [('선거', 'NNG'), ('제도', 'NNG')]),
#               (('국정감사', 'NNP'), [('국정', 'NNG'), ('감사', 'NNG')]),
#               (('사모펀드', 'NNP'), [('사모', 'NNG'), ('펀드', 'NNG')]),
#               (('블라디보', 'NNP'), [('블라', 'NNP'), ('디보', 'NNP')]),
#               (('지방선거', 'NNP'), [('지방', 'NNG'), ('선거', 'NNG')]),
#               (('박항', 'NNP'), [('박', 'NNP'), ('항', 'NNG')]),
#               (('법사위', 'NNP'), [('법', 'NNG'), ('사위', 'NNG')]),
#               (('외교통일', 'NNP'), [('외교', 'NNG'), ('통일', 'NNG')]),
#               (('바른정당', 'NNP'), [('바른', 'VA+ETM'), ('정당', 'NNG')]),
#               (('블라디보스토크', 'NNP'), [('블라디', 'NNP'), ('보스토크', 'NNG')]),
#               (('훈식', 'NNP'), [('훈', 'NNG'), ('식', 'NNB')]),
#               (('지방자치', 'NNP'), [('지방', 'NNG'), ('자치', 'NNG')]),
#               (('1심', 'NNP'), [('1', 'SN'), ('심', 'NNG')]),
#               (('한국당과', 'NNP'), [('한국', 'NNP'), ('당과', 'NNG')]),
#               (('김의겸', 'NNP'), [('김', 'NNP'), ('의', 'JKG'), ('겸', 'NNG')]),
#               (('핵시설', 'NNP'), [('핵', 'NNG'), ('시설', 'NNG')]),
#               (('추가경정', 'NNP'), [('추가', 'NNG'), ('경정', 'NNG')]),
#               (('한미연합', 'NNP'), [('한미', 'NNG'), ('연합', 'NNG')]),
#               (('방정책', 'NNP'), [('방정', 'NNG'), ('책', 'NNG')]),
#               (('최고위원회의', 'NNP'),
#                [('최고', 'NNG'), ('위원', 'NNG'), ('회의', 'NNG')]),
#               (('소득주도', 'NNP'), [('소득', 'NNG'), ('주도', 'NNG')]),
#               (('한일관계', 'NNP'), [('한', 'MM'), ('일', 'NR'), ('관계', 'NNG')]),
#               (('의원실', 'NNP'), [('의원', 'NNG'), ('실', 'NNG')]),
#               (('홍봉진', 'NNP'), [('홍', 'NNG'), ('봉진', 'NNG')]),
#               (('남북정상회담', 'NNP'),
#                [('남북', 'NNP'), ('정상', 'NNG'), ('회담', 'NNG')]),
#               (('탈북', 'NNP'), [('탈', 'XPN'), ('북', 'NNG')]),
#               (('경제정책', 'NNP'), [('경제', 'NNG'), ('정책', 'NNG')]),
#               (('농림축산', 'NNP'), [('농림', 'NNG'), ('축산', 'NNG')]),
#               (('최고인민', 'NNP'), [('최고', 'NNG'), ('인민', 'NNG')]),
#               (('국무회의', 'NNP'), [('국무', 'NNG'), ('회의', 'NNG')]),
#               (('3국', 'NNP'), [('3', 'SN'), ('국', 'NNG')]),
#               (('우리공화', 'NNP'), [('우리', 'NP'), ('공화', 'NNG')]),
#               (('중앙선거', 'NNP'), [('중앙', 'NNG'), ('선거', 'NNG')]),
#               (('즈베', 'NNP'), [('즈', 'MM'), ('베', 'NNG')]),
#               (('엠빅뉴스', 'NNP'), [('엠', 'NNG'), ('빅뉴스', 'NNG')]),
#               (('농림축산식품', 'NNP'),
#                [('농림', 'NNG'), ('축산', 'NNG'), ('식품', 'NNG')]),
#               (('서울중앙지검', 'NNP'),
#                [('서울', 'NNP'), ('중앙지', 'NNG'), ('검', 'NNG')]),
#               (('동양대', 'NNP'), [('동양', 'NNG'), ('대', 'NNG')]),
#               (('취재단', 'NNP'), [('취', 'NNG'), ('재단', 'NNG')]),
#               (('교섭본부', 'NNP'), [('교섭', 'NNG'), ('본부', 'NNG')]),
#               (('군사정보보호협정', 'NNP'),
#                [('군사', 'NNG'), ('정보', 'NNG'), ('보호', 'NNG'), ('협정', 'NNG')]),
#               (('노무현재단', 'NNP'), [('노무현', 'NNP'), ('재단', 'NNG')]),
#               (('지열병', 'NNP'), [('지열', 'NNG'), ('병', 'NNG')]),
#               (('정책실', 'NNP'), [('정책', 'NNG'), ('실', 'NNG')]),
#               (('규직', 'NNP'), [('규', 'NNG'), ('직', 'NNG')]),
#               (('합동참모', 'NNP'), [('합동', 'NNG'), ('참모', 'NNG')]),
#               (('4당', 'NNP'), [('4', 'SN'), ('당', 'NNG')]),
#               (('정책위의장', 'NNP'), [('정책', 'NNG'), ('위', 'NNG'), ('의장', 'NNG')]),
#               (('국정조사', 'NNP'), [('국정', 'NNG'), ('조사', 'NNG')]),
#               (('mbn뉴스', 'NNP'), [('mbn', 'SL'), ('뉴스', 'NNG')]),
#               (('정기국회', 'NNP'), [('정기', 'NNG'), ('국회', 'NNG')]),
#               (('제1야당', 'NNP'), [('제', 'XPN'), ('1', 'SN'), ('야당', 'NNG')]),
#               (('민주화운동', 'NNP'), [('민주', 'NNG'), ('화', 'XSN'), ('운동', 'NNG')]),
#               (('대안정치', 'NNP'), [('대안', 'NNG'), ('정치', 'NNG')]),
#               (('원내수석', 'NNP'), [('원내', 'NNG'), ('수석', 'NNG')]),
#               (('친구추가', 'NNP'), [('친구', 'NNG'), ('추가', 'NNG')]),
#               (('남북미', 'NNP'), [('남북', 'NNP'), ('미', 'NNG')]),
#               (('국무위원', 'NNP'), [('국무', 'NNG'), ('위원', 'NNG')]),
#               (('문화체육관광부', 'NNP'),
#                [('문화', 'NNG'), ('체육관', 'NNG'), ('광부', 'NNG')]),
#               (('방위비분담', 'NNP'), [('방위비', 'NNG'), ('분담', 'NNG')]),
#               (('경제협력', 'NNP'), [('경제', 'NNG'), ('협력', 'NNG')]),
#               (('국제사회', 'NNP'), [('국제', 'NNG'), ('사회', 'NNG')]),
#               (('진상조사', 'NNP'), [('진상', 'NNG'), ('조사', 'NNG')]),
#               (('당정청', 'NNP'), [('당정', 'NNG'), ('청', 'NNG')]),
#               (('민주연구원', 'NNP'), [('민주', 'NNP'), ('연구원', 'NNG')]),
#               (('대문구', 'NNP'), [('대', 'XPN'), ('문구', 'NNG')]),
#               (('스톡홀', 'NNP'), [('스톡', 'NNP'), ('홀', 'NNP')]),
#               (('국민청', 'NNP'), [('국민', 'NNG'), ('청', 'NNG')]),
#               (('비무장지대', 'NNP'), [('비무장', 'NNG'), ('지대', 'NNG')]),
#               (('한반도평화', 'NNP'), [('한반도', 'NNP'), ('평화', 'NNG')]),
#               (('중진의원', 'NNP'), [('중진', 'NNG'), ('의원', 'NNG')]),
#               (('최고인민회의', 'NNP'),
#                [('최고', 'NNG'), ('인민', 'NNG'), ('회의', 'NNG')]),
#               (('민주노총', 'NNP'), [('민주', 'NNP'), ('노총', 'NNG')]),
#               (('의원회관', 'NNP'), [('의원', 'NNG'), ('회관', 'NNG')]),
#               (('취재대행', 'NNP'), [('취재', 'NNG'), ('대행', 'NNG')]),
#               (('국제사회의', 'NNP'), [('국제', 'NNG'), ('사', 'NR'), ('회의', 'NNG')]),
#               (('원내수석부대표', 'NNP'),
#                [('원', 'NNG'), ('내수', 'NNG'), ('석부', 'NNG'), ('대표', 'NNG')]),
#               (('국가정보', 'NNP'), [('국가', 'NNG'), ('정보', 'NNG')]),
#               (('국정농', 'NNP'), [('국정', 'NNG'), ('농', 'NNG')]),
#               (('드루킹', 'NNP'), [('드루', 'NNP'), ('킹', 'NNP')]),
#               (('예산결산특별위원회', 'NNP'),
#                [('예산', 'NNG'), ('결산', 'NNG'), ('특별', 'NNG'), ('위원회', 'NNG')]),
#               (('국빈방문', 'NNP'), [('국빈', 'NNG'), ('방문', 'NNG')]),
#               (('젝트', 'NNP'), [('젝', 'NNP'), ('트', 'NNG')]),
#               (('가짜뉴스', 'NNP'), [('가짜', 'NNG'), ('뉴스', 'NNG')]),
#               (('당권파', 'NNP'), [('당권', 'NNG'), ('파', 'NNG')]),
#               (('자유무역', 'NNP'), [('자유', 'NNG'), ('무역', 'NNG')]),
#               (('국무위원회', 'NNP'), [('국무', 'NNG'), ('위원회', 'NNG')]),
#               (('장외투쟁', 'NNP'), [('장외', 'NNG'), ('투쟁', 'NNG')]),
#               (('대북특별대표', 'NNP'),
#                [('대북', 'NNG'), ('특별', 'NNG'), ('대표', 'NNG')]),
#               (('법무장관', 'NNP'), [('법무', 'NNG'), ('장관', 'NNG')]),
#               (('종전선언', 'NNP'), [('종전', 'NNG'), ('선언', 'NNG')]),
#               (('전당대', 'NNP'), [('전', 'MM'), ('당대', 'NNG')]),
#               (('정책실장', 'NNP'), [('정책', 'NNG'), ('실장', 'NNG')]),
#               (('수석대변인', 'NNP'), [('수석', 'NNG'), ('대변인', 'NNG')]),
#               (('직권남용', 'NNP'), [('직권', 'NNG'), ('남용', 'NNG')]),
#               (('북한군', 'NNP'), [('북한', 'NNP'), ('군', 'NNG')]),
#               (('정치개혁특별위원회', 'NNP'),
#                [('정치', 'NNG'), ('개혁', 'NNG'), ('특별', 'NNG'), ('위원회', 'NNG')]),
#               (('대통령', 'NNP'), [('대통령', 'NNG')]),
#               (('비당권파', 'NNP'), [('비당', 'NNG'), ('권파', 'NNG')]),
#               (('유엔총', 'NNP'), [('유엔', 'NNP'), ('총', 'NNG')]),
#               (('백색국가', 'NNP'), [('백색', 'NNG'), ('국가', 'NNG')]),
#               (('돼지열병', 'NNP'), [('돼지', 'NNG'), ('열', 'NR'), ('병', 'NNG')]),
#               (('아프리카돼지열병', 'NNP'),
#                [('아프리카', 'NNP'), ('돼지', 'NNG'), ('열', 'NR'), ('병', 'NNG')]),
#               (('군사합', 'NNP'), [('군사', 'NNG'), ('합', 'NNG')]),
#               (('취재기자', 'NNP'), [('취재', 'NNG'), ('기자', 'NNG')]),
#               (('창원성산', 'NNP'), [('창원', 'NNP'), ('성산', 'NNG')]),
#               (('국가보훈처', 'NNP'), [('국가', 'NNG'), ('보훈', 'NNG'), ('처', 'NNG')]),
#               (('예결위', 'NNP'), [('예결', 'NNG'), ('위', 'NNG')]),
#               (('반부패', 'NNP'), [('반', 'NNG'), ('부패', 'NNG')]),
#               (('구속영', 'NNP'), [('구속', 'NNG'), ('영', 'NNG')]),
#               (('새누리', 'NNP'), [('새', 'MM'), ('누리', 'NNG')]),
#               (('물밑', 'NNP'), [('물', 'NNG'), ('밑', 'NNG')]),
#               (('인싸', 'NNP'), [('인', 'NNG'), ('싸', 'VV+EC')]),
#               (('당협', 'NNP'), [('당', 'NNG'), ('협', 'NNG')]),
#               (('부정평가', 'NNP'), [('부정', 'NNG'), ('평가', 'NNG')]),
#               (('3법', 'NNP'), [('3', 'SN'), ('법', 'NNG')]),
#               (('미디어오늘', 'NNP'), [('미디어', 'NNG'), ('오늘', 'NNG')]),
#               (('의원총회', 'NNP'), [('의원', 'NNG'), ('총회', 'NNG')]),
#               (('북중', 'NNP'), [('북', 'NNG'), ('중', 'NNB')]),
#               (('이배', 'NNP'), [('이', 'MM'), ('배', 'NNG')]),
#               (('시민사회', 'NNP'), [('시민', 'NNG'), ('사회', 'NNG')]),
#               (('진상규명', 'NNP'), [('진상', 'NNG'), ('규명', 'NNG')]),
#               (('북한', 'NNP'), [('북한', 'NNP')]),
#               (('한일군사', 'NNP'), [('한', 'MM'), ('일', 'NR'), ('군사', 'NNG')]),
#               (('자유한국당과', 'NNP'),
#                [('자유', 'NNG'), ('한국', 'NNP'), ('당과', 'NNG')]),
#               (('바른미래당', 'NNP'),
#                [('바른', 'VA+ETM'), ('미래', 'NNG'), ('당', 'XSN')]),
#               (('신당', 'NNP'), [('신', 'XPN'), ('당', 'NNG')]),
#               (('일왕', 'NNP'), [('일', 'NR'), ('왕', 'NNG')]),
#               (('국회의장과', 'NNP'), [('국회', 'NNG'), ('의', 'JKG'), ('장과', 'NNG')]),
#               (('국정농단', 'NNP'), [('국정', 'NNG'), ('농단', 'NNG')]),
#               (('국민소통', 'NNP'), [('국민', 'NNG'), ('소통', 'NNG')]),
#               (('민생법안', 'NNP'), [('민생', 'NNG'), ('법안', 'NNG')]),
#               (('기자', 'NNP'), [('기자', 'NNG')]),
#               (('채이배', 'NNP'), [('채', 'MAG'), ('이', 'MM'), ('배', 'NNG')]),
#               (('남북공동', 'NNP'), [('남북', 'NNP'), ('공동', 'NNG')]),
#               (('외교안보', 'NNP'), [('외교', 'NNG'), ('안보', 'NNG')]),
#               (('문재인정부', 'NNP'), [('문재인', 'NNP'), ('정부', 'NNG')]),
#               (('사회부총리', 'NNP'), [('사회', 'NNG'), ('부총리', 'NNG')]),
#               (('광화문광', 'NNP'), [('광화', 'NNG'), ('문광', 'NNG')]),
#               (('이벤', 'NNP'), [('이', 'MM'), ('벤', 'NNG')]),
#               (('안전보', 'NNP'), [('안', 'MAG'), ('전보', 'NNG')]),
#               (('공동취재단', 'NNP'), [('공', 'NNG'), ('동취', 'NNG'), ('재단', 'NNG')]),
#               (('플랫포', 'NNP'), [('플랫', 'NNG'), ('포', 'NNG')]),
#               (('김부', 'NNP'), [('김', 'NNP'), ('부', 'NNG')]),
#               (('로텐더', 'NNP'), [('로', 'JKB'), ('텐더', 'NNG')]),
#               (('웅동학', 'NNP'), [('웅', 'IC'), ('동학', 'NNG')]),
#               (('권력기관', 'NNP'), [('권력', 'NNG'), ('기관', 'NNG')]),
#               (('금강산관광', 'NNP'), [('금강산', 'NNP'), ('관광', 'NNG')]),
#               (('사법개혁특별위원회', 'NNP'),
#                [('사법', 'NNG'), ('개혁', 'NNG'), ('특별', 'NNG'), ('위원회', 'NNG')]),
#               (('방송통신', 'NNP'), [('방송', 'NNG'), ('통신', 'NNG')]),
#               (('영상편집', 'NNP'), [('영상', 'NNG'), ('편집', 'NNG')]),
#               (('시정연설', 'NNP'), [('시정', 'NNG'), ('연설', 'NNG')]),
#               (('신남방정책', 'NNP'), [('신', 'XPN'), ('남방', 'NNG'), ('정책', 'NNG')]),
#               (('국민소통수석', 'NNP'),
#                [('국민', 'NNG'), ('소통', 'NNG'), ('수석', 'NNG')]),
#               (('행정안전위원회', 'NNP'),
#                [('행정', 'NNG'), ('안전', 'NNG'), ('위원회', 'NNG')]),
#               (('전진환', 'NNP'), [('전', 'MM'), ('진환', 'NNG')]),
#               (('외교통일위원회', 'NNP'),
#                [('외교통', 'NNG'), ('일', 'VCP+ETM'), ('위원회', 'NNG')]),
#               (('신뢰수준', 'NNP'), [('신뢰', 'NNG'), ('수준', 'NNG')]),
#               (('기획재정', 'NNP'), [('기획', 'NNG'), ('재정', 'NNG')]),
#               (('국가안보실장', 'NNP'),
#                [('국가', 'NNG'), ('안보', 'NNG'), ('실장', 'NNG')]),
#               (('한일군사정보보호협정', 'NNP'),
#                [('한', 'MM'),
#                 ('일', 'NR'),
#                 ('군사', 'NNG'),
#                 ('정보', 'NNG'),
#                 ('보호', 'NNG'),
#                 ('협정', 'NNG')]),
#               (('평화체제', 'NNP'), [('평화', 'NNG'), ('체제', 'NNG')]),
#               (('한반도평화교섭본부', 'NNP'),
#                [('한반도', 'NNP'), ('평화', 'NNG'), ('교섭', 'NNG'), ('본부', 'NNG')]),
#               (('국가안전', 'NNP'), [('국가', 'NNG'), ('안전', 'NNG')]),
#               (('국대', 'NNP'), [('국', 'NNG'), ('대', 'NNG')]),
#               (('촛불집', 'NNP'), [('촛불', 'NNG'), ('집', 'NNG')]),
#               (('즈니스', 'NNP'), [('즈', 'MM'), ('니스', 'NNG')]),
#               (('대륙간', 'NNP'), [('대륙', 'NNG'), ('간', 'NNG')]),
#               (('독립유공자', 'NNP'), [('독립', 'NNG'), ('유공자', 'NNG')]),
#               (('국민의당', 'NNP'), [('국민', 'NNG'), ('의', 'JKG'), ('당', 'NNG')]),
#               (('로드매', 'NNP'), [('로드', 'NNG'), ('매', 'NNG')]),
#               (('서울시장', 'NNP'), [('서울', 'NNP'), ('시장', 'NNG')]),
#               (('당정협', 'NNP'), [('당정', 'NNG'), ('협', 'NNG')]),
#               (('상공회의', 'NNP'), [('상공', 'NNG'), ('회의', 'NNG')]),
#               (('확대간부', 'NNP'), [('확대', 'NNG'), ('간부', 'NNG')]),
#               (('추경안', 'NNP'), [('추경', 'NNG'), ('안', 'NNG')]),
#               (('부장판', 'NNP'), [('부', 'XPN'), ('장판', 'NNG')]),
#               (('브렉시', 'NNP'), [('브렉', 'NNP'), ('시', 'NNG')]),
#               (('피의사실', 'NNP'), [('피', 'NNG'), ('의', 'JKG'), ('사실', 'NNG')]),
#               (('닝썬', 'NNP'), [('닝', 'NNP'), ('썬', 'NNP')]),
#               (('휴대전', 'NNP'), [('휴대', 'NNG'), ('전', 'NNG')]),
#               (('감반', 'NNP'), [('감', 'NNG'), ('반', 'NNG')]),
#               (('미국', 'NNP'), [('미국', 'NNP')]),
#               (('과학기술정보방송통신', 'NNP'),
#                [('과학', 'NNG'),
#                 ('기술', 'NNG'),
#                 ('정보', 'NNG'),
#                 ('방송', 'NNG'),
#                 ('통신', 'NNG')]),
#               (('여성가족부', 'NNP'), [('여성', 'NNG'), ('가족', 'NNG'), ('부', 'NNG')]),
#               (('울산시장', 'NNP'), [('울산', 'NNP'), ('시장', 'NNG')]),
#               (('대북정책특별대표', 'NNP'),
#                [('대북', 'NNG'), ('정책', 'NNG'), ('특별', 'NNG'), ('대표', 'NNG')]),
#               (('선거운동', 'NNP'), [('선거', 'NNG'), ('운동', 'NNG')]),
#               (('학다식', 'NNP'), [('학', 'NNG'), ('다식', 'NNG')]),
#               (('레시안', 'NNP'), [('레시', 'NNP'), ('안', 'NNG')]),
#               (('이견이', 'NNP'), [('이', 'MM'), ('견이', 'NNG')]),
#               (('사진공동취재단', 'NNP'),
#                [('사진', 'NNG'), ('공', 'NNG'), ('동취', 'NNG'), ('재단', 'NNG')]),
#               (('특감반', 'NNP'), [('특감', 'NNG'), ('반', 'NNG')]),
#               (('참석차', 'NNP'), [('참', 'MAG'), ('석차', 'NNG')]),
#               (('행안부', 'NNP'), [('행안', 'NNP'), ('부', 'NNG')]),
#               (('투르크메', 'NNP'), [('투르크', 'NNP'), ('메', 'NNG')]),
#               (('통상일정', 'NNP'), [('통상', 'NNG'), ('일정', 'NNG')]),
#               (('기획단', 'NNP'), [('기', 'NNG'), ('획단', 'NNG')]),
#               (('4대강', 'NNP'), [('4', 'SN'), ('대강', 'NNG')]),
#               (('대통령비서', 'NNP'), [('대통령', 'NNG'), ('비서', 'NNG')]),
#               (('보훈처', 'NNP'), [('보훈', 'NNG'), ('처', 'NNG')]),
#               (('예비후보', 'NNP'), [('예비', 'NNG'), ('후보', 'NNG')]),
#               (('고용노동부', 'NNP'), [('고용', 'NNG'), ('노동부', 'NNG')]),
#               (('우소나루', 'NNP'), [('우소', 'NNP'), ('나루', 'NNP')]),
#               (('인재영입', 'NNP'), [('인재', 'NNG'), ('영입', 'NNG')]),
#               (('3선', 'NNP'), [('3', 'SN'), ('선', 'NNG')]),
#               (('훌류', 'NNP'), [('훌', 'NNP'), ('류', 'NNP')]),
#               (('이산', 'NNP'), [('이', 'MM'), ('산', 'NNG')]),
#               (('대륙간탄도미사일', 'NNP'),
#                [('대륙', 'NNG'), ('간탄', 'NNG'), ('도', 'JX'), ('미사일', 'NNG')]),
#               (('핵무', 'NNP'), [('핵', 'NNG'), ('무', 'NNG')]),
#               (('국정운영', 'NNP'), [('국정', 'NNG'), ('운영', 'NNG')]),
#               (('연락사무소', 'NNP'), [('연락', 'NNG'), ('사무소', 'NNG')]),
#               (('농림축산식품부', 'NNP'),
#                [('농림', 'NNG'), ('축산', 'NNG'), ('식품', 'NNG'), ('부', 'NNG')]),
#               (('심의위원회', 'NNP'), [('심의', 'NNG'), ('위원회', 'NNG')]),
#               (('미중', 'NNP'), [('미', 'NNG'), ('중', 'NNB')]),
#               (('국가안전보장', 'NNP'),
#                [('국가', 'NNG'), ('안전', 'NNG'), ('보장', 'NNG')]),
#               (('민식이', 'NNP'), [('민', 'NNP'), ('식이', 'NNG')]),
#               (('방위사업', 'NNP'), [('방위', 'NNG'), ('사업', 'NNG')]),
#               (('헌법재판관', 'NNP'), [('헌법', 'NNG'), ('재판관', 'NNG')]),
#               (('무책임', 'NNP'), [('무', 'XPN'), ('책임', 'NNG')]),
#               (('원내대변인', 'NNP'), [('원내', 'NNG'), ('대변인', 'NNG')]),
#               (('산업통상자원중소벤처기업', 'NNP'),
#                [('산업', 'NNG'),
#                 ('통상', 'NNG'),
#                 ('자원', 'NNG'),
#                 ('중소', 'NNG'),
#                 ('벤처', 'NNG'),
#                 ('기업', 'NNG')]),
#               (('경제활', 'NNP'), [('경제', 'NNG'), ('활', 'NNG')]),
#               (('불확', 'NNP'), [('불', 'XPN'), ('확', 'NNG')]),
#               (('통상업무', 'NNP'), [('통상', 'NNG'), ('업무', 'NNG')]),
#               (('평화경제', 'NNP'), [('평화', 'NNG'), ('경제', 'NNG')]),
#               (('특별감찰', 'NNP'), [('특별', 'NNG'), ('감찰', 'NNG')]),
#               (('리용호', 'NNP'), [('리용', 'NNG'), ('호', 'NNG')]),
#               (('해임건', 'NNP'), [('해임', 'NNG'), ('건', 'VCP+EC')]),
#               (('포용국가', 'NNP'), [('포용', 'NNG'), ('국가', 'NNG')]),
#               (('관계부처', 'NNP'), [('관계', 'NNG'), ('부처', 'NNG')]),
#               (('소득주도성장', 'NNP'),
#                [('소득', 'NNG'), ('주도', 'NNG'), ('성장', 'NNG')]),
#               (('탈원전', 'NNP'), [('탈', 'XPN'), ('원전', 'NNG')]),
#               (('국가안전보장회의', 'NNP'),
#                [('국가', 'NNG'), ('안전', 'NNG'), ('보장', 'NNG'), ('회의', 'NNG')]),
#               (('합동참모본부', 'NNP'),
#                [('합동', 'NNG'), ('참모', 'NNG'), ('본부', 'NNG')]),
#               (('국무조정', 'NNP'), [('국무', 'NNG'), ('조정', 'NNG')]),
#               (('신강재강', 'NNP'), [('신강', 'NNG'), ('재강', 'NNG')]),
#               (('니스탄', 'NNP'), [('니스', 'NNG'), ('탄', 'NNG')]),
#               (('브렉시트', 'NNP'), [('브렉', 'NNP'), ('시트', 'NNG')]),
#               (('운영위원회', 'NNP'), [('운영', 'NNG'), ('위원회', 'NNG')]),
#               (('연합훈련', 'NNP'), [('연합', 'NNG'), ('훈련', 'NNG')]),
#               (('중앙위원회', 'NNP'), [('중앙', 'NNG'), ('위원회', 'NNG')]),
#               (('보수통합', 'NNP'), [('보수', 'NNG'), ('통합', 'NNG')]),
#               (('신산업', 'NNP'), [('신', 'XPN'), ('산업', 'NNG')]),
#               (('임시국', 'NNP'), [('임', 'NNP'), ('시국', 'NNG')]),
#               (('창당준비', 'NNP'), [('창당', 'NNG'), ('준비', 'NNG')]),
#               (('스플레이', 'NNP'), [('스', 'IC'), ('플레이', 'NNG')]),
#               (('군사분', 'NNP'), [('군사', 'NNG'), ('분', 'NNB')]),
#               (('유엔총회', 'NNP'), [('유엔', 'NNP'), ('총회', 'NNG')]),
#               (('인천국제', 'NNP'), [('인천', 'NNP'), ('국제', 'NNG')]),
#               (('뉴스제보', 'NNP'), [('뉴스', 'NNG'), ('제보', 'NNG')]),
#               (('tv조선제보', 'NNP'),
#                [('tv', 'SL'), ('조선', 'NNP'), ('제보', 'NNP')]),
#               (('경제부', 'NNP'), [('경제', 'NNG'), ('부', 'NNG')]),
#               (('국립서울', 'NNP'), [('국립', 'NNG'), ('서울', 'NNP')]),
#               (('상임위원회', 'NNP'), [('상임', 'NNG'), ('위원회', 'NNG')]),
#               (('미북', 'NNP'), [('미', 'NNP'), ('북', 'NNP')]),
#               (('사용가능', 'NNP'), [('사용', 'NNG'), ('가능', 'NNG')]),
#               (('환경노동', 'NNP'), [('환경', 'NNG'), ('노동', 'NNG')]),
#               (('국립서울현충', 'NNP'),
#                [('국립', 'NNG'), ('서울', 'NNP'), ('현충', 'NNG')]),
#               (('대표연설', 'NNP'), [('대표', 'NNG'), ('연설', 'NNG')]),
#               (('의원직', 'NNP'), [('의원', 'NNG'), ('직', 'NNG')]),
#               (('중앙선거관리', 'NNP'),
#                [('중앙', 'NNG'), ('선거', 'NNG'), ('관리', 'NNG')]),
#               (('이윤청', 'NNP'), [('이', 'MM'), ('윤청', 'NNP')]),
#               (('의사일', 'NNP'), [('의사', 'NNG'), ('일', 'NNG')]),
#               (('대전시', 'NNP'), [('대', 'XPN'), ('전시', 'NNG')]),
#               (('의원정', 'NNP'), [('의원', 'NNG'), ('정', 'NNG')]),
#               (('대한상공회의', 'NNP'),
#                [('대한', 'VV+ETM'), ('상공', 'NNG'), ('회의', 'NNG')]),
#               (('정치권', 'NNP'), [('정치', 'NNG'), ('권', 'XSN')]),
#               (('상응조치', 'NNP'), [('상응', 'NNG'), ('조치', 'NNG')]),
#               (('인기만화', 'NNP'), [('인기', 'NNG'), ('만화', 'NNG')]),
#               (('트로폴', 'NNP'), [('트', 'NNG'), ('로', 'JKB'), ('폴', 'NNG')]),
#               (('평화프로세스', 'NNP'), [('평화', 'NNG'), ('프로세스', 'NNG')]),
#               (('더이상', 'NNP'), [('더', 'MAG'), ('이상', 'NNG')]),
#               (('이미지출처', 'NNP'), [('이미지', 'NNG'), ('출처', 'NNG')]),
#               (('영상취재', 'NNP'), [('영상', 'NNG'), ('취재', 'NNG')]),
#               (('개혁법안', 'NNP'), [('개혁', 'NNG'), ('법안', 'NNG')]),
#               (('이스칸', 'NNP'), [('이스', 'NNP'), ('칸', 'NNG')]),
#               (('외교안', 'NNP'), [('외교', 'NNG'), ('안', 'NNG')]),
#               (('예산정책', 'NNP'), [('예산', 'NNG'), ('정책', 'NNG')]),
#               (('부지검', 'NNP'), [('부지', 'NNP'), ('검', 'NNG')]),
#               (('25전쟁', 'NNP'), [('25', 'SN'), ('전쟁', 'NNG')]),
#               (('본회의장', 'NNP'), [('본회', 'NNG'), ('의장', 'NNG')]),
#               (('시민기자', 'NNP'), [('시민', 'NNG'), ('기자', 'NNG')]),
#               (('장외집', 'NNP'), [('장외', 'NNG'), ('집', 'NNG')]),
#               (('저히', 'NNP'), [('저', 'MM'), ('히', 'NNG')]),
#               (('메트로폴', 'NNP'), [('메트로', 'NNP'), ('폴', 'NNG')]),
#               (('텔레그램', 'NNP'), [('텔레', 'NNP'), ('그램', 'NNG')]),
#               (('좌파독재', 'NNP'), [('좌파', 'NNG'), ('독재', 'NNG')]),
#               (('사진기자단', 'NNP'), [('사진', 'NNG'), ('기자단', 'NNG')]),
#               (('전략물', 'NNP'), [('전략', 'NNG'), ('물', 'NNG')]),
#               (('코링크', 'NNP'), [('코', 'NNG'), ('링크', 'NNG')]),
#               (('긍정평가', 'NNP'), [('긍정', 'NNG'), ('평가', 'NNG')]),
#               (('십시오', 'NNP'), [('십', 'NR'), ('시오', 'NR')]),
#               (('국가정보원', 'NNP'), [('국가', 'NNG'), ('정보원', 'NNG')]),
#               (('3자', 'NNP'), [('3', 'SN'), ('자', 'NNG')]),
#               (('사법농', 'NNP'), [('사법', 'NNG'), ('농', 'NNG')]),
#               (('비상행동', 'NNP'), [('비상', 'NNG'), ('행동', 'NNG')]),
#               (('일부개정', 'NNP'), [('일부', 'NNG'), ('개정', 'NNG')]),
#               (('알릴레오', 'NNP'), [('알릴', 'NNG'), ('레오', 'NNP')]),
#               (('탈북민', 'NNP'), [('탈', 'XPN'), ('북', 'NNP'), ('민', 'NNP')]),
#               (('버닝썬', 'NNP'), [('버', 'NNP'), ('닝', 'NNP'), ('썬', 'NNP')]),
#               (('장관급', 'NNP'), [('장관', 'NNG'), ('급', 'NNG')]),
#               (('헌법재판소', 'NNP'), [('헌법', 'NNG'), ('재판소', 'NNG')]),
#               (('인사검증', 'NNP'), [('인사', 'NNG'), ('검증', 'NNG')]),
#               (('에이브', 'NNP'), [('에', 'IC'), ('이브', 'NNG')]),
#               (('공정경제', 'NNP'), [('공정', 'NNG'), ('경제', 'NNG')]),
#               (('혁신성장', 'NNP'), [('혁신', 'NNG'), ('성', 'XSN'), ('장', 'NNG')]),
#               (('정치자금', 'NNP'), [('정치', 'NNG'), ('자금', 'NNG')]),
#               (('여야정', 'NNP'), [('여', 'NNG'), ('야정', 'NNG')]),
#               (('최순실', 'NNP'), [('최순', 'NNP'), ('실', 'NNG')]),
#               (('대통령비서실', 'NNP'), [('대통령', 'NNG'), ('비서실', 'NNG')]),
#               (('어질', 'NNP'), [('어', 'IC'), ('질', 'NNG')]),
#               (('1절', 'NNP'), [('1', 'SN'), ('절', 'NNG')]),
#               (('연합뉴스', 'NNP'), [('연합뉴스', 'NNP')]),
#               (('국민권익', 'NNP'), [('국민', 'NNG'), ('권익', 'NNG')]),
#               (('국민연금', 'NNP'), [('국민', 'NNG'), ('연금', 'NNG')]),
#               (('기재부', 'NNP'), [('기재', 'NNG'), ('부', 'NNG')]),
#               (('중앙선거여론조사', 'NNP'),
#                [('중앙', 'NNG'), ('선거', 'NNG'), ('여론', 'NNG'), ('조사', 'NNG')]),
#               (('이스칸데르', 'NNP'), [('이스', 'NNP'), ('칸', 'NNP'), ('데르', 'NNP')]),
#               (('국정현안', 'NNP'), [('국정', 'NNG'), ('현안', 'NNG')]),
#               (('접경지역', 'NNP'), [('접경', 'NNG'), ('지역', 'NNG')]),
#               (('상임위원', 'NNP'), [('상임', 'NNG'), ('위원', 'NNG')]),
#               (('세종문화', 'NNP'), [('세종', 'NNP'), ('문화', 'NNG')]),
#               (('사관학교', 'NNP'), [('사관', 'NNG'), ('학교', 'NNG')]),
#               (('중소기업중앙', 'NNP'), [('중소기업', 'NNG'), ('중앙', 'NNG')]),
#               (('북미대화', 'NNP'), [('북미', 'NNP'), ('대화', 'NNG')]),
#               (('국민청원', 'NNP'), [('국민', 'NNG'), ('청원', 'NNG')]),
#               (('대한애', 'NNP'), [('대한', 'VV+ETM'), ('애', 'NNG')]),
#               (('자사고', 'NNP'), [('자', 'IC'), ('사고', 'NNG')]),
#               (('한국갤럽', 'NNP'), [('한국', 'NNP'), ('갤럽', 'NNG')]),
#               (('잘모', 'NNP'), [('잘', 'MAG'), ('모', 'NNG')]),
#               (('의사진행', 'NNP'), [('의사', 'NNG'), ('진행', 'NNG')]),
#               (('어긋', 'NNP'), [('어', 'IC'), ('긋', 'NNG')]),
#               (('한국전', 'NNP'), [('한국', 'NNP'), ('전', 'NNG')]),
#               (('친구매', 'NNP'), [('친구', 'NNG'), ('매', 'NNG')]),
#               (('정치공', 'NNP'), [('정치', 'NNG'), ('공', 'NNG')]),
#               (('합의문', 'NNP'), [('합의', 'NNG'), ('문', 'NNG')]),
#               (('민정비서관', 'NNP'), [('민정', 'NNG'), ('비서관', 'NNG')]),
#               (('지역위원장', 'NNP'), [('지역', 'NNG'), ('위원장', 'NNG')]),
#               (('민주평화당은', 'NNP'),
#                [('민주', 'NNP'), ('평화', 'NNP'), ('당은', 'NNP+JX')]),
#               (('방위비분담금', 'NNP'), [('방위비', 'NNG'), ('분담금', 'NNG')]),
#               (('텅장', 'NNP'), [('텅', 'MAG'), ('장', 'NNG')]),
#               (('호르', 'NNP'), [('호', 'IC'), ('르', 'NNG')]),
#               (('한나라', 'NNP'), [('한', 'MM'), ('나라', 'NNG')]),
#               (('국정현안점검', 'NNP'),
#                [('국정', 'NNG'), ('현안', 'NNG'), ('점검', 'NNG')]),
#               (('워크쇼', 'NNP'), [('워크', 'NNG'), ('쇼', 'NNG')]),
#               (('외교부가', 'NNP'), [('외교', 'NNG'), ('부가', 'NNG')]),
#               (('미래지향', 'NNP'), [('미래', 'NNG'), ('지향', 'NNG')]),
#               (('대안정치연대', 'NNP'),
#                [('대안', 'NNG'), ('정치', 'NNG'), ('연대', 'NNG')]),
#               (('웅동학원', 'NNP'), [('웅동', 'NNP'), ('학원', 'NNG')]),
#               (('북미간', 'NNP'), [('북미', 'NNP'), ('간', 'NNB')]),
#               (('경제수석', 'NNP'), [('경제', 'NNG'), ('수석', 'NNG')]),
#               (('불평등', 'NNP'), [('불', 'XPN'), ('평등', 'NNG')]),
#               (('자문회의', 'NNP'), [('자문', 'NNG'), ('회의', 'NNG')]),
#               (('자치경찰', 'NNP'), [('자치', 'NNG'), ('경찰', 'NNG')]),
#               (('유해발굴', 'NNP'), [('유해', 'NNG'), ('발굴', 'NNG')]),
#               (('규탄대회', 'NNP'), [('규탄', 'NNG'), ('대회', 'NNG')]),
#               (('2심', 'NNP'), [('2', 'SN'), ('심', 'NNG')]),
#               (('다음주', 'NNP'), [('다음', 'NNG'), ('주', 'NNG')]),
#               (('교육위원회', 'NNP'), [('교육', 'NNG'), ('위원회', 'NNG')]),
#               (('원내지도', 'NNP'), [('원내', 'NNG'), ('지도', 'NNG')]),
#               (('중앙선거여론조사심의위원회', 'NNP'),
#                [('중앙', 'NNG'),
#                 ('선거', 'NNG'),
#                 ('여론', 'NNG'),
#                 ('조사', 'NNG'),
#                 ('심', 'XSN'),
#                 ('의', 'JKG'),
#                 ('위원회', 'NNG')]),
#               (('주시기', 'NNP'), [('주', 'MM'), ('시기', 'NNG')]),
#               (('국가직', 'NNP'), [('국가', 'NNG'), ('직', 'NNG')]),
#               (('어준', 'NNP'), [('어', 'IC'), ('준', 'NNP')]),
#               (('비리수사처', 'NNP'), [('비리', 'NNG'), ('수사', 'NNG'), ('처', 'NNG')]),
#               (('불투명', 'NNP'), [('불', 'XPN'), ('투명', 'NNG')]),
#               (('여론조', 'NNP'), [('여론', 'NNG'), ('조', 'NNG')]),
#               (('평화정착', 'NNP'), [('평화', 'NNG'), ('정착', 'NNG')]),
#               (('계올림픽', 'NNP'), [('계', 'NNG'), ('올림픽', 'NNP')]),
#               (('양국간', 'NNP'), [('양국', 'NNG'), ('간', 'NNG')]),
#               (('안전보장이사회', 'NNP'),
#                [('안전', 'NNG'), ('보장', 'NNG'), ('이', 'JKS'), ('사회', 'NNG')]),
#               (('자력갱', 'NNP'), [('자력', 'NNG'), ('갱', 'NNG')]),
#               (('온라인뉴스', 'NNP'), [('온라인', 'NNG'), ('뉴스', 'NNG')]),
#               (('불구속', 'NNP'), [('불', 'XPN'), ('구속', 'NNG')]),
#               (('소득주도성', 'NNP'), [('소득', 'NNG'), ('주도성', 'NNG')]),
#               (('원포인트', 'NNP'), [('원', 'NNG'), ('포인트', 'NNG')]),
#               (('대정부질문', 'NNP'), [('대', 'XPN'), ('정부', 'NNG'), ('질문', 'NNG')]),
#               (('부대변인', 'NNP'), [('부대', 'NNG'), ('변인', 'NNG')]),
#               (('제3지대', 'NNP'), [('제', 'XPN'), ('3', 'SN'), ('지대', 'NNG')]),
#               (('황광모', 'NNP'), [('황', 'NNP'), ('광모', 'NNG')]),
#               (('당협위원장', 'NNP'), [('당', 'NNG'), ('협', 'NNG'), ('위원장', 'NNG')]),
#               (('통일전선', 'NNP'), [('통일', 'NNG'), ('전선', 'NNG')]),
#               (('최태', 'NNP'), [('최', 'XPN'), ('태', 'NNG')]),
#               (('온라인뉴스팀', 'NNP'),
#                [('온라인', 'NNG'), ('뉴스', 'NNG'), ('팀', 'NNG')]),
#               (('기획재정위원회', 'NNP'),
#                [('기획', 'NNG'), ('재정', 'NNG'), ('위원회', 'NNG')]),
#               (('억달러', 'NNP'), [('억', 'NR'), ('달러', 'NNBC')]),
#               (('혜련', 'NNP'), [('혜', 'NNG'), ('련', 'NNG')]),
#               (('라늄', 'NNP'), [('라', 'IC'), ('늄', 'NNG')]),
#               (('노딜', 'NNP'), [('노', 'NNP'), ('딜', 'NNG')]),
#               (('인사수석', 'NNP'), [('인사', 'NNG'), ('수석', 'NNG')]),
#               (('고위공직자비리수사처', 'NNP'),
#                [('고위', 'NNG'),
#                 ('공직자', 'NNG'),
#                 ('비리', 'NNG'),
#                 ('수사', 'NNG'),
#                 ('처', 'NNG')]),
#               (('특별감찰반', 'NNP'), [('특별', 'NNG'), ('감찰', 'NNG'), ('반', 'NNG')]),
#               (('미측', 'NNP'), [('미', 'NNG'), ('측', 'NNB')]),
#               (('정무위원회', 'NNP'), [('정무', 'NNG'), ('위원회', 'NNG')]),
#               (('브란스병원', 'NNP'), [('브', 'NNP'), ('란스', 'NNP'), ('병원', 'NNG')]),
#               (('기관리', 'NNP'), [('기', 'NNG'), ('관리', 'NNG')]),
#               (('일부개정법률', 'NNP'),
#                [('일부', 'NNG'), ('개정', 'NNG'), ('법률', 'NNG')]),
#               (('정책연구원', 'NNP'), [('정책', 'NNG'), ('연구원', 'NNG')]),
#               (('18민주화운동', 'NNP'),
#                [('18', 'SN'), ('민주', 'NNG'), ('화', 'XSN'), ('운동', 'NNG')]),
#               (('윤리위', 'NNP'), [('윤리', 'NNG'), ('위', 'NNG')]),
#               (('한국노총', 'NNP'), [('한국', 'NNP'), ('노총', 'NNG')]),
#               (('멜리아', 'NNP'), [('멜', 'NNP'), ('리아', 'NNP')]),
#               (('중견기업', 'NNP'), [('중견', 'NNG'), ('기업', 'NNG')]),
#               (('태섭', 'NNP'), [('태', 'NNG'), ('섭', 'NNG')]),
#               (('적폐청산', 'NNP'), [('적폐', 'NNG'), ('청산', 'NNG')]),
#               (('경제산업', 'NNP'), [('경제', 'NNG'), ('산업', 'NNG')]),
#               (('수엘라', 'NNP'), [('수', 'NNG'), ('엘라', 'NNP')]),
#               (('헬싱키', 'NNP'), [('헬싱', 'NNP'), ('키', 'NNG')]),
#               (('경사노', 'NNP'), [('경사', 'NNG'), ('노', 'NNP')]),
#               (('부장판사', 'NNP'), [('부장', 'NNG'), ('판사', 'NNG')]),
#               (('남북교류', 'NNP'), [('남북', 'NNP'), ('교류', 'NNG')]),
#               (('준연동', 'NNP'), [('준', 'XPN'), ('연동', 'NNG')]),
#               (('합동연설', 'NNP'), [('합동', 'NNG'), ('연설', 'NNG')]),
#               (('초당적', 'NNP'), [('초', 'XPN'), ('당적', 'NNG')]),
#               (('삼지연', 'NNP'), [('삼', 'NR'), ('지연', 'NNG')]),
#               (('추상철', 'NNP'), [('추상', 'NNG'), ('철', 'NNG')]),
#               (('공동선언', 'NNP'), [('공동', 'NNG'), ('선언', 'NNG')]),
#               (('남북경', 'NNP'), [('남', 'NNG'), ('북경', 'NNG')]),
#               (('민갑룡', 'NNP'), [('민갑', 'NNG'), ('룡', 'NNP')]),
#               (('문제연구소', 'NNP'), [('문제', 'NNG'), ('연구소', 'NNG')]),
#               (('즉석당첨', 'NNP'), [('즉석', 'MM'), ('당첨', 'NNG')]),
#               (('국방과학', 'NNP'), [('국방', 'NNG'), ('과학', 'NNG')]),
#               (('경제활력', 'NNP'), [('경제', 'NNG'), ('활력', 'NNG')]),
#               (('수사기관', 'NNP'), [('수사', 'NNG'), ('기관', 'NNG')]),
#               (('교착상태', 'NNP'), [('교착', 'NNG'), ('상태', 'NNG')]),
#               (('차관급', 'NNP'), [('차관', 'NNG'), ('급', 'NNG')]),
#               (('금융감독', 'NNP'), [('금융', 'NNG'), ('감독', 'NNG')]),
#               (('제1부부', 'NNP'), [('제', 'XPN'), ('1', 'SN'), ('부부', 'NNG')]),
#               (('라윳', 'NNP'), [('라', 'NNP'), ('윳', 'NNP')]),
#               (('민식이법', 'NNP'), [('민', 'NNP'), ('식이', 'NNG'), ('법', 'NNG')]),
#               (('의원정수', 'NNP'), [('의원', 'NNG'), ('정수', 'NNG')]),
#               (('사법농단', 'NNP'), [('사법', 'NNG'), ('농단', 'NNG')]),
#               (('한국전쟁', 'NNP'), [('한국', 'NNP'), ('전쟁', 'NNG')]),
#               (('응우', 'NNP'), [('응', 'IC'), ('우', 'NNG')]),
#               (('운영위원장', 'NNP'), [('운영', 'NNG'), ('위원장', 'NNG')]),
#               (('일본', 'NNP'), [('일본', 'NNP')]),
#               (('이번주', 'NNP'), [('이번', 'NNG'), ('주', 'NNG')]),
#               (('북미관계', 'NNP'), [('북미', 'NNP'), ('관계', 'NNG')]),
#               (('르신', 'NNP'), [('르', 'NNG'), ('신', 'NNG')]),
#               (('국장급', 'NNP'), [('국장', 'NNG'), ('급', 'NNG')]),
#               (('주민', 'NNP'), [('주민', 'NNG')]),
#               (('형섭', 'NNP'), [('형', 'NNG'), ('섭', 'NNG')]),
#               (('서울남', 'NNP'), [('서울', 'NNP'), ('남', 'NNG')]),
#               (('합의안', 'NNP'), [('합의', 'NNG'), ('안', 'NNG')]),
#               (('전문대학원', 'NNP'), [('전문', 'NNG'), ('대학원', 'NNG')]),
#               (('허위사실', 'NNP'), [('허위', 'NNG'), ('사실', 'NNG')]),
#               (('과학기술정보방송통신위원회', 'NNP'),
#                [('과학', 'NNG'),
#                 ('기술', 'NNG'),
#                 ('정보', 'NNG'),
#                 ('방송', 'NNG'),
#                 ('통신', 'NNG'),
#                 ('위원회', 'NNG')]),
#               (('비서실장과', 'NNP'), [('비서실', 'NNG'), ('장과', 'NNG')]),
#               (('산업통상자원중소벤처기업위원회', 'NNP'),
#                [('산업', 'NNG'),
#                 ('통상', 'NNG'),
#                 ('자원', 'NNG'),
#                 ('중소', 'NNG'),
#                 ('벤처', 'NNG'),
#                 ('기업', 'NNG'),
#                 ('위원회', 'NNG')]),
#               (('남북군사', 'NNP'), [('남북', 'NNP'), ('군사', 'NNG')]),
#               (('말씀드리', 'NNP'), [('말씀', 'NNG'), ('드리', 'NNG')]),
#               (('전략물자', 'NNP'), [('전략', 'NNG'), ('물자', 'NNG')]),
#               (('한국당도', 'NNP'), [('한국', 'NNP'), ('당도', 'NNG')]),
#               (('우리측', 'NNP'), [('우리', 'NP'), ('측', 'NNB')]),
#               (('인사혁신', 'NNP'), [('인사', 'NNG'), ('혁신', 'NNG')]),
#               (('남북경협', 'NNP'), [('남북', 'NNP'), ('경협', 'NNG')]),
#               (('국토교통위원회', 'NNP'),
#                [('국토', 'NNG'), ('교통', 'NNG'), ('위원회', 'NNG')]),
#               (('대한상공회의소', 'NNP'),
#                [('대한', 'VV+ETM'), ('상공', 'NNG'), ('회의소', 'NNG')]),
#               (('민생경제', 'NNP'), [('민생', 'NNG'), ('경제', 'NNG')]),
#               (('원내대책회의', 'NNP'),
#                [('원내', 'NNG'), ('대책', 'NNG'), ('회의', 'NNG')]),
#               (('재송부', 'NNP'), [('재', 'XPN'), ('송부', 'NNG')]),
#               (('카운터파트', 'NNP'), [('카운터', 'NNP'), ('파트', 'NNG')]),
#               (('안정원', 'NNP'), [('안', 'MAG'), ('정원', 'NNG')]),
#               (('국회의사', 'NNP'), [('국회', 'NNG'), ('의사', 'NNG')]),
#               (('비례한국당', 'NNP'), [('비례', 'NNG'), ('한국', 'NNP'), ('당', 'NNG')]),
#               (('바른미래당과', 'NNP'),
#                [('바른', 'VA+ETM'), ('미래', 'NNG'), ('당과', 'NNG')]),
#               (('앵커멘트', 'NNP'), [('앵', 'NNG'), ('커멘트', 'NNG')]),
#               (('별구역', 'NNP'), [('별', 'MM'), ('구역', 'NNG')]),
#               (('안건조정', 'NNP'), [('안건', 'NNG'), ('조정', 'NNG')]),
#               (('실무회담', 'NNP'), [('실무', 'NNG'), ('회담', 'NNG')]),
#               (('국정수행', 'NNP'), [('국정', 'NNG'), ('수행', 'NNG')]),
#               (('총리실', 'NNP'), [('총리', 'NNG'), ('실', 'NNG')]),
#               (('표본오차', 'NNP'), [('표본', 'NNG'), ('오차', 'NNG')]),
#               (('금융위원회', 'NNP'), [('금융', 'NNG'), ('위원회', 'NNG')]),
#               (('공식별구역', 'NNP'), [('공식', 'NNG'), ('별', 'XSN'), ('구역', 'NNG')]),
#               (('강제동원', 'NNP'), [('강제', 'NNG'), ('동원', 'NNG')]),
#               (('전술유도', 'NNP'), [('전술', 'NNG'), ('유도', 'NNG')]),
#               (('무역기구', 'NNP'), [('무역', 'NNG'), ('기구', 'NNG')]),
#               (('농림축산식품해양수산', 'NNP'),
#                [('농림', 'NNG'),
#                 ('축산', 'NNG'),
#                 ('식품', 'NNG'),
#                 ('해', 'XSV+EC'),
#                 ('양수산', 'NNP')]),
#               (('최측근', 'NNP'), [('최', 'XPN'), ('측근', 'NNG')]),
#               (('자문위원', 'NNP'), [('자문', 'NNG'), ('위원', 'NNG')]),
#               (('인사혁신처', 'NNP'), [('인사', 'NNG'), ('혁신', 'NNG'), ('처', 'NNG')]),
#               (('끝날', 'NNP'), [('끝', 'NNG'), ('날', 'NNG')]),
#               (('북미협상', 'NNP'), [('북미', 'NNP'), ('협상', 'NNG')]),
#               (('다뉴', 'NNP'), [('다', 'MAG'), ('뉴', 'NNG')]),
#               (('기구독', 'NNP'), [('기구', 'NNG'), ('독', 'NNG')]),
#               (('4선', 'NNP'), [('4', 'SN'), ('선', 'NNG')]),
#               (('슈케', 'NNP'), [('슈', 'NNP'), ('케', 'NNP')]),
#               (('혁신위', 'NNP'), [('혁신', 'NNG'), ('위', 'NNG')]),
#               (('전원회의', 'NNP'), [('전원', 'NNG'), ('회의', 'NNG')]),
#               (('6자', 'NNP'), [('6', 'SN'), ('자', 'NNG')]),
#               (('전문기관', 'NNP'), [('전문', 'NNG'), ('기관', 'NNG')]),
#               (('근로시간', 'NNP'), [('근로', 'NNG'), ('시간', 'NNG')]),
#               (('법제사법위원회의', 'NNP'),
#                [('법제', 'NNG'), ('사법', 'NNG'), ('위원', 'NNG'), ('회의', 'NNG')]),
#               (('식량지원', 'NNP'), [('식량', 'NNG'), ('지원', 'NNG')]),
#               (('평통', 'NNP'), [('평', 'NNG'), ('통', 'NNG')]),
#               (('자영업자', 'NNP'), [('자', 'IC'), ('영업자', 'NNG')]),
#               (('광주형', 'NNP'), [('광주', 'NNP'), ('형', 'NNG')]),
#               (('개혁안', 'NNP'), [('개혁', 'NNG'), ('안', 'NNG')]),
#               (('민정수석실', 'NNP'), [('민정', 'NNG'), ('수석', 'NNG'), ('실', 'NNG')]),
#               (('한주홍', 'NNP'), [('한', 'MM'), ('주홍', 'NNG')]),
#               (('청해부대', 'NNP'), [('청해', 'NNG'), ('부대', 'NNG')]),
#               (('예의주시', 'NNP'), [('예의', 'NNG'), ('주시', 'NNG')]),
#               (('심사소', 'NNP'), [('심사', 'NNG'), ('소', 'NNG')]),
#               (('문화체육관광위원회', 'NNP'),
#                [('문화', 'NNG'), ('체육', 'NNG'), ('관광', 'NNG'), ('위원회', 'NNG')]),
#               (('참여정부', 'NNP'), [('참여', 'NNG'), ('정부', 'NNG')]),
#               (('추가경정예산안', 'NNP'),
#                [('추가', 'NNG'), ('경정', 'NNG'), ('예산안', 'NNG')]),
#               (('시의원', 'NNP'), [('시', 'NNG'), ('의원', 'NNG')]),
#               (('관계기관', 'NNP'), [('관계', 'NNG'), ('기관', 'NNG')]),
#               (('우리민족', 'NNP'), [('우리', 'NP'), ('민족', 'NNG')]),
#               (('류영주', 'NNP'), [('류', 'NNP'), ('영주', 'NNG')]),
#               (('능후', 'NNP'), [('능', 'NNG'), ('후', 'NNG')]),
#               (('박능후', 'NNP'), [('박', 'VV'), ('능', 'ETM'), ('후', 'NNG')]),
#               (('학기술', 'NNP'), [('학기', 'NNG'), ('술', 'NNG')]),
#               (('서울중앙지법', 'NNP'),
#                [('서울', 'NNP'), ('중앙', 'NNG'), ('지법', 'NNG')]),
#               (('환경노동위원회', 'NNP'),
#                [('환경', 'NNG'), ('노동', 'NNG'), ('위원회', 'NNG')]),
#               (('운영위', 'NNP'), [('운영', 'NNG'), ('위', 'NNG')]),
#               (('북한판', 'NNP'), [('북한', 'NNP'), ('판', 'NNG')]),
#               (('정춘', 'NNP'), [('정', 'NNP'), ('춘', 'NNG')]),
#               (('수석보좌관', 'NNP'), [('수석', 'NNG'), ('보좌관', 'NNG')]),
#               (('인사', 'NNP'), [('인사', 'NNG')]),
#               (('아', 'NNP'), [('아', 'IC')]),
#               (('증거인멸', 'NNP'), [('증거인', 'NNG'), ('멸', 'NNG')]),
#               (('총선기획단', 'NNP'), [('총', 'MM'), ('선기', 'NNG'), ('획단', 'NNG')]),
#               (('시험발사', 'NNP'), [('시험', 'NNG'), ('발사', 'NNG')]),
#               (('도시재생', 'NNP'), [('도시', 'NNG'), ('재생', 'NNG')]),
#               (('4차산업', 'NNP'), [('4', 'SN'), ('차', 'NNBC'), ('산업', 'NNG')]),
#               (('행안위', 'NNP'), [('행안', 'NNP'), ('위', 'NNG')]),
#               (('수출규', 'NNP'), [('수출', 'NNG'), ('규', 'NNG')]),
#               (('출판기념', 'NNP'), [('출판', 'NNG'), ('기념', 'NNG')]),
#               (('특수부', 'NNP'), [('특수', 'NNG'), ('부', 'NNG')]),
#               (('유의동', 'NNP'), [('유', 'NNP'), ('의', 'JKG'), ('동', 'NNG')]),
#               (('거돈', 'NNP'), [('거', 'NP'), ('돈', 'NNG')]),
#               (('공식환영', 'NNP'), [('공식', 'NNG'), ('환영', 'NNG')]),
#               (('회국회', 'NNP'), [('회', 'NNG'), ('국회', 'NNG')]),
#               (('은성수', 'NNP'), [('은성', 'NNG'), ('수', 'NNG')]),
#               (('출입기자', 'NNP'), [('출입', 'NNG'), ('기자', 'NNG')]),
#               (('민주항쟁', 'NNP'), [('민주', 'NNP'), ('항쟁', 'NNG')]),
#               (('대통합', 'NNP'), [('대', 'XPN'), ('통합', 'NNG')]),
#               (('문자메시', 'NNP'), [('문자', 'NNG'), ('메시', 'NNG')]),
#               (('정무위', 'NNP'), [('정무', 'NNG'), ('위', 'NNG')]),
#               (('리어트', 'NNP'), [('리어', 'NNG'), ('트', 'NNG')]),
#               (('단식농', 'NNP'), [('단식', 'NNG'), ('농', 'NNG')]),
# ...
#               (('대한불교조계종', 'NNP'),
#                [('대한', 'VV+ETM'), ('불교', 'NNG'), ('조계종', 'NNG')]),
#               (('그먼트', 'NNP'), [('그먼', 'MAJ'), ('트', 'NNG')]),
#               (('올림픽공원', 'NNP'), [('올림픽', 'NNP'), ('공원', 'NNG')]),
#               (('안구건조', 'NNP'), [('안구', 'NNG'), ('건조', 'NNG')]),
#               (('국립민속', 'NNP'), [('국립', 'NNG'), ('민속', 'NNG')]),
#               (('크로스컨', 'NNP'), [('크로스', 'NNP'), ('컨', 'NNP')]),
#               (('4기통', 'NNP'), [('4', 'SN'), ('기통', 'NNG')]),
#               (('올리브영', 'NNP'), [('올리브', 'NNG'), ('영', 'NNG')]),
#               (('수면무호흡', 'NNP'), [('수면', 'NNG'), ('무호흡', 'NNG')]),
#               (('램시마', 'NNP'), [('램', 'NNG'), ('시마', 'NNG')]),
#               (('보툴리', 'NNP'), [('보', 'NNP'), ('툴리', 'NNP')]),
#               (('충돌방지', 'NNP'), [('충돌', 'NNG'), ('방지', 'NNG')]),
#               (('홍해인', 'NNP'), [('홍', 'NNG'), ('해인', 'NNG')]),
#               (('백혈', 'NNP'), [('백', 'NR'), ('혈', 'NNG')]),
#               (('제주공항', 'NNP'), [('제주', 'NNP'), ('공항', 'NNG')]),
#               (('저비용', 'NNP'), [('저', 'MM'), ('비용', 'NNG')]),
#               (('최우수상', 'NNP'), [('최우', 'NNP'), ('수상', 'NNG')]),
#               (('조근영', 'NNP'), [('조', 'NNG'), ('근영', 'NNG')]),
#               (('햄버', 'NNP'), [('햄', 'NNP'), ('버', 'NNP')]),
#               (('즈너', 'NNP'), [('즈', 'NP'), ('너', 'NP')]),
#               (('세계평화', 'NNP'), [('세계', 'NNG'), ('평화', 'NNG')]),
#               (('독자', 'NNP'), [('독자', 'NNG')]),
#               (('완전변경', 'NNP'), [('완전', 'NNG'), ('변경', 'NNG')]),
#               (('문화교류', 'NNP'), [('문화', 'NNG'), ('교류', 'NNG')]),
#               (('창작뮤지컬', 'NNP'), [('창작', 'NNG'), ('뮤지컬', 'NNG')]),
#               (('애트', 'NNP'), [('애', 'NNG'), ('트', 'NNG')]),
#               (('텔루라이드', 'NNP'), [('텔', 'NNG'), ('루', 'JKB'), ('라이드', 'NNP')]),
#               (('풀체인지', 'NNP'), [('풀', 'NNG'), ('체인지', 'NNG')]),
#               (('미니멀', 'NNP'), [('미니', 'NNG'), ('멀', 'NNG')]),
#               (('협력업체', 'NNP'), [('협력', 'NNG'), ('업체', 'NNG')]),
#               (('취재후', 'NNP'), [('취재', 'NNG'), ('후', 'NNG')]),
#               (('다시금', 'NNP'), [('다시', 'MAG'), ('금', 'NNG')]),
#               (('거머쥐', 'NNP'), [('거머', 'NNP'), ('쥐', 'NNG')]),
#               (('팬미', 'NNP'), [('팬', 'NNG'), ('미', 'NNG')]),
#               (('코오롱생명과학', 'NNP'),
#                [('코오롱', 'NNP'), ('생명', 'NNG'), ('과학', 'NNG')]),
#               (('경연대회', 'NNP'), [('경연', 'NNG'), ('대회', 'NNG')]),
#               (('복합연', 'NNP'), [('복', 'NNG'), ('합연', 'NNG')]),
#               (('등록문화재', 'NNP'), [('등록', 'NNG'), ('문화재', 'NNG')]),
#               (('아르바이', 'NNP'), [('아르', 'NNG'), ('바이', 'NNG')]),
#               (('비인후', 'NNP'), [('비', 'XPN'), ('인후', 'NNG')]),
#               (('건강검진', 'NNP'), [('건강', 'NNG'), ('검진', 'NNG')]),
#               (('류마티스', 'NNP'), [('류', 'NNP'), ('마티스', 'NNP')]),
#               (('보툴리눔', 'NNP'), [('보', 'NNP'), ('툴리', 'NNP'), ('눔', 'NNB')]),
#               (('한의원', 'NNP'), [('한', 'MM'), ('의원', 'NNG')]),
#               (('예수교장로회', 'NNP'), [('예수교', 'NNG'), ('장로회', 'NNG')]),
#               (('도로교통', 'NNP'), [('도로', 'NNG'), ('교통', 'NNG')]),
#               (('스펙트', 'NNP'), [('스펙', 'NNP'), ('트', 'NNG')]),
#               (('커넥티드카', 'NNP'),
#                [('커', 'VA+EC'),
#                 ('넥', 'NNG'),
#                 ('티', 'VV'),
#                 ('드', 'EC'),
#                 ('카', 'NNG')]),
#               (('한국불교', 'NNP'), [('한국', 'NNP'), ('불교', 'NNG')]),
#               (('대형마트', 'NNP'), [('대형', 'NNG'), ('마트', 'NNG')]),
#               (('심방세', 'NNP'), [('심방', 'NNG'), ('세', 'NNG')]),
#               (('농림축산식품', 'NNP'),
#                [('농림', 'NNG'), ('축산', 'NNG'), ('식품', 'NNG')]),
#               (('신메뉴', 'NNP'), [('신', 'XPN'), ('메뉴', 'NNG')]),
#               (('편의사양', 'NNP'), [('편의', 'NNG'), ('사양', 'NNG')]),
#               (('미래지향', 'NNP'), [('미래', 'NNG'), ('지향', 'NNG')]),
#               (('예술경영지원센터', 'NNP'),
#                [('예술', 'NNG'), ('경영', 'NNG'), ('지원', 'NNG'), ('센터', 'NNG')]),
#               (('3도가량', 'NNP'), [('3', 'SN'), ('도', 'NNBC'), ('가량', 'NNG')]),
#               (('대한독립', 'NNP'), [('대한', 'VV+ETM'), ('독립', 'NNG')]),
#               (('광주형', 'NNP'), [('광주', 'NNP'), ('형', 'NNG')]),
#               (('우장호', 'NNP'), [('우', 'IC'), ('장호', 'NNG')]),
#               (('강원일보', 'NNP'), [('강원', 'NNP'), ('일보', 'NNG')]),
#               (('분당서울', 'NNP'), [('분당', 'NNP'), ('서울', 'NNP')]),
#               (('모두투어', 'NNP'), [('모두', 'MAG'), ('투어', 'NNG')]),
#               (('미술전문', 'NNP'), [('미술', 'NNG'), ('전문', 'NNG')]),
#               (('합작법인', 'NNP'), [('합작', 'NNG'), ('법인', 'NNG')]),
#               (('성평등', 'NNP'), [('성', 'NNG'), ('평등', 'NNG')]),
#               (('8시간', 'NNP'), [('8', 'SN'), ('시간', 'NNG')]),
#               (('에어팟프로', 'NNP'),
#                [('에', 'IC'), ('어', 'IC'), ('팟', 'NNG'), ('프로', 'NNG')]),
#               (('얼음벌', 'NNP'), [('얼음', 'NNG'), ('벌', 'NNG')]),
#               (('익스피', 'NNP'), [('익스', 'NNP'), ('피', 'NNG')]),
#               (('턴트', 'NNP'), [('턴', 'VV+ETM'), ('트', 'NNG')]),
#               (('조선총독', 'NNP'), [('조선', 'NNP'), ('총독', 'NNG')]),
#               (('맛집오늘', 'NNP'), [('맛집', 'NNG'), ('오늘', 'NNG')]),
#               (('정기연주', 'NNP'), [('정기연', 'NNP'), ('주', 'NNP')]),
#               (('열대저압', 'NNP'), [('열', 'NR'), ('대', 'NNBC'), ('저압', 'NNG')]),
#               (('대한예수교장로회', 'NNP'),
#                [('대한', 'VV+ETM'), ('예수교', 'NNG'), ('장로회', 'NNG')]),
#               (('3학년', 'NNP'), [('3', 'SN'), ('학년', 'NNG')]),
#               (('아우디폭스바겐', 'NNP'), [('아우디', 'NNP'), ('폭스바겐', 'NNP')]),
#               (('지역문화', 'NNP'), [('지역', 'NNG'), ('문화', 'NNG')]),
#               (('관광객', 'NNP'), [('관광객', 'NNG')]),
#               (('보건의료', 'NNP'), [('보건', 'NNG'), ('의료', 'NNG')]),
#               (('이고요', 'NNP'), [('이', 'MM'), ('고요', 'NNG')]),
#               (('홍보대사', 'NNP'), [('홍보', 'NNG'), ('대사', 'NNG')]),
#               (('상호작용', 'NNP'), [('상호', 'NNG'), ('작용', 'NNG')]),
#               (('서대문형무', 'NNP'), [('서대문', 'NNG'), ('형무', 'NNG')]),
#               (('국가지정', 'NNP'), [('국가', 'NNG'), ('지정', 'NNG')]),
#               (('20년간', 'NNP'), [('20', 'SN'), ('년', 'NNBC'), ('간', 'NNG')]),
#               (('서비스센터', 'NNP'), [('서비스', 'NNG'), ('센터', 'NNG')]),
#               (('네팔', 'NNP'), [('네', 'IC'), ('팔', 'NNG')]),
#               (('장마전선', 'NNP'), [('장마', 'NNG'), ('전선', 'NNG')]),
#               (('운전면허', 'NNP'), [('운전', 'NNG'), ('면허', 'NNG')]),
#               (('서울앤', 'NNP'), [('서울', 'NNP'), ('앤', 'NNG+JX')]),
#               (('싱어송라이터', 'NNP'), [('싱어', 'NNG'), ('송라이터', 'NNP')]),
#               (('리학', 'NNP'), [('리', 'NNP'), ('학', 'NNG')]),
#               (('시장에서', 'NNP'), [('시장', 'NNG'), ('에서', 'JKB')]),
#               (('영화의전당', 'NNP'), [('영화', 'NNG'), ('의', 'JKG'), ('전당', 'NNG')]),
#               (('엠넷', 'NNP'), [('엠', 'NNG'), ('넷', 'NR')]),
#               (('토닌', 'NNP'), [('토', 'NNP'), ('닌', 'NNP')]),
#               (('벤틀', 'NNP'), [('벤', 'NNP'), ('틀', 'NNG')]),
#               (('인공강', 'NNP'), [('인', 'NNG'), ('공강', 'NNG')]),
#               (('단체협약', 'NNP'), [('단체', 'NNG'), ('협약', 'NNG')]),
#               (('눈동', 'NNP'), [('눈', 'NNG'), ('동', 'NNG')]),
#               (('센터페시아', 'NNP'), [('센터', 'NNG'), ('페시아', 'NNP')]),
#               (('절기상', 'NNP'), [('절', 'NNG'), ('기상', 'NNG')]),
#               (('1급', 'NNP'), [('1', 'SN'), ('급', 'NNG')]),
#               (('주행거리', 'NNP'), [('주행', 'NNG'), ('거리', 'NNG')]),
#               (('레알마드리드', 'NNP'), [('레알', 'NNP'), ('마드리드', 'NNP')]),
#               (('이장', 'NNP'), [('이', 'MM'), ('장', 'NNG')]),
#               (('칸영화제', 'NNP'), [('칸', 'NNG'), ('영화제', 'NNG')]),
#               (('유어셀프', 'NNP'), [('유어', 'NNP'), ('셀프', 'NNP')]),
#               (('김포공항', 'NNP'), [('김포', 'NNP'), ('공항', 'NNG')]),
#               (('중북부', 'NNP'), [('중북', 'NNG'), ('부', 'NNG')]),
#               (('브런', 'NNP'), [('브', 'NNP'), ('런', 'NNP')]),
#               (('축구캠프', 'NNP'), [('축구', 'NNG'), ('캠프', 'NNG')]),
#               (('sk엔카', 'NNP'), [('sk', 'SL'), ('엔카', 'NNP')]),
#               (('리튜', 'NNP'), [('리', 'NNP'), ('튜', 'NNP')]),
#               (('국산차', 'NNP'), [('국산', 'NNG'), ('차', 'NNG')]),
#               (('켄싱턴', 'NNP'), [('켄싱', 'NNP'), ('턴', 'NNG')]),
#               (('한국소비', 'NNP'), [('한국', 'NNP'), ('소비', 'NNG')]),
#               (('갤러리아', 'NNP'), [('갤러', 'NNP'), ('리아', 'NNP')]),
#               (('말리부', 'NNP'), [('말', 'NNG'), ('리부', 'NNG')]),
#               (('르셀로', 'NNP'), [('르', 'NNG'), ('셀로', 'NNG')]),
#               (('대표회장', 'NNP'), [('대표', 'NNG'), ('회장', 'NNG')]),
#               (('5층', 'NNP'), [('5', 'SN'), ('층', 'NNG')]),
#               (('박창', 'NNP'), [('박', 'NNP'), ('창', 'NNG')]),
#               (('전자식', 'NNP'), [('전', 'MM'), ('자식', 'NNG')]),
#               (('아르헨', 'NNP'), [('아르', 'NNP'), ('헨', 'NNP')]),
#               (('두터', 'NNP'), [('두', 'MM'), ('터', 'NNG')]),
#               (('아프리카돼지', 'NNP'), [('아프리카', 'NNP'), ('돼지', 'NNG')]),
#               (('아프리카돼지열', 'NNP'),
#                [('아프리카', 'NNP'), ('돼지', 'NNG'), ('열', 'NNG')]),
#               (('안동시', 'NNP'), [('안', 'MAG'), ('동시', 'NNG')]),
#               (('경주시', 'NNP'), [('경주', 'NNP'), ('시', 'NNG')]),
#               (('다이닝', 'NNP'), [('다', 'MAG'), ('이닝', 'NNG')]),
#               (('7시리즈', 'NNP'), [('7', 'SN'), ('시리즈', 'NNG')]),
#               (('생활건강', 'NNP'), [('생활', 'NNG'), ('건강', 'NNG')]),
#               (('글로비스', 'NNP'), [('글', 'NNG'), ('로', 'JKB'), ('비스', 'NNG')]),
#               (('이윤청', 'NNP'), [('이', 'MM'), ('윤청', 'NNP')]),
#               (('소아청소년', 'NNP'), [('소아', 'NNG'), ('청소년', 'NNG')]),
#               (('한마음', 'NNP'), [('한', 'MM'), ('마음', 'NNG')]),
#               (('여행주간', 'NNP'), [('여행', 'NNG'), ('주간', 'NNG')]),
#               (('25전쟁', 'NNP'), [('25', 'SN'), ('전쟁', 'NNG')]),
#               (('시뮬', 'NNP'), [('시', 'NNG'), ('뮬', 'NNG')]),
#               (('궁능', 'NNP'), [('궁', 'NNP'), ('능', 'NNG')]),
#               (('ᆯ로이드', 'NNP'), [('ᆯ로', 'JKB'), ('이드', 'NNG')]),
#               (('학술대회', 'NNP'), [('학술', 'NNG'), ('대회', 'NNG')]),
#               (('끄럽', 'NNP'), [('끄', 'VV'), ('럽', 'NNP')]),
#               (('순복음', 'NNP'), [('순', 'MM'), ('복음', 'NNG')]),
#               (('픽사베이', 'NNP'), [('픽사', 'NNP'), ('베이', 'NNP')]),
#               (('역사문화', 'NNP'), [('역사', 'NNG'), ('문화', 'NNG')]),
#               (('전면부', 'NNP'), [('전', 'MM'), ('면부', 'NNG')]),
#               (('마스크팩', 'NNP'), [('마스크', 'NNG'), ('팩', 'NNG')]),
#               (('무작정', 'NNP'), [('무', 'XPN'), ('작정', 'NNG')]),
#               (('12시간', 'NNP'), [('12', 'SN'), ('시간', 'NNG')]),
#               (('이스탄', 'NNP'), [('이', 'MM'), ('스탄', 'NNP')]),
#               (('김모', 'NNP'), [('김', 'NNP'), ('모', 'NNG')]),
#               (('검은색', 'NNP'), [('검', 'VA'), ('은', 'ETM'), ('색', 'NNG')]),
#               (('회전근', 'NNP'), [('회전', 'NNG'), ('근', 'NNG')]),
#               (('6단', 'NNP'), [('6', 'SN'), ('단', 'NNG')]),
#               (('벤츠코리아', 'NNP'), [('벤츠', 'NNP'), ('코리아', 'NNP')]),
#               (('베닥', 'NNP'), [('베', 'NNG'), ('닥', 'NNG')]),
#               (('의과대학', 'NNP'), [('의과', 'NNG'), ('대학', 'NNG')]),
#               (('프스키', 'NNP'), [('프', 'VX'), ('스키', 'NNG')]),
#               (('히알루', 'NNP'), [('히', 'IC'), ('알루', 'NNP')]),
#               (('심장질환', 'NNP'), [('심장', 'NNG'), ('질환', 'NNG')]),
#               (('사물인터넷', 'NNP'), [('사물', 'NNG'), ('인터넷', 'NNG')]),
#               (('전트', 'NNP'), [('전', 'MM'), ('트', 'NNG')]),
#               (('재단과', 'NNP'), [('재', 'XPN'), ('단과', 'NNG')]),
#               (('컨소시', 'NNP'), [('컨', 'NNP'), ('소시', 'NNG')]),
#               (('삼성서울병원', 'NNP'),
#                [('삼성', 'NNP'), ('서울', 'NNP'), ('병원', 'NNG')]),
#               (('수석부회장', 'NNP'), [('수석', 'NNG'), ('부회장', 'NNG')]),
#               (('무신사', 'NNP'), [('무', 'XPN'), ('신사', 'NNG')]),
#               (('코스메틱', 'NNP'), [('코', 'NNG'), ('스메', 'NNG'), ('틱', 'NNG')]),
#               (('이슈진단', 'NNP'), [('이슈', 'NNG'), ('진단', 'NNG')]),
#               (('셰익스피', 'NNP'), [('셰', 'NNG'), ('익스', 'NNP'), ('피', 'NNG')]),
#               (('3차원', 'NNP'), [('3', 'SN'), ('차원', 'NNG')]),
#               (('휴가지원', 'NNP'), [('휴가', 'NNG'), ('지원', 'NNG')]),
#               (('심뇌혈관', 'NNP'), [('심뇌', 'NNG'), ('혈관', 'NNG')]),
#               (('신약개발', 'NNP'), [('신약', 'NNG'), ('개발', 'NNG')]),
#               (('대상포', 'NNP'), [('대상', 'NNG'), ('포', 'NNG')]),
#               (('예방과', 'NNP'), [('예', 'IC'), ('방과', 'NNG')]),
#               (('꽃망', 'NNP'), [('꽃', 'NNG'), ('망', 'NNG')]),
#               (('잠정합', 'NNP'), [('잠정', 'NNG'), ('합', 'NNG')]),
#               (('아', 'NNP'), [('아', 'IC')]),
#               (('미스트롯', 'NNP'), [('미스', 'NNG'), ('트롯', 'NNG')]),
#               (('어긋', 'NNP'), [('어', 'IC'), ('긋', 'NNG')]),
#               (('사전예약', 'NNP'), [('사전', 'NNG'), ('예약', 'NNG')]),
#               (('쏘카', 'NNP'), [('쏘', 'NNP'), ('카', 'NNG')]),
#               (('쿠킹', 'NNP'), [('쿠', 'NNP'), ('킹', 'NNP')]),
#               (('면역항암', 'NNP'), [('면역', 'NNG'), ('항암', 'NNG')]),
#               (('진흥원이', 'NNP'), [('진흥', 'NNP'), ('원이', 'NNG')]),
#               (('무기력', 'NNP'), [('무', 'XPN'), ('기력', 'NNG')]),
#               (('김효원기자', 'NNP'), [('김효원', 'NNP'), ('기자', 'NNG')]),
#               (('문화콘텐츠', 'NNP'), [('문화', 'NNG'), ('콘텐츠', 'NNG')]),
#               (('최저기온', 'NNP'), [('최저', 'NNG'), ('기온', 'NNG')]),
#               (('8세대', 'NNP'), [('8', 'SN'), ('세대', 'NNG')]),
#               (('의약국', 'NNP'), [('의약', 'NNG'), ('국', 'NNG')]),
#               (('메르세데스벤츠', 'NNP'), [('메르세데스', 'NNP'), ('벤츠', 'NNP')]),
#               (('2학년', 'NNP'), [('2', 'SN'), ('학년', 'NNG')]),
#               (('컨템포', 'NNP'), [('컨', 'NNP'), ('템포', 'NNG')]),
#               (('lg생활건강', 'NNP'),
#                [('lg', 'SL'), ('생활', 'NNG'), ('건강', 'NNG')]),
#               (('만트럭', 'NNP'), [('만', 'NR'), ('트럭', 'NNG')]),
#               (('성소수', 'NNP'), [('성', 'NNG'), ('소수', 'NNG')]),
#               (('삼일', 'NNP'), [('삼', 'NR'), ('일', 'NNBC')]),
#               (('오피아', 'NNP'), [('오', 'NR'), ('피아', 'NNG')]),
#               (('예방접종', 'NNP'), [('예방', 'NNG'), ('접종', 'NNG')]),
#               (('텔루라이', 'NNP'), [('텔', 'NNG'), ('루', 'JKB'), ('라이', 'NNG')]),
#               (('세브란스병원', 'NNP'),
#                [('세브', 'NNP'), ('란스', 'NNP'), ('병원', 'NNG')]),
#               (('연령대', 'NNP'), [('연령', 'NNG'), ('대', 'NNG')]),
#               (('6세대', 'NNP'), [('6', 'SN'), ('세대', 'NNG')]),
#               (('전년대비', 'NNP'), [('전년', 'NNG'), ('대비', 'NNG')]),
#               (('분당서울대병원', 'NNP'),
#                [('분당', 'NNP'), ('서울대', 'NNP'), ('병원', 'NNG')]),
#               (('바르셀로', 'NNP'), [('바르', 'NNG'), ('셀로', 'NNG')]),
#               (('무슬', 'NNP'), [('무', 'XPN'), ('슬', 'NNG')]),
#               (('변해정', 'NNP'), [('변해', 'NNG'), ('정', 'NNG')]),
#               (('허리디스크', 'NNP'), [('허리', 'NNG'), ('디스크', 'NNG')]),
#               (('틀랜드', 'NNP'), [('틀', 'NNG'), ('랜드', 'NNG')]),
#               (('성균관대', 'NNP'), [('성균관', 'NNP'), ('대', 'NNG')]),
#               (('10배', 'NNP'), [('10', 'SN'), ('배', 'NNG')]),
#               (('블라디보', 'NNP'), [('블라', 'NNP'), ('디보', 'NNP')]),
#               (('과학기술원', 'NNP'), [('과학', 'NNG'), ('기술원', 'NNG')]),
#               (('과학회', 'NNP'), [('과', 'NNG'), ('학회', 'NNG')]),
#               (('브스', 'NNP'), [('브', 'NNP'), ('스', 'NNP')]),
#               (('한국수입', 'NNP'), [('한국', 'NNP'), ('수입', 'NNG')]),
#               (('브뤼', 'NNP'), [('브', 'NNP'), ('뤼', 'NNP')]),
#               (('여객터미널', 'NNP'), [('여객', 'NNG'), ('터미널', 'NNG')]),
#               (('연예현장', 'NNP'), [('연예', 'NNG'), ('현장', 'NNG')]),
#               (('후방주', 'NNP'), [('후', 'NNG'), ('방주', 'NNG')]),
#               (('a씨', 'NNP'), [('a', 'SL'), ('씨', 'NNG')]),
#               (('동학농민', 'NNP'), [('동학', 'NNG'), ('농민', 'NNG')]),
#               (('예보가', 'NNP'), [('예', 'IC'), ('보가', 'NNG')]),
#               (('아기자', 'NNP'), [('아', 'IC'), ('기자', 'NNG')]),
#               (('공동주', 'NNP'), [('공동', 'NNG'), ('주', 'NNG')]),
#               (('bmw코리아', 'NNP'), [('bmw', 'SL'), ('코리아', 'NNP')]),
#               (('조현지', 'NNP'), [('조', 'NNG'), ('현지', 'NNG')]),
#               (('한국적', 'NNP'), [('한', 'MM'), ('국적', 'NNG')]),
#               (('유니클', 'NNP'), [('유니', 'NNP'), ('클', 'NNG')]),
#               (('축하공연', 'NNP'), [('축하', 'NNG'), ('공연', 'NNG')]),
#               (('여행상품', 'NNP'), [('여행', 'NNG'), ('상품', 'NNG')]),
#               (('스티벌이', 'NNP'), [('스티', 'NNP'), ('벌이', 'NNG')]),
#               (('송혜', 'NNP'), [('송', 'NNP'), ('혜', 'NNG')]),
#               ...]})

# %%
from konlpy.tag import Mecab

def tokenize(content, compound_dict) :
    mecab = Mecab()
    pos_str = "[" + ", ".join([str(t) for t in mecab.pos(content)]) + "]"
    for pattern in compound_dict :
        src = ", ".join([str(i) for i in pattern[1]])
        tgt = str(pattern[0])
        pos_str = pos_str.replace(src, tgt)

    tokenized_text = eval(pos_str)
    return tokenized_text

# %%
import pickle
import collections
from itertools import takewhile
from nltk import ngrams
from konlpy.tag import Mecab
from collections import defaultdict

def extract_compound(contents, compound_dict, category, ngram_n=7, cutoff = 2, group_by_pos = ['NNP', 'NNG', 'SN', 'SH', 'SL', 'NNBC']) :
    def split_by_pos(content, compound_dict, group_by_pos) :
        tmp = []
        split_li = []
        for t in tokenize(content, compound_dict) :
            if t[1] not in group_by_pos :
                if len(tmp) > 1 :
                    split_li.append(tmp)
                tmp = []
            else :
                tmp.append(t)
        return split_li

    mecab = Mecab()
    
    ngrams_li = []
    for content in contents : 
        splits = split_by_pos(content, compound_dict[category], group_by_pos)
        for split in [s for s in splits] :
            ngrams_li.extend([ngram for n in range(min(ngram_n, len(split)), 1, -1) for ngram in ngrams(split, n)])

    counter = collections.Counter(ngrams_li) #ngram을 빈도별로 집계
    #print(ngram_li)
    ngram_counter =  dict(takewhile(lambda i: i[1] >= cutoff, counter.most_common())) #빈도 cutoff 이상 ngram 추출
    
    # 빈도 우선으로 이미 등록된 ngram을 포함하고 있는 경우는 제외
    dct = defaultdict()
    for item in ngram_counter :        
        chk = next(( False for key in dct.keys() if (set(item).issubset(key)) | (set(key).issubset(item))), True)
        if chk : dct[item] = ngram_counter[item]
    
    ret = []
    for k in dct.keys() :
        word = ' '.join([w[0] for w in k])
        ret.append(((word, 'NNP'), list(k), dct[k]))
        
    return ret

# %%
import pandas as pd
import numpy as np
import multiprocessing as mp
from functools import partial

categories=['정치', '경제', '사회', 'IT과학', '생활문화']

for c in categories :
    print(c)
    df = pd.read_csv("../../data/{}.csv".format(c))
    contents = df['content'].tolist()
    
    print(num_cores)
    num_cores =mp.cpu_count() - 3
    row_split_count = int(len(contents)/num_cores)
    doc_split = [contents[i:i + row_split_count] for i in range(0, len(contents), row_split_count)]
    
    pool = mp.Pool(processes = num_cores)
    compounds = pool.map(partial(extract_compound, compound_dict = compound_dict, category = c, cutoff = 100), doc_split)
    pool.close()
    pool.join()
    
    compounds = [comp for l in compounds for comp in l]    
    
    pickle_out = open('tmp_ngram_{}.pickle'.format(c),"wb")
    pickle.dump(compounds, pickle_out)
    pickle_out.close()
# Out:
# 정치
# 13
# 경제
# 13
# 사회
# 13

# %%
import pickle

pickle_in = open('tmp_ngram_{}.pickle'.format('정치'),"rb")
ngram = pickle.load(pickle_in)
ngram
# Out:
# [(('flash 오류', 'NNP'), [('flash', 'SL'), ('오류', 'NNG')], 769),
#  (('함수 추가 function', 'NNP'),
#   [('함수', 'NNG'), ('추가', 'NNG'), ('function', 'SL')],
#   769),
#  (('3 일', 'NNP'), [('3', 'SN'), ('일', 'NNBC')], 688),
#  (('2 차', 'NNP'), [('2', 'SN'), ('차', 'NNBC')], 601),
#  (('김 위원장', 'NNP'), [('김', 'NNP'), ('위원장', 'NNP')], 565),
#  (('무단 전재', 'NNP'), [('무단', 'NNG'), ('전재', 'NNG')], 517),
#  (('배포 금지', 'NNP'), [('배포', 'NNG'), ('금지', 'NNG')], 455),
#  (('트럼프 대통령', 'NNP'), [('트럼프', 'NNG'), ('대통령', 'NNP')], 363),
#  (('독수리 훈련', 'NNP'), [('독수리', 'NNG'), ('훈련', 'NNG')], 325),
#  (('차 북미정상회담', 'NNP'), [('차', 'NNBC'), ('북미정상회담', 'NNP')], 314),
#  (('4 일', 'NNP'), [('4', 'SN'), ('일', 'NNBC')], 289),
#  (('채널 구독', 'NNP'), [('채널', 'NNG'), ('구독', 'NNG')], 286),
#  (('기자 회견', 'NNP'), [('기자', 'NNP'), ('회견', 'NNG')], 279),
#  (('개학 연기', 'NNP'), [('개학', 'NNG'), ('연기', 'NNG')], 278),
#  (('정상 회담', 'NNP'), [('정상', 'NNG'), ('회담', 'NNG')], 276),
#  (('2 일', 'NNP'), [('2', 'SN'), ('일', 'NNBC')], 270),
#  (('일 오후', 'NNP'), [('일', 'NNBC'), ('오후', 'NNG')], 265),
#  (('28 일', 'NNP'), [('28', 'SN'), ('일', 'NNBC')], 240),
#  (('news 1', 'NNP'), [('news', 'SL'), ('1', 'SN')], 234),
#  (('3 월', 'NNP'), [('3', 'SN'), ('월', 'NNBC')], 228),
#  (('문 대통령', 'NNP'), [('문', 'NNG'), ('대통령', 'NNP')], 221),
#  (('북한 국무위원장', 'NNP'), [('북한', 'NNP'), ('국무위원장', 'NNP')], 219),
#  (('도널드 트럼프', 'NNP'), [('도널드', 'NNP'), ('트럼프', 'NNP')], 218),
#  (('네이버 홈', 'NNP'), [('네이버', 'NNP'), ('홈', 'NNG')], 215),
#  (('네이버 메인', 'NNP'), [('네이버', 'NNP'), ('메인', 'NNP')], 187),
#  (('쇼 미더뉴스', 'NNP'), [('쇼', 'NNG'), ('미더뉴스', 'NNP')], 180),
#  (('1 일', 'NNP'), [('1', 'SN'), ('일', 'NNBC')], 180),
#  (('미국 대통령', 'NNP'), [('미국', 'NNP'), ('대통령', 'NNP')], 172),
#  (('공감 언론 뉴시스 통신사', 'NNP'),
#   [('공감', 'NNG'), ('언론', 'NNP'), ('뉴시스', 'NNP'), ('통신사', 'NNG')],
#   158),
#  (('키리졸브 연습', 'NNP'), [('키리졸브', 'NNP'), ('연습', 'NNG')], 155),
#  (('트럼프 미국', 'NNP'), [('트럼프', 'NNP'), ('미국', 'NNP')], 153),
#  (('베트남 하노이', 'NNP'), [('베트남', 'NNP'), ('하노이', 'NNP')], 150),
#  (('문재인 대통령', 'NNP'), [('문재인', 'NNP'), ('대통령', 'NNP')], 149),
#  (('일 오전', 'NNP'), [('일', 'NNBC'), ('오전', 'NNG')], 147),
#  (('한국 유치원', 'NNP'), [('한국', 'NNP'), ('유치원', 'NNG')], 142),
#  (('유치원 3법', 'NNP'), [('유치원', 'NNG'), ('3법', 'NNP')], 139),
#  (('국방 당국', 'NNP'), [('국방', 'NNG'), ('당국', 'NNG')], 138),
#  (('국회 정론관', 'NNP'), [('국회', 'NNG'), ('정론관', 'NNP')], 129),
#  (('유치원 총연합회', 'NNP'), [('유치원', 'NNG'), ('총연합회', 'NNP')], 128),
#  (('차 회담', 'NNP'), [('차', 'NNBC'), ('회담', 'NNG')], 126),
#  (('북미 2', 'NNP'), [('북미', 'NNP'), ('2', 'SN')], 124),
#  (('하노이 회담', 'NNP'), [('하노이', 'NNP'), ('회담', 'NNG')], 120),
#  (('뉴스1 코리아', 'NNP'), [('뉴스1', 'NNP'), ('코리아', 'NNP')], 120),
#  (('MWC 2019', 'NNP'), [('MWC', 'SL'), ('2019', 'SN')], 119),
#  (('지난달 28', 'NNP'), [('지난달', 'NNG'), ('28', 'SN')], 118),
#  (('회담 결렬', 'NNP'), [('회담', 'NNG'), ('결렬', 'NNG')], 113),
#  (('영변 핵시설', 'NNP'), [('영변', 'NNG'), ('핵시설', 'NNP')], 109),
#  (('현지 시간', 'NNP'), [('현지', 'NNG'), ('시간', 'NNG')], 108),
#  (('북미 회담', 'NNP'), [('북미', 'NNP'), ('회담', 'NNG')], 108),
#  (('지휘소 연습', 'NNP'), [('지휘소', 'NNG'), ('연습', 'NNG')], 107),
#  (('일 베트남', 'NNP'), [('일', 'NNBC'), ('베트남', 'NNP')], 101),
#  (('국회 교육위원회', 'NNP'), [('국회', 'NNG'), ('교육위원회', 'NNP')], 101),
#  (('민주당 의원', 'NNP'), [('민주당', 'NNP'), ('의원', 'NNP')], 96),
#  (('유치원 개학', 'NNP'), [('유치원', 'NNG'), ('개학', 'NNG')], 94),
#  (('월 국회', 'NNP'), [('월', 'NNBC'), ('국회', 'NNG')], 92),
#  (('7 일', 'NNP'), [('7', 'SN'), ('일', 'NNBC')], 90),
#  (('2 월', 'NNP'), [('2', 'SN'), ('월', 'NNBC')], 89),
#  (('김정은 국무위원장', 'NNP'), [('김정은', 'NNP'), ('국무위원장', 'NNP')], 88),
#  (('5 일', 'NNP'), [('5', 'SN'), ('일', 'NNBC')], 86),
#  (('여의도 국회', 'NNP'), [('여의도', 'NNP'), ('국회', 'NNG')], 86),
#  (('한미연합 훈련', 'NNP'), [('한미연합', 'NNP'), ('훈련', 'NNG')], 84),
#  (('친선 방문', 'NNP'), [('친선', 'NNG'), ('방문', 'NNG')], 84),
#  (('전용 열차', 'NNP'), [('전용', 'NNG'), ('열차', 'NNG')], 80),
#  (('정경두 국방부장관', 'NNP'), [('정경두', 'NNP'), ('국방부장관', 'NNP')], 78),
#  (('내년 총선', 'NNP'), [('내년', 'NNG'), ('총선', 'NNG')], 78),
#  (('김 대변인', 'NNP'), [('김', 'NNP'), ('대변인', 'NNG')], 77),
#  (('차 북', 'NNP'), [('차', 'NNBC'), ('북', 'NNG')], 76),
#  (('1 월', 'NNP'), [('1', 'SN'), ('월', 'NNBC')], 74),
#  (('Foal Eagle', 'NNP'), [('Foal', 'SL'), ('Eagle', 'SL')], 73),
#  (('이번 회담', 'NNP'), [('이번', 'NNG'), ('회담', 'NNG')], 73),
#  (('공식 친선', 'NNP'), [('공식', 'NNG'), ('친선', 'NNG')], 72),
#  (('트럼프 대통령', 'NNP'), [('트럼프', 'NNP'), ('대통령', 'NNP')], 70),
#  (('김정은 위원장', 'NNP'), [('김정은', 'NNP'), ('위원장', 'NNP')], 70),
#  (('베트남 방문', 'NNP'), [('베트남', 'NNP'), ('방문', 'NNG')], 70),
#  (('개학 무기', 'NNP'), [('개학', 'NNG'), ('무기', 'NNG')], 70),
#  (('뉴시스 채널', 'NNP'), [('뉴시스', 'NNP'), ('채널', 'NNG')], 69),
#  (('뉴시스 빅 데이터 MSI 주가 시세표', 'NNP'),
#   [('뉴시스', 'NNP'),
#    ('빅', 'NNP'),
#    ('데이터', 'NNG'),
#    ('MSI', 'SL'),
#    ('주가', 'NNG'),
#    ('시세표', 'NNG')],
#   69),
#  (('박영태 기자', 'NNP'), [('박영태', 'NNP'), ('기자', 'NNP')], 69),
#  (('since 1999', 'NNP'), [('since', 'SL'), ('1999', 'SN')], 69),
#  (('핵시설 폐기', 'NNP'), [('핵시설', 'NNP'), ('폐기', 'NNG')], 68),
#  (('서울 경제', 'NNP'), [('서울', 'NNP'), ('경제', 'NNG')], 68),
#  (('News 1', 'NNP'), [('News', 'SL'), ('1', 'SN')], 68),
#  (('리용 호', 'NNP'), [('리용', 'NNG'), ('호', 'NNBC')], 67),
#  (('KR 연습', 'NNP'), [('KR', 'SL'), ('연습', 'NNG')], 67),
#  (('2017 년', 'NNP'), [('2017', 'SN'), ('년', 'NNBC')], 66),
#  (('100 주년', 'NNP'), [('100', 'SN'), ('주년', 'NNBC')], 66),
#  (('연기 선언', 'NNP'), [('연기', 'NNG'), ('선언', 'NNG')], 66),
#  (('황 대표', 'NNP'), [('황', 'NNG'), ('대표', 'NNP')], 66),
#  (('한미 국방', 'NNP'), [('한미', 'NNG'), ('국방', 'NNG')], 65),
#  (('패스트 트랙', 'NNP'), [('패스트', 'NNG'), ('트랙', 'NNG')], 65),
#  (('연합 지휘소', 'NNP'), [('연합', 'NNG'), ('지휘소', 'NNG')], 64),
#  (('청와대 대변인', 'NNP'), [('청와대', 'NNP'), ('대변인', 'NNG')], 63),
#  (('머니 투데이', 'NNP'), [('머니', 'NNP'), ('투데이', 'NNP')], 63),
#  (('오후 국회', 'NNP'), [('오후', 'NNG'), ('국회', 'NNG')], 61),
#  (('연합방위 태세', 'NNP'), [('연합방위', 'NNP'), ('태세', 'NNG')], 60),
#  (('12 일', 'NNP'), [('12', 'SN'), ('일', 'NNBC')], 59),
#  (('오전 서울', 'NNP'), [('오전', 'NNG'), ('서울', 'NNP')], 59),
#  (('아시아 경제', 'NNP'), [('아시아', 'NNP'), ('경제', 'NNG')], 59),
#  (('제재 해제', 'NNP'), [('제재', 'NNG'), ('해제', 'NNG')], 58),
#  (('오후 서울', 'NNP'), [('오후', 'NNG'), ('서울', 'NNP')], 57),
#  (('메트로폴 호텔', 'NNP'), [('메트로폴', 'NNP'), ('호텔', 'NNG')], 56),
#  (('자료 사진', 'NNP'), [('자료', 'NNG'), ('사진', 'NNG')], 56),
#  (('조선중앙 통신', 'NNP'), [('조선중앙', 'NNP'), ('통신', 'NNG')], 56),
#  (('교섭본부 장', 'NNP'), [('교섭본부', 'NNP'), ('장', 'NNP')], 56),
#  (('에듀 파인', 'NNP'), [('에듀', 'NNP'), ('파인', 'NNG')], 56),
#  (('소규모 부대', 'NNP'), [('소규모', 'NNP'), ('부대', 'NNG')], 55),
#  (('일 간', 'NNP'), [('일', 'NNBC'), ('간', 'NNG')], 55),
#  (('장관 후보', 'NNP'), [('장관', 'NNP'), ('후보', 'NNG')], 55),
#  (('집단 행동', 'NNP'), [('집단', 'NNG'), ('행동', 'NNG')], 55),
#  (('방문 일정', 'NNP'), [('방문', 'NNG'), ('일정', 'NNG')], 54),
#  (('Key Resolve', 'NNP'), [('Key', 'SL'), ('Resolve', 'SL')], 54),
#  (('베트남 공식', 'NNP'), [('베트남', 'NNP'), ('공식', 'NNG')], 54),
#  (('27 일', 'NNP'), [('27', 'SN'), ('일', 'NNBC')], 53),
#  (('TV 조선', 'NNP'), [('TV', 'SL'), ('조선', 'NNP')], 53),
#  (('한반도평화 교섭본부', 'NNP'), [('한반도평화', 'NNP'), ('교섭본부', 'NNP')], 53),
#  (('무기 연기', 'NNP'), [('무기', 'NNG'), ('연기', 'NNG')], 53),
#  (('월 임시국회', 'NNP'), [('월', 'NNBC'), ('임시국회', 'NNP')], 53),
#  (('6 월', 'NNP'), [('6', 'SN'), ('월', 'NNBC')], 52),
#  (('국가안전 보장', 'NNP'), [('국가안전', 'NNP'), ('보장', 'NNG')], 52),
#  (('국방부장관 대행', 'NNP'), [('국방부장관', 'NNP'), ('대행', 'NNG')], 51),
#  (('보장 회의', 'NNP'), [('보장', 'NNG'), ('회의', 'NNG')], 51),
#  (('외기 동훈련', 'NNP'), [('외기', 'NNG'), ('동훈련', 'NNG')], 50),
#  (('4 월', 'NNP'), [('4', 'SN'), ('월', 'NNBC')], 50),
#  (('북한 매체', 'NNP'), [('북한', 'NNP'), ('매체', 'NNG')], 50),
#  (('서울 여의도', 'NNP'), [('서울', 'NNP'), ('여의도', 'NNP')], 50),
#  (('비핵화 협상', 'NNP'), [('비핵화', 'NNG'), ('협상', 'NNG')], 49),
#  (('대비 태세', 'NNP'), [('대비', 'NNG'), ('태세', 'NNG')], 49),
#  (('대응 방안', 'NNP'), [('대응', 'NNG'), ('방안', 'NNG')], 49),
#  (('한반도 비핵화', 'NNP'), [('한반도', 'NNP'), ('비핵화', 'NNG')], 49),
#  (('꿀 잼', 'NNP'), [('꿀', 'NNG'), ('잼', 'NNG')], 49),
#  (('김 의원', 'NNP'), [('김', 'NNP'), ('의원', 'NNP')], 49),
#  (('전략 무기', 'NNP'), [('전략', 'NNG'), ('무기', 'NNG')], 48),
#  (('군 당국', 'NNP'), [('군', 'NNG'), ('당국', 'NNG')], 48),
#  (('10 시', 'NNP'), [('10', 'SN'), ('시', 'NNBC')], 48),
#  (('한미 양국', 'NNP'), [('한미', 'NNG'), ('양국', 'NNG')], 48),
#  (('기관지 노동신문', 'NNP'), [('기관지', 'NNG'), ('노동신문', 'NNP')], 48),
#  (('민주당 국회', 'NNP'), [('민주당', 'NNP'), ('국회', 'NNG')], 48),
#  (('미 연합훈련', 'NNP'), [('미', 'NNG'), ('연합훈련', 'NNP')], 47),
#  (('훈련 종료', 'NNP'), [('훈련', 'NNG'), ('종료', 'NNG')], 47),
#  (('동맹 연습', 'NNP'), [('동맹', 'NNG'), ('연습', 'NNG')], 47),
#  (('12 월', 'NNP'), [('12', 'SN'), ('월', 'NNBC')], 47),
#  (('주요국 대사', 'NNP'), [('주요국', 'NNP'), ('대사', 'NNG')], 47),
#  (('정치 활동', 'NNP'), [('정치', 'NNG'), ('활동', 'NNG')], 47),
#  (('제재 완화', 'NNP'), [('제재', 'NNG'), ('완화', 'NNG')], 46),
#  (('외교부 한반도평화', 'NNP'), [('외교부', 'NNP'), ('한반도평화', 'NNP')], 46),
#  (('노동당 기관지', 'NNP'), [('노동당', 'NNG'), ('기관지', 'NNG')], 45),
#  (('이도훈 외교부', 'NNP'), [('이도훈', 'NNP'), ('외교부', 'NNP')], 45),
#  (('유치원 대란', 'NNP'), [('유치원', 'NNG'), ('대란', 'NNG')], 45),
#  (('교육 위원장', 'NNP'), [('교육', 'NNG'), ('위원장', 'NNP')], 45),
#  (('서울 영등포구', 'NNP'), [('서울', 'NNP'), ('영등포구', 'NNP')], 45),
#  (('영등포구 여의도', 'NNP'), [('영등포구', 'NNP'), ('여의도', 'NNP')], 45),
#  (('귀국 길', 'NNP'), [('귀국', 'NNG'), ('길', 'NNG')], 44),
#  (('1 년', 'NNP'), [('1', 'SN'), ('년', 'NNBC')], 44),
#  (('유튜브 채널', 'NNP'), [('유튜브', 'NNP'), ('채널', 'NNG')], 44),
#  (('회담 결과', 'NNP'), [('회담', 'NNG'), ('결과', 'NNG')], 43),
#  (('마이크 폼페이', 'NNP'), [('마이크', 'NNG'), ('폼페이', 'NNG')], 43),
#  (('통일부 장관', 'NNP'), [('통일부', 'NNG'), ('장관', 'NNP')], 43),
#  (('호 외무상', 'NNP'), [('호', 'NNBC'), ('외무상', 'NNP')], 42),
#  (('차 정상', 'NNP'), [('차', 'NNBC'), ('정상', 'NNG')], 42),
#  (('국회 교육', 'NNP'), [('국회', 'NNG'), ('교육', 'NNG')], 42),
#  (('북미정상회담 결렬', 'NNP'), [('북미정상회담', 'NNP'), ('결렬', 'NNG')], 41),
#  (('미국 국방부장관', 'NNP'), [('미국', 'NNP'), ('국방부장관', 'NNP')], 41),
#  (('북한 비핵화', 'NNP'), [('북한', 'NNP'), ('비핵화', 'NNG')], 40),
#  (('검증 가능', 'NNP'), [('검증', 'NNG'), ('가능', 'NNG')], 39),
#  (('연합뉴스 자료', 'NNP'), [('연합뉴스', 'NNP'), ('자료', 'NNG')], 39),
#  (('역사 속', 'NNP'), [('역사', 'NNG'), ('속', 'NNG')], 39),
#  (('핵 담판', 'NNP'), [('핵', 'NNG'), ('담판', 'NNG')], 39),
#  (('북한 노동당', 'NNP'), [('북한', 'NNP'), ('노동당', 'NNG')], 39),
#  (('김부겸 행정', 'NNP'), [('김부겸', 'NNP'), ('행정', 'NNG')], 39),
#  (('소셜 미디어', 'NNP'), [('소셜', 'NNG'), ('미디어', 'NNG')], 39),
#  (('임세영 기자', 'NNP'), [('임세영', 'NNP'), ('기자', 'NNP')], 39),
#  (('한미 연합군', 'NNP'), [('한미', 'NNG'), ('연합군', 'NNG')], 38),
#  (('45 분', 'NNP'), [('45', 'SN'), ('분', 'NNBC')], 38),
#  (('부대 위주', 'NNP'), [('부대', 'NNG'), ('위주', 'NNG')], 38),
#  (('과학기술정보 통신부', 'NNP'), [('과학기술정보', 'NNP'), ('통신부', 'NNG')], 38),
#  (('대통령 비서실장', 'NNP'), [('대통령', 'NNP'), ('비서실장', 'NNP')], 38),
#  (('사립유치원 개학', 'NNP'), [('사립유치원', 'NNP'), ('개학', 'NNG')], 38),
#  (('교육위원회 소속', 'NNP'), [('교육위원회', 'NNP'), ('소속', 'NNG')], 38),
#  (('바른미래 당', 'NNP'), [('바른미래', 'NNP'), ('당', 'NNG')], 38),
#  (('외무성 부상', 'NNP'), [('외무성', 'NNG'), ('부상', 'NNG')], 37),
#  (('지난달 27', 'NNP'), [('지난달', 'NNG'), ('27', 'SN')], 37),
#  (('이번 결정', 'NNP'), [('이번', 'NNG'), ('결정', 'NNG')], 37),
#  (('1 차', 'NNP'), [('1', 'SN'), ('차', 'NNBC')], 37),
#  (('중재 역할', 'NNP'), [('중재', 'NNG'), ('역할', 'NNG')], 37),
#  (('이번주 후반', 'NNP'), [('이번주', 'NNP'), ('후반', 'NNG')], 37),
#  (('전 대표', 'NNP'), [('전', 'NNG'), ('대표', 'NNP')], 37),
#  (('정치자금 법', 'NNP'), [('정치자금', 'NNP'), ('법', 'NNG')], 37),
#  (('멜리아 호텔', 'NNP'), [('멜리아', 'NNP'), ('호텔', 'NNG')], 36),
#  (('2008 년', 'NNP'), [('2008', 'SN'), ('년', 'NNBC')], 36),
#  (('동영상 뉴스', 'NNP'), [('동영상', 'NNG'), ('뉴스', 'NNG')], 36),
#  (('종합 경제 정보 미디어', 'NNP'),
#   [('종합', 'NNG'), ('경제', 'NNG'), ('정보', 'NNG'), ('미디어', 'NNG')],
#   36),
#  (('개 부처', 'NNP'), [('개', 'NNBC'), ('부처', 'NNG')], 36),
#  (('국토 교통부', 'NNP'), [('국토', 'NNG'), ('교통부', 'NNP')], 36),
#  (('교육위원회 위원', 'NNP'), [('교육위원회', 'NNP'), ('위원', 'NNP')], 36),
#  (('북한 김정은', 'NNP'), [('북한', 'NNP'), ('김정은', 'NNP')], 35),
#  (('북미정상회담 결과', 'NNP'), [('북미정상회담', 'NNP'), ('결과', 'NNG')], 35),
#  (('군사 대비', 'NNP'), [('군사', 'NNG'), ('대비', 'NNG')], 35),
#  (('결렬 이후', 'NNP'), [('결렬', 'NNG'), ('이후', 'NNG')], 35),
#  (('NSC 전체회의', 'NNP'), [('NSC', 'SL'), ('전체회의', 'NNP')], 35),
#  (('본부 장', 'NNP'), [('본부', 'NNG'), ('장', 'NNP')], 35),
#  (('FE 훈련', 'NNP'), [('FE', 'SL'), ('훈련', 'NNG')], 35),
#  (('한글 명칭', 'NNP'), [('한글', 'NNG'), ('명칭', 'NNG')], 35),
#  (('월 국회정상', 'NNP'), [('월', 'NNBC'), ('국회정상', 'NNP')], 35),
#  (('경제 채널', 'NNP'), [('경제', 'NNG'), ('채널', 'NNG')], 34),
#  (('연중 실시', 'NNP'), [('연중', 'NNG'), ('실시', 'NNG')], 34),
#  (('2 면', 'NNP'), [('2', 'SN'), ('면', 'NNG')], 34),
#  (('대북 특별대표', 'NNP'), [('대북', 'NNG'), ('특별대표', 'NNP')], 34),
#  (('손혜원 의원', 'NNP'), [('손혜원', 'NNP'), ('의원', 'NNP')], 34),
#  (('슈퍼 챗', 'NNP'), [('슈퍼', 'NNG'), ('챗', 'NNG')], 34),
#  (('8 월', 'NNP'), [('8', 'SN'), ('월', 'NNBC')], 33),
#  (('조승래 간사', 'NNP'), [('조승래', 'NNP'), ('간사', 'NNG')], 33),
#  (('주중 대사', 'NNP'), [('주중', 'NNG'), ('대사', 'NNG')], 33),
#  (('14 일', 'NNP'), [('14', 'SN'), ('일', 'NNBC')], 32),
#  (('국무부 대북', 'NNP'), [('국무부', 'NNG'), ('대북', 'NNG')], 32),
#  (('청와대 정책실장', 'NNP'), [('청와대', 'NNP'), ('정책실장', 'NNP')], 32),
#  (('2016 년', 'NNP'), [('2016', 'SN'), ('년', 'NNBC')], 32),
#  (('8 일', 'NNP'), [('8', 'SN'), ('일', 'NNBC')], 32),
#  (('1961 년', 'NNP'), [('1961', 'SN'), ('년', 'NNBC')], 31),
#  (('훈련 조정', 'NNP'), [('훈련', 'NNG'), ('조정', 'NNG')], 31),
#  (('이낙연 국무총리', 'NNP'), [('이낙연', 'NNP'), ('국무총리', 'NNG')], 31),
#  (('1 운동', 'NNP'), [('1', 'SN'), ('운동', 'NNG')], 31),
#  (('여야 3당', 'NNP'), [('여야', 'NNG'), ('3당', 'NNP')], 31),
#  (('박 의원', 'NNP'), [('박', 'NNP'), ('의원', 'NNP')], 31),
#  (('비핵화 조치', 'NNP'), [('비핵화', 'NNG'), ('조치', 'NNG')], 30),
#  (('프리덤 가디언', 'NNP'), [('프리덤', 'NNP'), ('가디언', 'NNP')], 30),
#  (('훈련 중단', 'NNP'), [('훈련', 'NNG'), ('중단', 'NNG')], 30),
#  (('주일 대사', 'NNP'), [('주일', 'NNG'), ('대사', 'NNG')], 30),
#  (('연합뉴스 TV', 'NNP'), [('연합뉴스', 'NNP'), ('TV', 'SL')], 30),
#  (('일 서울', 'NNP'), [('일', 'NNBC'), ('서울', 'NNP')], 30),
#  (('유아 교육', 'NNP'), [('유아', 'NNG'), ('교육', 'NNG')], 30),
#  (('CBS 노컷뉴스', 'NNP'), [('CBS', 'SL'), ('노컷뉴스', 'NNP')], 30),
#  (('18 망언', 'NNP'), [('18', 'SN'), ('망언', 'NNG')], 30),
#  (('오후 10', 'NNP'), [('오후', 'NNG'), ('10', 'SN')], 29),
#  (('2007 년', 'NNP'), [('2007', 'SN'), ('년', 'NNBC')], 29),
#  (('태세 유지', 'NNP'), [('태세', 'NNG'), ('유지', 'NNG')], 29),
#  (('침 해소', 'NNP'), [('침', 'NNG'), ('해소', 'NNG')], 29),
#  (('청춘뉘 우스', 'NNP'), [('청춘뉘', 'NNP'), ('우스', 'NNG')], 29),
#  (('현역 의원', 'NNP'), [('현역', 'NNG'), ('의원', 'NNP')], 29),
#  (('대안 학교', 'NNP'), [('대안', 'NNG'), ('학교', 'NNG')], 29),
#  (('남 탓', 'NNP'), [('남', 'NNG'), ('탓', 'NNG')], 29),
#  (('차 북미', 'NNP'), [('차', 'NNBC'), ('북미', 'NNP')], 28),
#  (('1975 년', 'NNP'), [('1975', 'SN'), ('년', 'NNBC')], 28),
#  (('일 새벽', 'NNP'), [('일', 'NNBC'), ('새벽', 'NNG')], 28),
#  (('담판 결렬', 'NNP'), [('담판', 'NNG'), ('결렬', 'NNG')], 28),
#  (('일 보도', 'NNP'), [('일', 'NNBC'), ('보도', 'NNG')], 28),
#  (('지난해 12', 'NNP'), [('지난해', 'NNG'), ('12', 'SN')], 28),
#  (('존 볼턴', 'NNP'), [('존', 'NNP'), ('볼턴', 'NNP')], 27),
#  (('북 정상', 'NNP'), [('북', 'NNP'), ('정상', 'NNG')], 27),
#  (('지난해 6', 'NNP'), [('지난해', 'NNG'), ('6', 'SN')], 27),
#  (('명칭 변경', 'NNP'), [('명칭', 'NNG'), ('변경', 'NNG')], 27),
#  (('훈련 명칭', 'NNP'), [('훈련', 'NNG'), ('명칭', 'NNG')], 27),
#  (('the 300', 'NNP'), [('the', 'SL'), ('300', 'SN')], 27),
#  (('대화 재개', 'NNP'), [('대화', 'NNG'), ('재개', 'NNG')], 27),
#  (('총선 출마', 'NNP'), [('총선', 'NNG'), ('출마', 'NNG')], 27),
#  (('강경화 외교부 장관', 'NNP'), [('강경화', 'NNP'), ('외교부', 'NNP'), ('장관', 'NNP')], 27),
#  (('22 일', 'NNP'), [('22', 'SN'), ('일', 'NNBC')], 27),
#  (('고승민 기자', 'NNP'), [('고승민', 'NNP'), ('기자', 'NNP')], 27),
#  (('kkssmm 99', 'NNP'), [('kkssmm', 'SL'), ('99', 'SN')], 27),
#  (('국당 대표', 'NNP'), [('국당', 'NNP'), ('대표', 'NNP')], 27),
#  (('홍 전', 'NNP'), [('홍', 'NNG'), ('전', 'NNG')], 27),
#  (('황교안 대표', 'NNP'), [('황교안', 'NNP'), ('대표', 'NNP')], 27),
#  (('뉴스1 seiyu', 'NNP'), [('뉴스1', 'NNP'), ('seiyu', 'SL')], 27),
#  (('26 일', 'NNP'), [('26', 'SN'), ('일', 'NNBC')], 26),
#  (('한미연합 군사훈련', 'NNP'), [('한미연합', 'NNP'), ('군사훈련', 'NNP')], 26),
#  (('연합 군사훈련', 'NNP'), [('연합', 'NNG'), ('군사훈련', 'NNP')], 26),
#  (('5 월', 'NNP'), [('5', 'SN'), ('월', 'NNBC')], 26),
#  (('11 년', 'NNP'), [('11', 'SN'), ('년', 'NNBC')], 26),
#  (('44 년', 'NNP'), [('44', 'SN'), ('년', 'NNBC')], 26),
#  (('센터 장', 'NNP'), [('센터', 'NNG'), ('장', 'NNP')], 26),
#  (('조 변호사', 'NNP'), [('조', 'NNG'), ('변호사', 'NNG')], 26),
#  (('봄맞이 선물 주나봄', 'NNP'), [('봄맞이', 'NNG'), ('선물', 'NNG'), ('주나봄', 'NNP')], 26),
#  (('리얼타임 뉴스', 'NNP'), [('리얼타임', 'NNG'), ('뉴스', 'NNG')], 26),
#  (('향후 대응', 'NNP'), [('향후', 'NNG'), ('대응', 'NNG')], 26),
#  (('일 김정은', 'NNP'), [('일', 'NNBC'), ('김정은', 'NNP')], 26),
#  (('유아교육법 시행령', 'NNP'), [('유아교육법', 'NNP'), ('시행령', 'NNG')], 26),
#  (('For Use Only in the Republic of', 'NNP'),
#   [('For', 'SL'),
#    ('Use', 'SL'),
#    ('Only', 'SL'),
#    ('in', 'SL'),
#    ('the', 'SL'),
#    ('Republic', 'SL'),
#    ('of', 'SL')],
#   26),
#  (('Use Only in the Republic of Korea', 'NNP'),
#   [('Use', 'SL'),
#    ('Only', 'SL'),
#    ('in', 'SL'),
#    ('the', 'SL'),
#    ('Republic', 'SL'),
#    ('of', 'SL'),
#    ('Korea', 'SL')],
#   26),
#  (('No Redistribution', 'NNP'), [('No', 'SL'), ('Redistribution', 'SL')], 26),
#  (('TV 홍카콜라', 'NNP'), [('TV', 'SL'), ('홍카콜라', 'NNP')], 26),
#  (('이찬열 국회', 'NNP'), [('이찬열', 'NNP'), ('국회', 'NNG')], 26),
#  (('임춘한 기자', 'NNP'), [('임춘한', 'NNP'), ('기자', 'NNP')], 26),
#  (('규모 연합훈련', 'NNP'), [('규모', 'NNG'), ('연합훈련', 'NNP')], 25),
#  (('미 국방', 'NNP'), [('미', 'NNG'), ('국방', 'NNG')], 25),
#  (('동훈련 방식', 'NNP'), [('동훈련', 'NNG'), ('방식', 'NNG')], 25),
#  (('주한미군 사령관', 'NNP'), [('주한미군', 'NNP'), ('사령관', 'NNG')], 25),
#  (('미사일 실험', 'NNP'), [('미사일', 'NNG'), ('실험', 'NNG')], 25),
#  (('중폭 개각', 'NNP'), [('중폭', 'NNG'), ('개각', 'NNG')], 25),
#  (('TV 제공', 'NNP'), [('TV', 'SL'), ('제공', 'NNG')], 25),
#  (('중재 안', 'NNP'), [('중재', 'NNG'), ('안', 'NNG')], 25),
#  (('협상 결렬', 'NNP'), [('협상', 'NNG'), ('결렬', 'NNG')], 24),
#  (('한미 군', 'NNP'), [('한미', 'NNG'), ('군', 'NNG')], 24),
#  (('회담 직후', 'NNP'), [('회담', 'NNG'), ('직후', 'NNG')], 24),
#  (('한국 경제', 'NNP'), [('한국', 'NNP'), ('경제', 'NNG')], 24),
#  (('년 3', 'NNP'), [('년', 'NNBC'), ('3', 'SN')], 24),
#  (('5 건', 'NNP'), [('5', 'SN'), ('건', 'NNBC')], 24),
#  (('2018 년', 'NNP'), [('2018', 'SN'), ('년', 'NNBC')], 24),
#  (('안보 공약', 'NNP'), [('안보', 'NNG'), ('공약', 'NNG')], 24),
#  (('협상 과정에서', 'NNP'), [('협상', 'NNG'), ('과정에서', 'NNP')], 24),
#  (('현지 시각', 'NNP'), [('현지', 'NNG'), ('시각', 'NNG')], 24),
#  (('30 분', 'NNP'), [('30', 'SN'), ('분', 'NNBC')], 24),
#  (('친선 협조', 'NNP'), [('친선', 'NNG'), ('협조', 'NNG')], 24),
#  (('이날 오후', 'NNP'), [('이날', 'NNG'), ('오후', 'NNG')], 24),
#  (('베트남 국빈방문 일정', 'NNP'),
#   [('베트남', 'NNP'), ('국빈방문', 'NNP'), ('일정', 'NNG')],
#   24),
#  (('베트남 랑선', 'NNP'), [('베트남', 'NNP'), ('랑선', 'NNG')], 24),
#  (('일 국회', 'NNP'), [('일', 'NNBC'), ('국회', 'NNG')], 24),
#  (('1절 기념식', 'NNP'), [('1절', 'NNP'), ('기념식', 'NNG')], 24),
#  (('원내 대표', 'NNP'), [('원내', 'NNG'), ('대표', 'NNP')], 24),
#  (('정치자금 법상', 'NNP'), [('정치자금', 'NNP'), ('법상', 'NNG')], 24),
#  (('국회 개원', 'NNP'), [('국회', 'NNG'), ('개원', 'NNG')], 24),
#  (('텔 레전드', 'NNP'), [('텔', 'NNP'), ('레전드', 'NNP')], 23),
#  (('대급 이하', 'NNP'), [('대급', 'NNG'), ('이하', 'NNG')], 23),
#  (('10 월', 'NNP'), [('10', 'SN'), ('월', 'NNBC')], 23),
#  (('연합 사령부', 'NNP'), [('연합', 'NNG'), ('사령부', 'NNG')], 23),
#  (('네이버 채널', 'NNP'), [('네이버', 'NNP'), ('채널', 'NNG')], 23),
#  (('년 간', 'NNP'), [('년', 'NNBC'), ('간', 'NNG')], 23),
#  (('진영 의원', 'NNP'), [('진영', 'NNG'), ('의원', 'NNP')], 23),
#  (('외교장관 회담', 'NNP'), [('외교장관', 'NNP'), ('회담', 'NNG')], 23),
#  (('조명균 통일부', 'NNP'), [('조명균', 'NNP'), ('통일부', 'NNG')], 23),
#  (('1절 100', 'NNP'), [('1절', 'NNP'), ('100', 'SN')], 23),
#  (('최종 합의', 'NNP'), [('최종', 'NNG'), ('합의', 'NNG')], 23),
#  (('교육 기관', 'NNP'), [('교육', 'NNG'), ('기관', 'NNG')], 23),
#  (('소속 의원', 'NNP'), [('소속', 'NNG'), ('의원', 'NNP')], 23),
#  (('국당 의원', 'NNP'), [('국당', 'NNP'), ('의원', 'NNP')], 23),
#  (('이헌승 의원', 'NNP'), [('이헌승', 'NNP'), ('의원', 'NNP')], 23),
#  (('연구 원장', 'NNP'), [('연구', 'NNG'), ('원장', 'NNG')], 23),
#  (('김세연 의원', 'NNP'), [('김세연', 'NNP'), ('의원', 'NNP')], 23),
#  (('서영교 의원', 'NNP'), [('서영교', 'NNP'), ('의원', 'NNP')], 23),
#  (('임재훈 바른미래', 'NNP'), [('임재훈', 'NNP'), ('바른미래', 'NNP')], 23),
#  (('레전드 메트로폴', 'NNP'), [('레전드', 'NNP'), ('메트로폴', 'NNP')], 22),
#  (('방위 태세', 'NNP'), [('방위', 'NNG'), ('태세', 'NNG')], 22),
#  (('캠프 험프리스', 'NNP'), [('캠프', 'NNP'), ('험프리스', 'NNP')], 22),
#  (('구독 신청', 'NNP'), [('구독', 'NNG'), ('신청', 'NNG')], 22),
#  (('2002 년', 'NNP'), [('2002', 'SN'), ('년', 'NNBC')], 22),
#  (('장관 대행', 'NNP'), [('장관', 'NNP'), ('대행', 'NNG')], 22),
#  (('조선 뉴스', 'NNP'), [('조선', 'NNP'), ('뉴스', 'NNG')], 22),
#  (('3 대', 'NNP'), [('3', 'SN'), ('대', 'NNBC')], 22),
#  (('베트남 공식방문', 'NNP'), [('베트남', 'NNP'), ('공식방문', 'NNP')], 22),
#  (('일 한국', 'NNP'), [('일', 'NNBC'), ('한국', 'NNP')], 22),
#  (('합의 불발', 'NNP'), [('합의', 'NNG'), ('불발', 'NNG')], 22),
#  (('한국 합참의장', 'NNP'), [('한국', 'NNP'), ('합참의장', 'NNP')], 22),
#  (('나라 사이', 'NNP'), [('나라', 'NNG'), ('사이', 'NNG')], 22),
#  (('협조 관계', 'NNP'), [('협조', 'NNG'), ('관계', 'NNG')], 22),
#  (('베트남 국가주석', 'NNP'), [('베트남', 'NNP'), ('국가주석', 'NNP')], 22),
#  (('8 개', 'NNP'), [('8', 'SN'), ('개', 'NNBC')], 22),
#  (('대사 인사', 'NNP'), [('대사', 'NNG'), ('인사', 'NNP')], 22),
#  (('박용진 의원', 'NNP'), [('박용진', 'NNP'), ('의원', 'NNP')], 22),
#  (('투기 의혹', 'NNP'), [('투기', 'NNG'), ('의혹', 'NNG')], 22),
#  (('핵심 관계자', 'NNP'), [('핵심', 'NNG'), ('관계자', 'NNP')], 22),
#  (('대통령 탄핵', 'NNP'), [('대통령', 'NNP'), ('탄핵', 'NNG')], 22),
#  (('당직 인선', 'NNP'), [('당직', 'NNG'), ('인선', 'NNG')], 22),
#  (('향후 여야 협상', 'NNP'), [('향후', 'NNG'), ('여야', 'NNG'), ('협상', 'NNG')], 22),
#  (('백악관 국가안보', 'NNP'), [('백악관', 'NNG'), ('국가안보', 'NNP')], 21),
#  (('스텔스 전투기', 'NNP'), [('스텔스', 'NNG'), ('전투기', 'NNG')], 21),
#  (('컴퓨터 시뮬레이션', 'NNP'), [('컴퓨터', 'NNG'), ('시뮬레이션', 'NNG')], 21),
#  (('9 개월', 'NNP'), [('9', 'SN'), ('개월', 'NNBC')], 21),
#  (('차 미', 'NNP'), [('차', 'NNBC'), ('미', 'NNG')], 21),
#  (('최신 뉴스', 'NNP'), [('최신', 'NNG'), ('뉴스', 'NNG')], 21),
#  (('인기 무료 만화', 'NNP'), [('인기', 'NNG'), ('무료', 'NNG'), ('만화', 'NNG')], 21),
#  (('비핵화 의지', 'NNP'), [('비핵화', 'NNG'), ('의지', 'NNG')], 21),
#  (('대북정책 특별대표', 'NNP'), [('대북정책', 'NNP'), ('특별대표', 'NNP')], 21),
#  (('6 일', 'NNP'), [('6', 'SN'), ('일', 'NNBC')], 21),
#  (('안보 도전', 'NNP'), [('안보', 'NNG'), ('도전', 'NNG')], 21),
#  (('오후 청와대', 'NNP'), [('오후', 'NNG'), ('청와대', 'NNP')], 21),
#  (('국가정보 원장', 'NNP'), [('국가정보', 'NNP'), ('원장', 'NNG')], 21),
#  (('최고 지도자', 'NNP'), [('최고', 'NNG'), ('지도자', 'NNG')], 21),
#  (('리 외무상', 'NNP'), [('리', 'NNG'), ('외무상', 'NNP')], 21),
#  (('주년 3', 'NNP'), [('주년', 'NNBC'), ('3', 'SN')], 21),
#  (('선거제 개혁', 'NNP'), [('선거제', 'NNG'), ('개혁', 'NNG')], 21),
#  (('오전 국회', 'NNP'), [('오전', 'NNG'), ('국회', 'NNG')], 21),
#  (('황교안 자유', 'NNP'), [('황교안', 'NNP'), ('자유', 'NNG')], 21),
#  (('황 대표', 'NNP'), [('황', 'NNP'), ('대표', 'NNP')], 21),
#  (('가운데 처리', 'NNP'), [('가운데', 'NNG'), ('처리', 'NNG')], 21),
#  (('파인 도입', 'NNP'), [('파인', 'NNG'), ('도입', 'NNG')], 21),
#  (('핵 추진', 'NNP'), [('핵', 'NNG'), ('추진', 'NNG')], 20),
#  (('작년 6', 'NNP'), [('작년', 'NNG'), ('6', 'SN')], 20),
#  (('기동 훈련', 'NNP'), [('기동', 'NNG'), ('훈련', 'NNG')], 20),
#  (('합동군사 훈련', 'NNP'), [('합동군사', 'NNP'), ('훈련', 'NNG')], 20),
#  (('양국 군', 'NNP'), [('양국', 'NNG'), ('군', 'NNG')], 20),
#  (('미 국무부', 'NNP'), [('미', 'NNG'), ('국무부', 'NNG')], 20),
#  (('결렬 직후', 'NNP'), [('결렬', 'NNG'), ('직후', 'NNG')], 20),
#  (('1994 년', 'NNP'), [('1994', 'SN'), ('년', 'NNBC')], 20),
#  (('북한 외무성', 'NNP'), [('북한', 'NNP'), ('외무성', 'NNG')], 20),
#  (('북핵 협상', 'NNP'), [('북핵', 'NNP'), ('협상', 'NNG')], 20),
#  (('간 시행', 'NNP'), [('간', 'NNG'), ('시행', 'NNG')], 20),
#  (('서훈 국가정보', 'NNP'), [('서훈', 'NNP'), ('국가정보', 'NNP')], 20),
#  (('15 일', 'NNP'), [('15', 'SN'), ('일', 'NNBC')], 20),
#  (('응우옌 푸 쫑', 'NNP'), [('응우옌', 'NNP'), ('푸', 'NNP'), ('쫑', 'NNG')], 20),
#  (('채널 추가', 'NNP'), [('채널', 'NNG'), ('추가', 'NNG')], 20),
#  (('에어 팟', 'NNP'), [('에어', 'NNG'), ('팟', 'NNG')], 20),
#  (('창 아시아', 'NNP'), [('창', 'NNG'), ('아시아', 'NNP')], 20),
#  (('유총 유치원', 'NNP'), [('유총', 'NNP'), ('유치원', 'NNG')], 20),
#  (('탄력 근로', 'NNP'), [('탄력', 'NNG'), ('근로', 'NNG')], 20),
#  (('한국 당', 'NNP'), [('한국', 'NNP'), ('당', 'NNP')], 20),
#  (('이용수 할머니', 'NNP'), [('이용수', 'NNP'), ('할머니', 'NNG')], 20),
#  (('김 여사', 'NNP'), [('김', 'NNP'), ('여사', 'NNG')], 20),
#  (('국당 국회', 'NNP'), [('국당', 'NNP'), ('국회', 'NNG')], 20),
#  (('4 박 5', 'NNP'), [('4', 'SN'), ('박', 'NNBC'), ('5', 'SN')], 19),
#  (('회담 이후', 'NNP'), [('회담', 'NNG'), ('이후', 'NNG')], 19),
#  (('워 게임', 'NNP'), [('워', 'NNG'), ('게임', 'NNG')], 19),
#  (('경기도 평택시', 'NNP'), [('경기도', 'NNP'), ('평택시', 'NNP')], 19),
#  (('방 안', 'NNP'), [('방', 'NNG'), ('안', 'NNG')], 19),
#  (('2 부', 'NNP'), [('2', 'SN'), ('부', 'NNBC')], 19),
#  (('미국 국방', 'NNP'), [('미국', 'NNP'), ('국방', 'NNG')], 19),
#  (('하노이 멜리아', 'NNP'), [('하노이', 'NNP'), ('멜리아', 'NNP')], 19),
#  (('최선희 북한', 'NNP'), [('최선희', 'NNP'), ('북한', 'NNP')], 19),
#  (('국무부 대북정책', 'NNP'), [('국무부', 'NNG'), ('대북정책', 'NNP')], 19),
#  (('일 미국', 'NNP'), [('일', 'NNBC'), ('미국', 'NNP')], 19),
#  (('블라디보스토크 총영사', 'NNP'), [('블라디보스토크', 'NNP'), ('총영사', 'NNG')], 19),
#  (('후속 대책', 'NNP'), [('후속', 'NNG'), ('대책', 'NNG')], 19),
#  (('노영민 대통령', 'NNP'), [('노영민', 'NNP'), ('대통령', 'NNP')], 19),
#  (('준비 태세', 'NNP'), [('준비', 'NNG'), ('태세', 'NNG')], 19),
#  (('북미정상회담 직후', 'NNP'), [('북미정상회담', 'NNP'), ('직후', 'NNG')], 19),
#  (('기념 티셔츠', 'NNP'), [('기념', 'NNG'), ('티셔츠', 'NNG')], 19),
#  (('20 대', 'NNP'), [('20', 'SN'), ('대', 'NNBC')], 19),
#  (('김정숙 여사', 'NNP'), [('김정숙', 'NNP'), ('여사', 'NNG')], 19),
#  (('우상호 의원', 'NNP'), [('우상호', 'NNP'), ('의원', 'NNP')], 19),
#  (('대사 후임', 'NNP'), [('대사', 'NNG'), ('후임', 'NNG')], 19),
#  (('부동산 투기', 'NNP'), [('부동산', 'NNG'), ('투기', 'NNG')], 19),
#  (('김현미 국토', 'NNP'), [('김현미', 'NNP'), ('국토', 'NNG')], 19),
#  (('전략 부총장', 'NNP'), [('전략', 'NNG'), ('부총장', 'NNG')], 19),
#  (('친교 만찬', 'NNP'), [('친교', 'NNG'), ('만찬', 'NNG')], 18),
#  (('독수리 연습', 'NNP'), [('독수리', 'NNG'), ('연습', 'NNG')], 18),
#  (('9 월', 'NNP'), [('9', 'SN'), ('월', 'NNBC')], 18),
#  (('최종 결정', 'NNP'), [('최종', 'NNG'), ('결정', 'NNG')], 18),
#  (('2 년', 'NNP'), [('2', 'SN'), ('년', 'NNBC')], 18),
#  (('협상 수석대표', 'NNP'), [('협상', 'NNG'), ('수석대표', 'NNG')], 18),
#  (('합의 무산', 'NNP'), [('합의', 'NNG'), ('무산', 'NNG')], 18),
#  (('양국 국방', 'NNP'), [('양국', 'NNG'), ('국방', 'NNG')], 18),
#  (('규모 부대', 'NNP'), [('규모', 'NNG'), ('부대', 'NNG')], 18),
#  (('월 14', 'NNP'), [('월', 'NNBC'), ('14', 'SN')], 18),
#  (('전쟁 영웅', 'NNP'), [('전쟁', 'NNG'), ('영웅', 'NNG')], 18),
#  (('형사 고발', 'NNP'), [('형사', 'NNG'), ('고발', 'NNG')], 18),
#  (('일 청와대', 'NNP'), [('일', 'NNBC'), ('청와대', 'NNP')], 18),
#  (('러시아 대사', 'NNP'), [('러시아', 'NNP'), ('대사', 'NNG')], 18),
#  (('교육부 장관', 'NNP'), [('교육부', 'NNG'), ('장관', 'NNP')], 18),
#  (('성명서 발표', 'NNP'), [('성명서', 'NNG'), ('발표', 'NNG')], 18),
#  (('풀뿌리 상권', 'NNP'), [('풀뿌리', 'NNG'), ('상권', 'NNG')], 18),
#  (('볼턴 백악관', 'NNP'), [('볼턴', 'NNP'), ('백악관', 'NNG')], 17),
#  (('최선희 외무성', 'NNP'), [('최선희', 'NNP'), ('외무성', 'NNG')], 17),
#  (('트 에이스', 'NNP'), [('트', 'NNG'), ('에이스', 'NNG')], 17),
#  (('작전 능력', 'NNP'), [('작전', 'NNG'), ('능력', 'NNG')], 17),
#  (('후방 지역', 'NNP'), [('후방', 'NNG'), ('지역', 'NNG')], 17),
#  (('작전 개념', 'NNP'), [('작전', 'NNG'), ('개념', 'NNG')], 17),
#  (('전시작전 통제', 'NNP'), [('전시작전', 'NNP'), ('통제', 'NNG')], 17),
#  (('쌍 중단', 'NNP'), [('쌍', 'NNG'), ('중단', 'NNG')], 17),
#  (('이번 2', 'NNP'), [('이번', 'NNG'), ('2', 'SN')], 17),
#  (('미 연합', 'NNP'), [('미', 'NNG'), ('연합', 'NNG')], 17),
#  (('군사 작전', 'NNP'), [('군사', 'NNG'), ('작전', 'NNG')], 17),
#  (('팀 스피릿', 'NNP'), [('팀', 'NNG'), ('스피릿', 'NNG')], 17),
#  (('전시 증원', 'NNP'), [('전시', 'NNG'), ('증원', 'NNG')], 17),
#  (('미 군', 'NNP'), [('미', 'NNG'), ('군', 'NNG')], 17),
#  (('훈련 기간', 'NNP'), [('훈련', 'NNG'), ('기간', 'NNG')], 17),
#  (('환송 인파', 'NNP'), [('환송', 'NNG'), ('인파', 'NNG')], 17),
#  (('일 하노이', 'NNP'), [('일', 'NNBC'), ('하노이', 'NNP')], 17),
#  (('2 개', 'NNP'), [('2', 'SN'), ('개', 'NNBC')], 17),
#  (('중재자 역할', 'NNP'), [('중재자', 'NNG'), ('역할', 'NNG')], 17),
#  (('로버트 에이브럼스', 'NNP'), [('로버트', 'NNP'), ('에이브럼스', 'NNP')], 17),
#  (('이번 정상', 'NNP'), [('이번', 'NNG'), ('정상', 'NNG')], 17),
#  (('북한 외무상', 'NNP'), [('북한', 'NNP'), ('외무상', 'NNP')], 17),
#  (('미국 국무부', 'NNP'), [('미국', 'NNP'), ('국무부', 'NNG')], 17),
#  (('대사 내정자', 'NNP'), [('대사', 'NNG'), ('내정자', 'NNG')], 17),
#  (('정치 행동 회의', 'NNP'), [('정치', 'NNG'), ('행동', 'NNG'), ('회의', 'NNG')], 17),
#  (('공조 방안', 'NNP'), [('공조', 'NNG'), ('방안', 'NNG')], 17),
#  (('12 년', 'NNP'), [('12', 'SN'), ('년', 'NNBC')], 17),
#  (('이도훈 본부', 'NNP'), [('이도훈', 'NNP'), ('본부', 'NNG')], 17),
#  (('일 기자', 'NNP'), [('일', 'NNBC'), ('기자', 'NNP')], 17),
#  (('국가안보 실장', 'NNP'), [('국가안보', 'NNP'), ('실장', 'NNG')], 17),
#  (('베트남 전쟁', 'NNP'), [('베트남', 'NNP'), ('전쟁', 'NNG')], 17),
#  (('위안부 피해자', 'NNP'), [('위안부', 'NNG'), ('피해자', 'NNP')], 17),
#  (('2020 년', 'NNP'), [('2020', 'SN'), ('년', 'NNBC')], 17),
#  (('시 주석', 'NNP'), [('시', 'NNG'), ('주석', 'NNG')], 17),
#  (('개각 발표', 'NNP'), [('개각', 'NNG'), ('발표', 'NNG')], 17),
#  (('청와대 관계자', 'NNP'), [('청와대', 'NNP'), ('관계자', 'NNP')], 17),
#  (('이날 논평', 'NNP'), [('이날', 'NNG'), ('논평', 'NNG')], 17),
#  (('춘추 관장', 'NNP'), [('춘추', 'NNP'), ('관장', 'NNG')], 17),
#  (('3당 교섭단체', 'NNP'), [('3당', 'NNP'), ('교섭단체', 'NNP')], 17),
#  (('나경원 원내대표', 'NNP'), [('나경원', 'NNP'), ('원내대표', 'NNP')], 17),
#  (('김순례 의원', 'NNP'), [('김순례', 'NNP'), ('의원', 'NNP')], 17),
#  (('하노이 메트로폴', 'NNP'), [('하노이', 'NNP'), ('메트로폴', 'NNP')], 16),
#  (('훈련 축소', 'NNP'), [('훈련', 'NNG'), ('축소', 'NNG')], 16),
#  (('추진 항공모함', 'NNP'), [('추진', 'NNG'), ('항공모함', 'NNG')], 16),
#  (('문제 해결', 'NNP'), [('문제', 'NNG'), ('해결', 'NNG')], 16),
#  (('동안 유지', 'NNP'), [('동안', 'NNG'), ('유지', 'NNG')], 16),
#  (('년 처음', 'NNP'), [('년', 'NNBC'), ('처음', 'NNG')], 16),
#  (('1 뉴스', 'NNP'), [('1', 'SN'), ('뉴스', 'NNG')], 16),
#  (('프리미엄 미디어 Signal', 'NNP'),
#   [('프리미엄', 'NNG'), ('미디어', 'NNG'), ('Signal', 'SL')],
#   16),
#  (('포스트 하노이', 'NNP'), [('포스트', 'NNP'), ('하노이', 'NNP')], 16),
#  (('호 북한', 'NNP'), [('호', 'NNBC'), ('북한', 'NNP')], 16),
#  (('후반 개각', 'NNP'), [('후반', 'NNG'), ('개각', 'NNG')], 16),
#  (('개각 대상', 'NNP'), [('개각', 'NNG'), ('대상', 'NNG')], 16),
#  (('북미정상회담 이후', 'NNP'), [('북미정상회담', 'NNP'), ('이후', 'NNG')], 16),
#  (('2015 년', 'NNP'), [('2015', 'SN'), ('년', 'NNBC')], 16),
#  (('연합 준비', 'NNP'), [('연합', 'NNG'), ('준비', 'NNG')], 16),
#  (('북한 핵', 'NNP'), [('북한', 'NNP'), ('핵', 'NNG')], 16),
#  (('fn 파스', 'NNP'), [('fn', 'SL'), ('파스', 'NNG')], 16),
#  (('연예뉴스 fn 스타', 'NNP'), [('연예뉴스', 'NNP'), ('fn', 'SL'), ('스타', 'NNG')], 16),
#  (('파이낸셜 뉴스', 'NNP'), [('파이낸셜', 'NNP'), ('뉴스', 'NNG')], 16),
#  (('시 30', 'NNP'), [('시', 'NNBC'), ('30', 'SN')], 16),
#  (('당과 정부', 'NNP'), [('당과', 'NNG'), ('정부', 'NNG')], 16),
#  (('계승 발전', 'NNP'), [('계승', 'NNG'), ('발전', 'NNG')], 16),
#  (('핵 폐기', 'NNP'), [('핵', 'NNG'), ('폐기', 'NNG')], 16),
#  (('지원 사업', 'NNP'), [('지원', 'NNG'), ('사업', 'NNG')], 16),
#  (('연기 철회', 'NNP'), [('연기', 'NNG'), ('철회', 'NNG')], 16),
#  (('해양수산부 장관', 'NNP'), [('해양수산부', 'NNP'), ('장관', 'NNP')], 16),
#  (('오스트리아 대사', 'NNP'), [('오스트리아', 'NNP'), ('대사', 'NNG')], 16),
#  (('국가 관리회계', 'NNP'), [('국가', 'NNP'), ('관리회계', 'NNP')], 16),
#  (('출마 지역', 'NNP'), [('출마', 'NNG'), ('지역', 'NNG')], 16),
#  (('신속처리 안건', 'NNP'), [('신속처리', 'NNP'), ('안건', 'NNG')], 16),
#  (('단수 후보', 'NNP'), [('단수', 'NNG'), ('후보', 'NNG')], 16),
#  (('교통부 장관', 'NNP'), [('교통부', 'NNP'), ('장관', 'NNP')], 16),
#  (('문화체육관광부 장관', 'NNP'), [('문화체육관광부', 'NNP'), ('장관', 'NNP')], 16),
#  (('목포 부동산', 'NNP'), [('목포', 'NNP'), ('부동산', 'NNG')], 16),
#  (('S 10', 'NNP'), [('S', 'SL'), ('10', 'SN')], 16),
#  (('중앙 선거관리위원회', 'NNP'), [('중앙', 'NNG'), ('선거관리위원회', 'NNP')], 16),
#  (('조 대표', 'NNP'), [('조', 'NNG'), ('대표', 'NNP')], 16),
#  (('홍문종 의원', 'NNP'), [('홍문종', 'NNP'), ('의원', 'NNP')], 16),
#  (('서울 신문', 'NNP'), [('서울', 'NNP'), ('신문', 'NNG')], 16),
#  (('국가안보 회의', 'NNP'), [('국가안보', 'NNP'), ('회의', 'NNG')], 15),
#  (('노 딜', 'NNP'), [('노', 'NNP'), ('딜', 'NNP')], 15),
#  (('미군 전략', 'NNP'), [('미군', 'NNG'), ('전략', 'NNG')], 15),
#  (('매경 뉴스 레터', 'NNP'), [('매경', 'NNP'), ('뉴스', 'NNG'), ('레터', 'NNP')], 15),
#  (('뉴스 이상', 'NNP'), [('뉴스', 'NNG'), ('이상', 'NNG')], 15),
#  (('김귀근 기자', 'NNP'), [('김귀근', 'NNP'), ('기자', 'NNP')], 15),
#  (('미 8 군사령부', 'NNP'), [('미', 'NNG'), ('8', 'SN'), ('군사령부', 'NNG')], 15),
#  (('25 일', 'NNP'), [('25', 'SN'), ('일', 'NNBC')], 15),
#  (('세월 동안', 'NNP'), [('세월', 'NNG'), ('동안', 'NNG')], 15),
#  (('2 주', 'NNP'), [('2', 'SN'), ('주', 'NNBC')], 15),
#  (('미 양국', 'NNP'), [('미', 'NNG'), ('양국', 'NNG')], 15),
#  (('세계 평화', 'NNP'), [('세계', 'NNG'), ('평화', 'NNG')], 15),
#  (('에이브럼스 연합 사령관', 'NNP'),
#   [('에이브럼스', 'NNP'), ('연합', 'NNG'), ('사령관', 'NNG')],
#   15),
#  (('북미 양측', 'NNP'), [('북미', 'NNP'), ('양측', 'NNG')], 15),
#  (('대북제재 해제', 'NNP'), [('대북제재', 'NNP'), ('해제', 'NNG')], 15),
#  (('싱가포르 북미정상회담', 'NNP'), [('싱가포르', 'NNP'), ('북미정상회담', 'NNP')], 15),
#  (('전쟁 연습', 'NNP'), [('전쟁', 'NNG'), ('연습', 'NNG')], 15),
#  (('향후 공조', 'NNP'), [('향후', 'NNG'), ('공조', 'NNG')], 15),
#  (('년 이후', 'NNP'), [('년', 'NNBC'), ('이후', 'NNG')], 15),
#  (('하노이 담판', 'NNP'), [('하노이', 'NNP'), ('담판', 'NNG')], 15),
#  (('하노이 북미정상회담', 'NNP'), [('하노이', 'NNP'), ('북미정상회담', 'NNP')], 15),
#  (('다음 날', 'NNP'), [('다음', 'NNG'), ('날', 'NNG')], 15),
#  (('푸 쫑 베트남', 'NNP'), [('푸', 'NNP'), ('쫑', 'NNG'), ('베트남', 'NNP')], 15),
#  (('간 실시', 'NNP'), [('간', 'NNG'), ('실시', 'NNG')], 15),
#  (('이날 한미', 'NNP'), [('이날', 'NNG'), ('한미', 'NNG')], 15),
#  (('2019 년', 'NNP'), [('2019', 'SN'), ('년', 'NNBC')], 15),
#  (('2 시', 'NNP'), [('2', 'SN'), ('시', 'NNBC')], 15),
#  (('엄정 대응', 'NNP'), [('엄정', 'NNG'), ('대응', 'NNG')], 15),
#  (('부인 김정숙', 'NNP'), [('부인', 'NNG'), ('김정숙', 'NNP')], 15),
#  (('문체부 장관', 'NNP'), [('문체부', 'NNP'), ('장관', 'NNP')], 15),
#  (('교육 당국', 'NNP'), [('교육', 'NNG'), ('당국', 'NNG')], 15),
#  (('대 총선', 'NNP'), [('대', 'NNBC'), ('총선', 'NNG')], 15),
#  (('비공개 회동', 'NNP'), [('비공개', 'NNP'), ('회동', 'NNG')], 15),
#  (('징계 여부', 'NNP'), [('징계', 'NNG'), ('여부', 'NNG')], 15),
#  (('정하종 기자', 'NNP'), [('정하종', 'NNP'), ('기자', 'NNP')], 15),
#  (('강영식 우리민족', 'NNP'), [('강영식', 'NNP'), ('우리민족', 'NNP')], 15),
#  (('운동 사무총장', 'NNP'), [('운동', 'NNG'), ('사무총장', 'NNG')], 15),
#  (('서울 마포구 사무실', 'NNP'), [('서울', 'NNP'), ('마포구', 'NNP'), ('사무실', 'NNG')], 15),
#  (('3 chc', 'NNP'), [('3', 'SN'), ('chc', 'SL')], 15),
#  (('사립학교 법', 'NNP'), [('사립학교', 'NNP'), ('법', 'NNG')], 15),
#  (('주요 당직', 'NNP'), [('주요', 'NNG'), ('당직', 'NNG')], 15),
#  (('교육 위원', 'NNP'), [('교육', 'NNG'), ('위원', 'NNP')], 15),
#  (('교육위 간사', 'NNP'), [('교육위', 'NNP'), ('간사', 'NNG')], 15),
#  (('span class', 'NNP'), [('span', 'SL'), ('class', 'SL')], 15),
#  (('규모 훈련', 'NNP'), [('규모', 'NNG'), ('훈련', 'NNG')], 14),
#  (('연합군 사령부', 'NNP'), [('연합군', 'NNG'), ('사령부', 'NNG')], 14),
#  (('평택시 미 8', 'NNP'), [('평택시', 'NNP'), ('미', 'NNG'), ('8', 'SN')], 14),
#  (('8 군사령부 캠프', 'NNP'), [('8', 'SN'), ('군사령부', 'NNG'), ('캠프', 'NNP')], 14),
#  (('오후 경기도', 'NNP'), [('오후', 'NNG'), ('경기도', 'NNP')], 14),
#  (('미동 맹', 'NNP'), [('미동', 'NNG'), ('맹', 'NNG')], 14),
#  (('일 발표', 'NNP'), [('일', 'NNBC'), ('발표', 'NNG')], 14),
#  (('한경 닷컴', 'NNP'), [('한경', 'NNP'), ('닷컴', 'NNP')], 14),
#  (('이번 북미정상회담', 'NNP'), [('이번', 'NNG'), ('북미정상회담', 'NNP')], 14),
#  (('1976 년', 'NNP'), [('1976', 'SN'), ('년', 'NNBC')], 14),
#  (('연합 전시', 'NNP'), [('연합', 'NNG'), ('전시', 'NNG')], 14),
#  (('규모 한미연합', 'NNP'), [('규모', 'NNG'), ('한미연합', 'NNP')], 14),
#  (('결렬 후', 'NNP'), [('결렬', 'NNG'), ('후', 'NNG')], 14),
#  (('우라늄 농축', 'NNP'), [('우라늄', 'NNG'), ('농축', 'NNG')], 14),
#  (('수석대표 협의', 'NNP'), [('수석대표', 'NNG'), ('협의', 'NNG')], 14),
#  (('대면 논의', 'NNP'), [('대면', 'NNG'), ('논의', 'NNG')], 14),
#  (('1 기', 'NNP'), [('1', 'SN'), ('기', 'NNG')], 14),
#  (('국방부 관계자', 'NNP'), [('국방부', 'NNG'), ('관계자', 'NNP')], 14),
#  (('보수 정치 행동', 'NNP'), [('보수', 'NNG'), ('정치', 'NNG'), ('행동', 'NNG')], 14),
#  (('선임 기자', 'NNP'), [('선임', 'NNG'), ('기자', 'NNP')], 14),
#  (('김현종 2차장', 'NNP'), [('김현종', 'NNP'), ('2차장', 'NNP')], 14),
#  (('특별 열차', 'NNP'), [('특별', 'NNG'), ('열차', 'NNG')], 14),
#  (('평화 위업', 'NNP'), [('평화', 'NNG'), ('위업', 'NNG')], 14),
#  (('9 시', 'NNP'), [('9', 'SN'), ('시', 'NNBC')], 14),
#  (('환경 변화', 'NNP'), [('환경', 'NNG'), ('변화', 'NNG')], 14),
#  (('지속 강화', 'NNP'), [('지속', 'NNG'), ('강화', 'NNG')], 14),
#  (('이번 베트남', 'NNP'), [('이번', 'NNG'), ('베트남', 'NNP')], 14),
#  (('국민 일보', 'NNP'), [('국민', 'NNG'), ('일보', 'NNG')], 14),
#  (('미국 증시', 'NNP'), [('미국', 'NNP'), ('증시', 'NNG')], 14),
#  (('서울 광화문광장', 'NNP'), [('서울', 'NNP'), ('광화문광장', 'NNP')], 14),
#  (('이번 개각', 'NNP'), [('이번', 'NNG'), ('개각', 'NNG')], 14),
#  (('김병섭 서울대', 'NNP'), [('김병섭', 'NNP'), ('서울대', 'NNP')], 14),
#  (('통일연구원 장', 'NNP'), [('통일연구원', 'NNP'), ('장', 'NNP')], 14),
#  (('영리 법인', 'NNP'), [('영리', 'NNG'), ('법인', 'NNG')], 14),
#  (('회담 특별 페이지', 'NNP'), [('회담', 'NNG'), ('특별', 'NNG'), ('페이지', 'NNG')], 14),
#  (('동영상 구경', 'NNP'), [('동영상', 'NNG'), ('구경', 'NNG')], 14),
#  (('노컷뉴스 무단', 'NNP'), [('노컷뉴스', 'NNP'), ('무단', 'NNG')], 14),
#  (('오후 하노이', 'NNP'), [('오후', 'NNG'), ('하노이', 'NNP')], 14),
#  (('문희상 국회의장', 'NNP'), [('문희상', 'NNP'), ('국회의장', 'NNP')], 14),
#  (('통신부 장관', 'NNP'), [('통신부', 'NNG'), ('장관', 'NNP')], 14),
#  (('박영선 의원', 'NNP'), [('박영선', 'NNP'), ('의원', 'NNP')], 14),
#  (('일 페이스북', 'NNP'), [('일', 'NNBC'), ('페이스북', 'NNP')], 14),
#  (('이념 성향', 'NNP'), [('이념', 'NNG'), ('성향', 'NNG')], 14),
#  (('이형진 기자', 'NNP'), [('이형진', 'NNP'), ('기자', 'NNP')], 14),
#  (('지명직 최고위원', 'NNP'), [('지명직', 'NNP'), ('최고위원', 'NNP')], 14),
#  (('임 의원', 'NNP'), [('임', 'NNP'), ('의원', 'NNP')], 14),
#  (('이해 당사자', 'NNP'), [('이해', 'NNG'), ('당사자', 'NNG')], 14),
#  (('3 toadboy', 'NNP'), [('3', 'SN'), ('toadboy', 'SL')], 14),
#  (('디지털 타임스', 'NNP'), [('디지털', 'NNG'), ('타임스', 'NNP')], 14),
#  (('뉴스 구독', 'NNP'), [('뉴스', 'NNG'), ('구독', 'NNG')], 14),
#  (('소피 텔', 'NNP'), [('소피', 'NNG'), ('텔', 'NNP')], 13),
#  (('일 김', 'NNP'), [('일', 'NNBC'), ('김', 'NNP')], 13),
#  (('1 B', 'NNP'), [('1', 'SN'), ('B', 'SL')], 13),
#  (('일 경기도', 'NNP'), [('일', 'NNBC'), ('경기도', 'NNP')], 13),
#  (('종료 결정', 'NNP'), [('종료', 'NNG'), ('결정', 'NNG')], 13),
#  (('1 억달러', 'NNP'), [('1', 'SN'), ('억달러', 'NNP')], 13),
#  (('한국 정부', 'NNP'), [('한국', 'NNP'), ('정부', 'NNG')], 13),
#  (('대책 마련', 'NNP'), [('대책', 'NNG'), ('마련', 'NNG')], 13),
#  (('18 일', 'NNP'), [('18', 'SN'), ('일', 'NNBC')], 13),
#  (('실기 동', 'NNP'), [('실기', 'NNG'), ('동', 'NNG')], 13),
#  (('한미연합 사령부', 'NNP'), [('한미연합', 'NNP'), ('사령부', 'NNG')], 13),
#  (('직후 기자', 'NNP'), [('직후', 'NNG'), ('기자', 'NNP')], 13),
#  (('고위 관계자', 'NNP'), [('고위', 'NNG'), ('관계자', 'NNP')], 13),
#  (('연합 방위력', 'NNP'), [('연합', 'NNG'), ('방위력', 'NNG')], 13),
#  (('규모 합동군사', 'NNP'), [('규모', 'NNG'), ('합동군사', 'NNP')], 13),
#  (('핵 은폐 의혹', 'NNP'), [('핵', 'NNG'), ('은폐', 'NNG'), ('의혹', 'NNG')], 13),
#  (('9 일', 'NNP'), [('9', 'SN'), ('일', 'NNBC')], 13),
#  (('서울 종로구', 'NNP'), [('서울', 'NNP'), ('종로구', 'NNP')], 13),
#  (('과정에서 한국', 'NNP'), [('과정에서', 'NNP'), ('한국', 'NNP')], 13),
#  (('회담 종료', 'NNP'), [('회담', 'NNG'), ('종료', 'NNG')], 13),
#  (('출신 장관', 'NNP'), [('출신', 'NNG'), ('장관', 'NNP')], 13),
#  (('로컬 푸드', 'NNP'), [('로컬', 'NNG'), ('푸드', 'NNG')], 13),
#  (('오전 9', 'NNP'), [('오전', 'NNG'), ('9', 'SN')], 13),
#  (('방문 결과', 'NNP'), [('방문', 'NNG'), ('결과', 'NNG')], 13),
#  (('베트남 당과', 'NNP'), [('베트남', 'NNP'), ('당과', 'NNG')], 13),
#  (('메리어트 호텔', 'NNP'), [('메리어트', 'NNP'), ('호텔', 'NNG')], 13),
#  (('3 시', 'NNP'), [('3', 'SN'), ('시', 'NNBC')], 13),
#  (('호텔 앞', 'NNP'), [('호텔', 'NNG'), ('앞', 'NNG')], 13),
#  (('하노이 시내', 'NNP'), [('하노이', 'NNP'), ('시내', 'NNG')], 13),
#  (('연중 소규모', 'NNP'), [('연중', 'NNG'), ('소규모', 'NNP')], 13),
#  (('주년 기념사', 'NNP'), [('주년', 'NNBC'), ('기념사', 'NNG')], 13),
#  (('사유 재산', 'NNP'), [('사유', 'NNG'), ('재산', 'NNG')], 13),
#  (('박한기 합참의장', 'NNP'), [('박한기', 'NNP'), ('합참의장', 'NNP')], 13),
#  (('유엔사 전력', 'NNP'), [('유엔사', 'NNP'), ('전력', 'NNG')], 13),
#  (('수준 유지', 'NNP'), [('수준', 'NNG'), ('유지', 'NNG')], 13),
#  (('군 훈련', 'NNP'), [('군', 'NNG'), ('훈련', 'NNG')], 13),
#  (('안보 환경', 'NNP'), [('안보', 'NNG'), ('환경', 'NNG')], 13),
#  (('변화 속', 'NNP'), [('변화', 'NNG'), ('속', 'NNG')], 13),
#  (('무역 협상', 'NNP'), [('무역', 'NNG'), ('협상', 'NNG')], 13),
#  (('취향 저격 뉴스', 'NNP'), [('취향', 'NNG'), ('저격', 'NNG'), ('뉴스', 'NNG')], 13),
#  (('GoodNews paper', 'NNP'), [('GoodNews', 'SL'), ('paper', 'SL')], 13),
#  (('부처 장관', 'NNP'), [('부처', 'NNG'), ('장관', 'NNP')], 13),
#  (('서울대 교수', 'NNP'), [('서울대', 'NNP'), ('교수', 'NNG')], 13),
#  (('김연철 통일연구원', 'NNP'), [('김연철', 'NNP'), ('통일연구원', 'NNP')], 13),
#  (('영변 핵', 'NNP'), [('영변', 'NNG'), ('핵', 'NNG')], 13),
#  (('바른미래 당과', 'NNP'), [('바른미래', 'NNP'), ('당과', 'NNG')], 13),
#  (('이슬기 기자', 'NNP'), [('이슬기', 'NNP'), ('기자', 'NNP')], 13),
#  (('연합뉴스 통화', 'NNP'), [('연합뉴스', 'NNP'), ('통화', 'NNG')], 13),
#  (('단수 확정', 'NNP'), [('단수', 'NNG'), ('확정', 'NNG')], 13),
#  (('의원 출신', 'NNP'), [('의원', 'NNP'), ('출신', 'NNG')], 13),
#  (('중진 의원', 'NNP'), [('중진', 'NNG'), ('의원', 'NNP')], 13),
#  (('유영민 과학기술정보', 'NNP'), [('유영민', 'NNP'), ('과학기술정보', 'NNP')], 13),
#  (('입 국장', 'NNP'), [('입', 'NNG'), ('국장', 'NNG')], 13),
#  (('중소벤처기업부 장관', 'NNP'), [('중소벤처기업부', 'NNP'), ('장관', 'NNP')], 13),
#  (('대 국회', 'NNP'), [('대', 'NNBC'), ('국회', 'NNG')], 13),
#  (('이날 기자', 'NNP'), [('이날', 'NNG'), ('기자', 'NNP')], 13),
#  (('정치 이념', 'NNP'), [('정치', 'NNG'), ('이념', 'NNG')], 13),
#  (('대표 체제', 'NNP'), [('대표', 'NNP'), ('체제', 'NNG')], 13),
#  (('박기호 기자', 'NNP'), [('박기호', 'NNP'), ('기자', 'NNP')], 13),
#  (('교육위원회 김한표', 'NNP'), [('교육위원회', 'NNP'), ('김한표', 'NNP')], 13),
#  (('홍문종 위원', 'NNP'), [('홍문종', 'NNP'), ('위원', 'NNP')], 13),
#  (('경제 임춘한', 'NNP'), [('경제', 'NNG'), ('임춘한', 'NNP')], 13),
#  (('기자 choon', 'NNP'), [('기자', 'NNP'), ('choon', 'SL')], 13),
#  (('KBS 뉴스', 'NNP'), [('KBS', 'SL'), ('뉴스', 'NNG')], 13),
#  (('일 회담', 'NNP'), [('일', 'NNBC'), ('회담', 'NNG')], 12),
#  (('지난달 26', 'NNP'), [('지난달', 'NNG'), ('26', 'SN')], 12),
#  (('급 이상', 'NNP'), [('급', 'NNG'), ('이상', 'NNG')], 12),
#  (('태세 약화', 'NNP'), [('태세', 'NNG'), ('약화', 'NNG')], 12),
#  (('실기 동훈련', 'NNP'), [('실기', 'NNG'), ('동훈련', 'NNG')], 12),
#  (('모바일 한경 구독', 'NNP'), [('모바일', 'NNP'), ('한경', 'NNG'), ('구독', 'NNG')], 12),
#  (('1 부', 'NNP'), [('1', 'SN'), ('부', 'NNBC')], 12),
#  (('회담 후', 'NNP'), [('회담', 'NNG'), ('후', 'NNG')], 12),
#  (('지난해 10', 'NNP'), [('지난해', 'NNG'), ('10', 'SN')], 12),
#  (('시행령 개정', 'NNP'), [('시행령', 'NNG'), ('개정', 'NNG')], 12),
#  (('일 저녁', 'NNP'), [('일', 'NNBC'), ('저녁', 'NNG')], 12),
#  (('남북 정상', 'NNP'), [('남북', 'NNP'), ('정상', 'NNG')], 12),
#  (('시일 안', 'NNP'), [('시일', 'NNG'), ('안', 'NNG')], 12),
#  (('행정 안전', 'NNP'), [('행정', 'NNG'), ('안전', 'NNG')], 12),
#  (('한반도 군사', 'NNP'), [('한반도', 'NNP'), ('군사', 'NNG')], 12),
#  (('침략 전쟁', 'NNP'), [('침략', 'NNG'), ('전쟁', 'NNG')], 12),
#  (('북핵 문제', 'NNP'), [('북핵', 'NNP'), ('문제', 'NNG')], 12),
#  (('칼 빈슨', 'NNP'), [('칼', 'NNG'), ('빈슨', 'NNG')], 12),
#  (('이달 중순', 'NNP'), [('이달', 'NNG'), ('중순', 'NNG')], 12),
#  (('회담 상황', 'NNP'), [('회담', 'NNG'), ('상황', 'NNG')], 12),
#  (('각급 채널', 'NNP'), [('각급', 'NNG'), ('채널', 'NNG')], 12),
#  (('하노이 호치민 묘역', 'NNP'), [('하노이', 'NNP'), ('호치민', 'NNP'), ('묘역', 'NNG')], 12),
#  (('일 사진', 'NNP'), [('일', 'NNBC'), ('사진', 'NNG')], 12),
#  (('북한 우정 유치원', 'NNP'), [('북한', 'NNP'), ('우정', 'NNP'), ('유치원', 'NNG')], 12),
#  (('한글 이름', 'NNP'), [('한글', 'NNG'), ('이름', 'NNG')], 12),
#  (('동 훈련', 'NNP'), [('동', 'NNG'), ('훈련', 'NNG')], 12),
#  (('여론 몰이', 'NNP'), [('여론', 'NNG'), ('몰이', 'NNG')], 12),
#  (('전투준비태세 수준', 'NNP'), [('전투준비태세', 'NNP'), ('수준', 'NNG')], 12),
#  (('전날 베트남', 'NNP'), [('전날', 'NNG'), ('베트남', 'NNP')], 12),
#  (('이태호 제작', 'NNP'), [('이태호', 'NNP'), ('제작', 'NNG')], 12),
#  (('공산당 서기장', 'NNP'), [('공산당', 'NNG'), ('서기장', 'NNG')], 12),
#  (('벤처 기업', 'NNP'), [('벤처', 'NNG'), ('기업', 'NNG')], 12),
#  (('집권 후', 'NNP'), [('집권', 'NNG'), ('후', 'NNG')], 12),
#  (('오후 2', 'NNP'), [('오후', 'NNG'), ('2', 'SN')], 12),
#  (('법학 전문대학원', 'NNP'), [('법학', 'NNG'), ('전문대학원', 'NNP')], 12),
#  (('쫑 주석', 'NNP'), [('쫑', 'NNG'), ('주석', 'NNG')], 12),
#  (('부처 수장', 'NNP'), [('부처', 'NNG'), ('수장', 'NNG')], 12),
#  (('이석배 블라디보스토크', 'NNP'), [('이석배', 'NNP'), ('블라디보스토크', 'NNP')], 12),
#  (('보우 소나', 'NNP'), [('보우', 'NNG'), ('소나', 'NNG')], 12),
#  (('보우 소나', 'NNP'), [('보우', 'NNP'), ('소나', 'NNG')], 12),
#  (('학기 개학', 'NNP'), [('학기', 'NNG'), ('개학', 'NNG')], 12),
#  (('여야 4당', 'NNP'), [('여야', 'NNG'), ('4당', 'NNP')], 12),
#  (('13 일', 'NNP'), [('13', 'SN'), ('일', 'NNBC')], 12),
#  (('민주당 홍영표', 'NNP'), [('민주당', 'NNP'), ('홍영표', 'NNP')], 12),
#  (('연기 투쟁', 'NNP'), [('연기', 'NNG'), ('투쟁', 'NNG')], 12),
#  (('2000 년', 'NNP'), [('2000', 'SN'), ('년', 'NNBC')], 12),
#  (('전 대통령', 'NNP'), [('전', 'NNG'), ('대통령', 'NNP')], 12),
#  (('이해찬 대표', 'NNP'), [('이해찬', 'NNP'), ('대표', 'NNP')], 12),
#  (('당 핵심', 'NNP'), [('당', 'NNG'), ('핵심', 'NNG')], 12),
#  (('사회 갈등', 'NNP'), [('사회', 'NNG'), ('갈등', 'NNG')], 12),
#  (('한국 사회 여론 연구소', 'NNP'),
#   [('한국', 'NNP'), ('사회', 'NNG'), ('여론', 'NNG'), ('연구소', 'NNG')],
#   12),
#  (('지지 정당', 'NNP'), [('지지', 'NNG'), ('정당', 'NNG')], 12),
#  (('추경호 의원', 'NNP'), [('추경호', 'NNP'), ('의원', 'NNP')], 12),
#  (('여의도 연구', 'NNP'), [('여의도', 'NNG'), ('연구', 'NNG')], 12),
#  (('새벽 시장', 'NNP'), [('새벽', 'NNG'), ('시장', 'NNG')], 12),
#  (('수익 활동', 'NNP'), [('수익', 'NNG'), ('활동', 'NNG')], 12),
#  (('보수 대통', 'NNP'), [('보수', 'NNG'), ('대통', 'NNG')], 12),
#  (('국당 황교안', 'NNP'), [('국당', 'NNP'), ('황교안', 'NNP')], 12),
#  (('민주당 원내대변인', 'NNP'), [('민주당', 'NNP'), ('원내대변인', 'NNP')], 12),
#  (('1 임세영', 'NNP'), [('1', 'SN'), ('임세영', 'NNP')], 12),
#  (('손 의원', 'NNP'), [('손', 'NNG'), ('의원', 'NNP')], 12),
#  (('이양수 원내대변인', 'NNP'), [('이양수', 'NNP'), ('원내대변인', 'NNP')], 12),
#  (('시행령 시행', 'NNP'), [('시행령', 'NNG'), ('시행', 'NNG')], 12),
#  (('법안 처리', 'NNP'), [('법안', 'NNG'), ('처리', 'NNG')], 12),
#  (('어린이집 공공', 'NNP'), [('어린이집', 'NNG'), ('공공', 'NNG')], 12),
#  (('4차산업 혁명', 'NNP'), [('4차산업', 'NNP'), ('혁명', 'NNG')], 12),
#  (('회담 기간', 'NNP'), [('회담', 'NNG'), ('기간', 'NNG')], 11),
#  (('전면 해제', 'NNP'), [('전면', 'NNG'), ('해제', 'NNG')], 11),
#  (('8 개월', 'NNP'), [('8', 'SN'), ('개월', 'NNBC')], 11),
#  (('연합 작전', 'NNP'), [('연합', 'NNG'), ('작전', 'NNG')], 11),
#  (('B 폭격기', 'NNP'), [('B', 'SL'), ('폭격기', 'NNG')], 11),
#  (('월 28', 'NNP'), [('월', 'NNBC'), ('28', 'SN')], 11),
#  (('방어 훈련', 'NNP'), [('방어', 'NNG'), ('훈련', 'NNG')], 11),
#  (('미 대통령', 'NNP'), [('미', 'NNG'), ('대통령', 'NNP')], 11),
#  (('태평양 사령부', 'NNP'), [('태평양', 'NNP'), ('사령부', 'NNG')], 11),
#  (('실험 중단', 'NNP'), [('실험', 'NNG'), ('중단', 'NNG')], 11),
#  (('조선 구독', 'NNP'), [('조선', 'NNP'), ('구독', 'NNG')], 11),
#  (('뉴스 홈페이지', 'NNP'), [('뉴스', 'NNG'), ('홈페이지', 'NNG')], 11),
#  (('중국 내륙', 'NNP'), [('중국', 'NNP'), ('내륙', 'NNG')], 11),
#  (('해외 이주 신고', 'NNP'), [('해외', 'NNG'), ('이주', 'NNG'), ('신고', 'NNG')], 11),
#  (('건강 보험', 'NNP'), [('건강', 'NNG'), ('보험', 'NNG')], 11),
#  (('일 김정', 'NNP'), [('일', 'NNBC'), ('김정', 'NNP')], 11),
#  (('경우 북한', 'NNP'), [('경우', 'NNG'), ('북한', 'NNP')], 11),
#  (('1절 기념사', 'NNP'), [('1절', 'NNP'), ('기념사', 'NNG')], 11),
#  (('월 27', 'NNP'), [('월', 'NNBC'), ('27', 'SN')], 11),
#  (('War Games', 'NNP'), [('War', 'SL'), ('Games', 'SL')], 11),
#  (('지난해 4', 'NNP'), [('지난해', 'NNG'), ('4', 'SN')], 11),
#  (('북핵 수석대표', 'NNP'), [('북핵', 'NNP'), ('수석대표', 'NNG')], 11),
#  (('이번주 미국', 'NNP'), [('이번주', 'NNP'), ('미국', 'NNP')], 11),
#  (('종료 직후', 'NNP'), [('종료', 'NNG'), ('직후', 'NNG')], 11),
#  (('필리핀 방문', 'NNP'), [('필리핀', 'NNP'), ('방문', 'NNG')], 11),
#  (('일 주요국', 'NNP'), [('일', 'NNBC'), ('주요국', 'NNP')], 11),
#  (('국토 교통', 'NNP'), [('국토', 'NNG'), ('교통', 'NNG')], 11),
#  (('의원 입각', 'NNP'), [('의원', 'NNP'), ('입각', 'NNG')], 11),
#  (('디지털 뉴스', 'NNP'), [('디지털', 'NNG'), ('뉴스', 'NNG')], 11),
#  (('핵 무력', 'NNP'), [('핵', 'NNG'), ('무력', 'NNG')], 11),
#  (('한미연합 방위', 'NNP'), [('한미연합', 'NNP'), ('방위', 'NNG')], 11),
#  (('메릴랜드주 옥', 'NNP'), [('메릴랜드주', 'NNP'), ('옥', 'NNG')], 11),
#  (('반격 연습', 'NNP'), [('반격', 'NNG'), ('연습', 'NNG')], 11),
#  (('일 북미정상회담', 'NNP'), [('일', 'NNBC'), ('북미정상회담', 'NNP')], 11),
#  (('플러스 알파', 'NNP'), [('플러스', 'NNG'), ('알파', 'NNG')], 11),
#  (('작별 인사', 'NNP'), [('작별', 'NNG'), ('인사', 'NNP')], 11),
#  (('유엔 제재', 'NNP'), [('유엔', 'NNP'), ('제재', 'NNG')], 11),
#  (('인민 생활', 'NNP'), [('인민', 'NNG'), ('생활', 'NNG')], 11),
#  (('청와대 제공', 'NNP'), [('청와대', 'NNP'), ('제공', 'NNG')], 11),
#  (('이번 방문', 'NNP'), [('이번', 'NNG'), ('방문', 'NNG')], 11),
#  (('강화 발전', 'NNP'), [('강화', 'NNG'), ('발전', 'NNG')], 11),
#  (('다음 달', 'NNP'), [('다음', 'NNG'), ('달', 'NNG')], 11),
#  (('년 대선', 'NNP'), [('년', 'NNBC'), ('대선', 'NNG')], 11),
#  (('2 위', 'NNP'), [('2', 'SN'), ('위', 'NNBC')], 11),
#  (('11 월', 'NNP'), [('11', 'SN'), ('월', 'NNBC')], 11),
#  (('오전 베트남', 'NNP'), [('오전', 'NNG'), ('베트남', 'NNP')], 11),
#  (('베트남 친선', 'NNP'), [('베트남', 'NNP'), ('친선', 'NNG')], 11),
#  (('비핵화 합의', 'NNP'), [('비핵화', 'NNG'), ('합의', 'NNG')], 11),
#  (('3 분', 'NNP'), [('3', 'SN'), ('분', 'NNBC')], 11),
#  (('이하 한국시간', 'NNP'), [('이하', 'NNP'), ('한국시간', 'NNP')], 11),
#  (('정 장관', 'NNP'), [('정', 'NNP'), ('장관', 'NNP')], 11),
#  (('처음 명명', 'NNP'), [('처음', 'NNG'), ('명명', 'NNG')], 11),
#  (('영변 이외', 'NNP'), [('영변', 'NNG'), ('이외', 'NNG')], 11),
#  (('추가 핵시설', 'NNP'), [('추가', 'NNG'), ('핵시설', 'NNP')], 11),
#  (('미 국방부장관', 'NNP'), [('미', 'NNG'), ('국방부장관', 'NNP')], 11),
#  (('비서실장 대행', 'NNP'), [('비서실장', 'NNP'), ('대행', 'NNG')], 11),
#  (('노동당 부위원장', 'NNP'), [('노동당', 'NNG'), ('부위원장', 'NNG')], 11),
#  (('확대 정상', 'NNP'), [('확대', 'NNG'), ('정상', 'NNG')], 11),
#  (('육성 지원', 'NNP'), [('육성', 'NNG'), ('지원', 'NNG')], 11),
#  (('유엔군 사령', 'NNP'), [('유엔군', 'NNG'), ('사령', 'NNG')], 11),
#  (('김인현 고려대 법학', 'NNP'), [('김인현', 'NNP'), ('고려대', 'NNP'), ('법학', 'NNG')], 11),
#  (('전문대학원 교수', 'NNP'), [('전문대학원', 'NNP'), ('교수', 'NNG')], 11),
#  (('공단 이사장', 'NNP'), [('공단', 'NNG'), ('이사장', 'NNG')], 11),
#  (('광주 지회', 'NNP'), [('광주', 'NNP'), ('지회', 'NNG')], 11),
#  (('신경민 의원', 'NNP'), [('신경민', 'NNP'), ('의원', 'NNP')], 11),
#  (('교육 종사자', 'NNP'), [('교육', 'NNG'), ('종사자', 'NNG')], 11),
#  (('교육 정책', 'NNP'), [('교육', 'NNG'), ('정책', 'NNG')], 11),
#  (('당내 인사', 'NNP'), [('당내', 'NNG'), ('인사', 'NNP')], 11),
#  (('한겨레 정기 구독', 'NNP'), [('한겨레', 'NNG'), ('정기', 'NNG'), ('구독', 'NNG')], 11),
#  (('한겨레 신문', 'NNP'), [('한겨레', 'NNG'), ('신문', 'NNG')], 11),
#  (('시 의원', 'NNP'), [('시', 'NNG'), ('의원', 'NNP')], 11),
#  (('국회 소집', 'NNP'), [('국회', 'NNG'), ('소집', 'NNG')], 11),
#  (('3당 원내대표', 'NNP'), [('3당', 'NNP'), ('원내대표', 'NNP')], 11),
#  (('안건 지정', 'NNP'), [('안건', 'NNG'), ('지정', 'NNG')], 11),
#  (('무소속 손혜원', 'NNP'), [('무소속', 'NNP'), ('손혜원', 'NNP')], 11),
#  (('청와대 국가', 'NNP'), [('청와대', 'NNP'), ('국가', 'NNP')], 11),
#  (('주년 기념식', 'NNP'), [('주년', 'NNBC'), ('기념식', 'NNG')], 11),
#  (('대사 교체', 'NNP'), [('대사', 'NNG'), ('교체', 'NNG')], 11),
#  (('복수 후보', 'NNP'), [('복수', 'NNG'), ('후보', 'NNG')], 11),
#  (('내년 4', 'NNP'), [('내년', 'NNG'), ('4', 'SN')], 11),
#  (('택시 기사', 'NNP'), [('택시', 'NNG'), ('기사', 'NNG')], 11),
#  (('김영춘 장관', 'NNP'), [('김영춘', 'NNP'), ('장관', 'NNP')], 11),
#  (('의원 국정조사', 'NNP'), [('의원', 'NNP'), ('국정조사', 'NNP')], 11),
#  (('사립유치원 단체', 'NNP'), [('사립유치원', 'NNP'), ('단체', 'NNG')], 11),
#  (('학교 급식 법', 'NNP'), [('학교', 'NNG'), ('급식', 'NNG'), ('법', 'NNG')], 11),
#  (('법 개정안', 'NNP'), [('법', 'NNG'), ('개정안', 'NNG')], 11),
#  (('홍준표 자유', 'NNP'), [('홍준표', 'NNP'), ('자유', 'NNG')], 11),
#  (('대통 합', 'NNP'), [('대통', 'NNG'), ('합', 'NNG')], 11),
#  (('국회 인근', 'NNP'), [('국회', 'NNG'), ('인근', 'NNG')], 11),
#  (('대치 정국', 'NNP'), [('대치', 'NNG'), ('정국', 'NNG')], 11),
#  (('박용진 위원', 'NNP'), [('박용진', 'NNP'), ('위원', 'NNP')], 11),
#  (('민주당 유치원', 'NNP'), [('민주당', 'NNP'), ('유치원', 'NNG')], 11),
#  (('선언 철회', 'NNP'), [('선언', 'NNG'), ('철회', 'NNG')], 11),
#  (('디지털 타임스', 'NNP'), [('디지털', 'NNP'), ('타임스', 'NNP')], 11),
#  (('일본군 성 노예', 'NNP'), [('일본군', 'NNP'), ('성', 'NNG'), ('노예', 'NNG')], 11),
#  (('김성진 기자', 'NNP'), [('김성진', 'NNP'), ('기자', 'NNP')], 10),
#  (('ksj 87', 'NNP'), [('ksj', 'SL'), ('87', 'SN')], 10),
#  (('1 명', 'NNP'), [('1', 'SN'), ('명', 'NNBC')], 10),
#  (('베트남 정부', 'NNP'), [('베트남', 'NNP'), ('정부', 'NNG')], 10),
#  (('연대 급', 'NNP'), [('연대', 'NNP'), ('급', 'NNG')], 10),
#  (('약화 우려', 'NNP'), [('약화', 'NNG'), ('우려', 'NNG')], 10),
#  (('미군 헬기', 'NNP'), [('미군', 'NNG'), ('헬기', 'NNG')], 10),
#  (('하노이 정상', 'NNP'), [('하노이', 'NNP'), ('정상', 'NNG')], 10),
#  (('긴장 완화', 'NNP'), [('긴장', 'NNG'), ('완화', 'NNG')], 10),
#  (('월 싱가포르', 'NNP'), [('월', 'NNBC'), ('싱가포르', 'NNP')], 10),
#  (('Team Spirit', 'NNP'), [('Team', 'SL'), ('Spirit', 'SL')], 10),
#  (('부 반격', 'NNP'), [('부', 'NNBC'), ('반격', 'NNG')], 10),
#  (('위기관리 연습', 'NNP'), [('위기관리', 'NNG'), ('연습', 'NNG')], 10),
#  (('방위비분담금 협상', 'NNP'), [('방위비분담금', 'NNP'), ('협상', 'NNG')], 10),
#  (('중국 국가주석', 'NNP'), [('중국', 'NNP'), ('국가주석', 'NNP')], 10),
#  (('외교 경로', 'NNP'), [('외교', 'NNG'), ('경로', 'NNG')], 10),
#  (('이날 춘추관', 'NNP'), [('이날', 'NNG'), ('춘추관', 'NNG')], 10),
#  (('7 곳', 'NNP'), [('7', 'SN'), ('곳', 'NNG')], 10),
#  (('전 실장', 'NNP'), [('전', 'NNG'), ('실장', 'NNG')], 10),
#  (('뉴스 국', 'NNP'), [('뉴스', 'NNG'), ('국', 'NNG')], 10),
#  (('하노이 2', 'NNP'), [('하노이', 'NNP'), ('2', 'SN')], 10),
#  (('북미대화 재개', 'NNP'), [('북미대화', 'NNP'), ('재개', 'NNG')], 10),
#  (('워싱턴 DC', 'NNP'), [('워싱턴', 'NNP'), ('DC', 'SL')], 10),
#  (('합의 도출', 'NNP'), [('합의', 'NNG'), ('도출', 'NNG')], 10),
#  (('유지 측면', 'NNP'), [('유지', 'NNG'), ('측면', 'NNG')], 10),
#  (('중재 행보', 'NNP'), [('중재', 'NNG'), ('행보', 'NNG')], 10),
#  (('미 정상', 'NNP'), [('미', 'NNG'), ('정상', 'NNG')], 10),
#  (('강수윤 기자', 'NNP'), [('강수윤', 'NNP'), ('기자', 'NNP')], 10),
#  (('기존 봄', 'NNP'), [('기존', 'NNG'), ('봄', 'NNG')], 10),
#  (('일 폼페이', 'NNP'), [('일', 'NNBC'), ('폼페이', 'NNG')], 10),
#  (('대북제재 완화', 'NNP'), [('대북제재', 'NNP'), ('완화', 'NNG')], 10),
#  (('일부 해제', 'NNP'), [('일부', 'NNG'), ('해제', 'NNG')], 10),
#  (('제재 결의', 'NNP'), [('제재', 'NNG'), ('결의', 'NNG')], 10),
#  (('지난달 22', 'NNP'), [('지난달', 'NNG'), ('22', 'SN')], 10),
#  (('열차 출발', 'NNP'), [('열차', 'NNG'), ('출발', 'NNG')], 10),
#  (('현지 주민', 'NNP'), [('현지', 'NNG'), ('주민', 'NNP')], 10),
#  (('5 년', 'NNP'), [('5', 'SN'), ('년', 'NNBC')], 10),
#  (('소피 텔', 'NNP'), [('소피', 'NNP'), ('텔', 'NNP')], 10),
#  (('정상 국가', 'NNP'), [('정상', 'NNG'), ('국가', 'NNP')], 10),
#  (('오후 3', 'NNP'), [('오후', 'NNG'), ('3', 'SN')], 10),
#  (('협상 동력', 'NNP'), [('협상', 'NNG'), ('동력', 'NNG')], 10),
#  (('일 밤', 'NNP'), [('일', 'NNBC'), ('밤', 'NNG')], 10),
#  (('55 년', 'NNP'), [('55', 'SN'), ('년', 'NNBC')], 10),
#  (('북미정상회담 기념', 'NNP'), [('북미정상회담', 'NNP'), ('기념', 'NNG')], 10),
#  (('3 saba', 'NNP'), [('3', 'SN'), ('saba', 'SL')], 10),
#  (('시행령 개정안', 'NNP'), [('시행령', 'NNG'), ('개정안', 'NNG')], 10),
#  (('역내 평화', 'NNP'), [('역내', 'NNG'), ('평화', 'NNG')], 10),
#  (('조태형 기자', 'NNP'), [('조태형', 'NNP'), ('기자', 'NNP')], 10),
#  (('뉴스1 phototom', 'NNP'), [('뉴스1', 'NNP'), ('phototom', 'SL')], 10),
#  (('2012 년', 'NNP'), [('2012', 'SN'), ('년', 'NNBC')], 10),
#  (('북한 조선중앙', 'NNP'), [('북한', 'NNP'), ('조선중앙', 'NNP')], 10),
#  (('핵 문제', 'NNP'), [('핵', 'NNG'), ('문제', 'NNG')], 10),
#  (('서재준 기자', 'NNP'), [('서재준', 'NNP'), ('기자', 'NNP')], 10),
#  (('seojiba 3', 'NNP'), [('seojiba', 'SL'), ('3', 'SN')], 10),
#  (('1 함대', 'NNP'), [('1', 'SN'), ('함대', 'NNG')], 10),
#  (('백악관 비서실장', 'NNP'), [('백악관', 'NNG'), ('비서실장', 'NNP')], 10),
#  (('최대 정치 행사', 'NNP'), [('최대', 'NNG'), ('정치', 'NNG'), ('행사', 'NNG')], 10),
#  (('법 위반', 'NNP'), [('법', 'NNG'), ('위반', 'NNG')], 10),
#  (('시진핑 주석', 'NNP'), [('시진핑', 'NNP'), ('주석', 'NNG')], 10),
#  (('미중 무역전쟁', 'NNP'), [('미중', 'NNP'), ('무역전쟁', 'NNP')], 10),
#  (('보건복지부 장관', 'NNP'), [('보건복지부', 'NNP'), ('장관', 'NNP')], 10),
#  (('박영선 민주당', 'NNP'), [('박영선', 'NNP'), ('민주당', 'NNP')], 10),
#  (('국토 부', 'NNP'), [('국토', 'NNG'), ('부', 'NNP')], 10),
#  (('이연승 선박 안전 기술 공단', 'NNP'),
#   [('이연승', 'NNP'), ('선박', 'NNG'), ('안전', 'NNG'), ('기술', 'NNG'), ('공단', 'NNG')],
#   10),
#  (('일 이틀', 'NNP'), [('일', 'NNBC'), ('이틀', 'NNG')], 10),
#  (('국영 뉴스 통신 아 젠시', 'NNP'),
#   [('국영', 'NNG'), ('뉴스', 'NNG'), ('통신', 'NNG'), ('아', 'NNP'), ('젠시', 'NNP')],
#   10),
#  (('이날 오전', 'NNP'), [('이날', 'NNG'), ('오전', 'NNG')], 10),
#  (('관리회계 시스템', 'NNP'), [('관리회계', 'NNP'), ('시스템', 'NNG')], 10),
#  (('정부 여당', 'NNP'), [('정부', 'NNG'), ('여당', 'NNG')], 10),
#  (('정부 지원금', 'NNP'), [('정부', 'NNG'), ('지원금', 'NNG')], 10),
#  (('일부 세력', 'NNP'), [('일부', 'NNG'), ('세력', 'NNG')], 10),
#  (('1 기', 'NNP'), [('1', 'SN'), ('기', 'NNBC')], 10),
#  (('예상 출마', 'NNP'), [('예상', 'NNG'), ('출마', 'NNG')], 10),
#  (('조선일보 구독', 'NNP'), [('조선일보', 'NNP'), ('구독', 'NNG')], 10),
#  (('서울 시내', 'NNP'), [('서울', 'NNP'), ('시내', 'NNG')], 10),
#  (('kr 저작권자', 'NNP'), [('kr', 'SL'), ('저작권자', 'NNG')], 10),
#  (('글렌데일 시', 'NNP'), [('글렌데일', 'NNP'), ('시', 'NNG')], 10),
#  (('국당 나경원', 'NNP'), [('국당', 'NNP'), ('나경원', 'NNP')], 10),
#  (('국회 일정', 'NNP'), [('국회', 'NNG'), ('일정', 'NNG')], 10),
#  (('경제사회 노동 위원회', 'NNP'),
#   [('경제사회', 'NNP'), ('노동', 'NNG'), ('위원회', 'NNG')],
#   10),
#  (('법 개정', 'NNP'), [('법', 'NNG'), ('개정', 'NNG')], 10),
#  (('김관영 원내대표', 'NNP'), [('김관영', 'NNP'), ('원내대표', 'NNP')], 10),
#  (('야 3당', 'NNP'), [('야', 'NNG'), ('3당', 'NNP')], 10),
#  (('상임위 차원', 'NNP'), [('상임위', 'NNP'), ('차원', 'NNG')], 10),
#  (('교섭단체 원내수석부대표', 'NNP'), [('교섭단체', 'NNP'), ('원내수석부대표', 'NNP')], 10),
#  (('미 회담', 'NNP'), [('미', 'NNG'), ('회담', 'NNG')], 10),
#  (('임형섭 기자', 'NNP'), [('임형섭', 'NNP'), ('기자', 'NNP')], 10),
#  (('한반도평화 프로세스', 'NNP'), [('한반도평화', 'NNP'), ('프로세스', 'NNG')], 10),
#  (('일 국가안전', 'NNP'), [('일', 'NNBC'), ('국가안전', 'NNP')], 10),
#  (('국장 면세점', 'NNP'), [('국장', 'NNG'), ('면세점', 'NNG')], 10),
#  (('추 의원', 'NNP'), [('추', 'NNG'), ('의원', 'NNP')], 10),
#  (('여야 5', 'NNP'), [('여야', 'NNG'), ('5', 'SN')], 10),
#  (('갤럭시 S', 'NNP'), [('갤럭시', 'NNP'), ('S', 'SL')], 10),
#  (('1 호기', 'NNP'), [('1', 'SN'), ('호기', 'NNG')], 10),
#  (('도종환 문화체육관광부', 'NNP'), [('도종환', 'NNP'), ('문화체육관광부', 'NNP')], 10),
#  (('9 개', 'NNP'), [('9', 'SN'), ('개', 'NNBC')], 10),
#  (('김영춘 해양수산부', 'NNP'), [('김영춘', 'NNP'), ('해양수산부', 'NNP')], 10),
#  (('백지수 기자', 'NNP'), [('백지수', 'NNP'), ('기자', 'NNP')], 10),
#  (('연기 중단', 'NNP'), [('연기', 'NNG'), ('중단', 'NNG')], 10),
#  (('3법 처리', 'NNP'), [('3법', 'NNP'), ('처리', 'NNG')], 10),
#  (('임재훈 의원', 'NNP'), [('임재훈', 'NNP'), ('의원', 'NNP')], 10),
#  (('여의도 연구', 'NNP'), [('여의도', 'NNP'), ('연구', 'NNG')], 10),
#  (('17 대', 'NNP'), [('17', 'SN'), ('대', 'NNBC')], 10),
#  (('당 대변인', 'NNP'), [('당', 'NNG'), ('대변인', 'NNG')], 10),
#  (('민경욱 의원', 'NNP'), [('민경욱', 'NNP'), ('의원', 'NNP')], 10),
#  (('정계 은퇴', 'NNP'), [('정계', 'NNG'), ('은퇴', 'NNG')], 10),
#  (('국당 전', 'NNP'), [('국당', 'NNP'), ('전', 'NNG')], 10),
#  (('유시민 노무현재단 이사장', 'NNP'),
#   [('유시민', 'NNP'), ('노무현재단', 'NNP'), ('이사장', 'NNG')],
#   10),
#  (('황교안 체제', 'NNP'), [('황교안', 'NNP'), ('체제', 'NNG')], 10),
#  (('외국인 노동자', 'NNP'), [('외국인', 'NNG'), ('노동자', 'NNP')], 10),
#  (('활동 가이드라인', 'NNP'), [('활동', 'NNG'), ('가이드라인', 'NNG')], 10),
#  (('유 이사장', 'NNP'), [('유', 'NNG'), ('이사장', 'NNG')], 10),
#  (('취임 일', 'NNP'), [('취임', 'NNG'), ('일', 'NNG')], 10),
#  (('의원 회관', 'NNP'), [('의원', 'NNP'), ('회관', 'NNG')], 10),
#  (('이종명 의원', 'NNP'), [('이종명', 'NNP'), ('의원', 'NNP')], 10),
#  (('정과 이해', 'NNP'), [('정과', 'NNG'), ('이해', 'NNG')], 10),
#  (('사립유치원 문제', 'NNP'), [('사립유치원', 'NNP'), ('문제', 'NNG')], 10),
#  (('이날 국회', 'NNP'), [('이날', 'NNG'), ('국회', 'NNG')], 10),
#  (('국회 통과', 'NNP'), [('국회', 'NNG'), ('통과', 'NNG')], 10),
#  (('의혹 해소 요구', 'NNP'), [('의혹', 'NNG'), ('해소', 'NNG'), ('요구', 'NNG')], 10),
#  (('임시국회 소집', 'NNP'), [('임시국회', 'NNP'), ('소집', 'NNG')], 10),
#  (('애 국당', 'NNP'), [('애', 'NNG'), ('국당', 'NNP')], 10),
#  (('아로나 민', 'NNP'), [('아로나', 'NNP'), ('민', 'NNP')], 10),
#  (('댓글 정책', 'NNP'), [('댓글', 'NNG'), ('정책', 'NNG')], 10),
#  (('전 총재', 'NNP'), [('전', 'NNG'), ('총재', 'NNG')], 10),
#  (('북한 요리사', 'NNP'), [('북한', 'NNP'), ('요리사', 'NNG')], 9),
#  (('쌍용 훈련', 'NNP'), [('쌍용', 'NNP'), ('훈련', 'NNG')], 9),
#  (('능력 향상', 'NNP'), [('능력', 'NNG'), ('향상', 'NNG')], 9),
#  (('핵 잠수함', 'NNP'), [('핵', 'NNG'), ('잠수함', 'NNG')], 9),
#  (('22 스텔스', 'NNP'), [('22', 'SN'), ('스텔스', 'NNG')], 9),
#  (('미 훈련', 'NNP'), [('미', 'NNG'), ('훈련', 'NNG')], 9),
#  (('연합훈련 중단', 'NNP'), [('연합훈련', 'NNP'), ('중단', 'NNG')], 9),
#  (('지역 방어', 'NNP'), [('지역', 'NNG'), ('방어', 'NNG')], 9),
#  (('멘 텀', 'NNP'), [('멘', 'NNG'), ('텀', 'NNG')], 9),
#  (('한반도 전개', 'NNP'), [('한반도', 'NNP'), ('전개', 'NNG')], 9),
#  (('한미 훈련', 'NNP'), [('한미', 'NNG'), ('훈련', 'NNG')], 9),
#  (('신한반도 체제', 'NNP'), [('신한반도', 'NNP'), ('체제', 'NNG')], 9),
#  (('국방장관 대행', 'NNP'), [('국방장관', 'NNP'), ('대행', 'NNG')], 9),
#  (('1 주일', 'NNP'), [('1', 'SN'), ('주일', 'NNBC')], 9),
#  (('연중 시행', 'NNP'), [('연중', 'NNG'), ('시행', 'NNG')], 9),
#  (('트럼프 미', 'NNP'), [('트럼프', 'NNP'), ('미', 'NNG')], 9),
#  (('폭발 사고', 'NNP'), [('폭발', 'NNG'), ('사고', 'NNG')], 9),
#  (('년 북한', 'NNP'), [('년', 'NNBC'), ('북한', 'NNP')], 9),
#  (('야외 실기', 'NNP'), [('야외', 'NNG'), ('실기', 'NNG')], 9),
#  (('유엔군 사령부', 'NNP'), [('유엔군', 'NNG'), ('사령부', 'NNG')], 9),
#  (('일 전화통화', 'NNP'), [('일', 'NNBC'), ('전화통화', 'NNP')], 9),
#  (('조선중앙 TV', 'NNP'), [('조선중앙', 'NNP'), ('TV', 'SL')], 9),
#  (('대북특사 파견', 'NNP'), [('대북특사', 'NNP'), ('파견', 'NNG')], 9),
#  (('민주당 대표', 'NNP'), [('민주당', 'NNP'), ('대표', 'NNP')], 9),
#  (('북핵 폐기', 'NNP'), [('북핵', 'NNP'), ('폐기', 'NNG')], 9),
#  (('농축 시설', 'NNP'), [('농축', 'NNG'), ('시설', 'NNG')], 9),
#  (('예비 단계', 'NNP'), [('예비', 'NNG'), ('단계', 'NNG')], 9),
#  (('이후 처음', 'NNP'), [('이후', 'NNG'), ('처음', 'NNG')], 9),
#  (('신범철 아산 정책연구원 안보통일 센터', 'NNP'),
#   [('신범철', 'NNP'),
#    ('아산', 'NNP'),
#    ('정책연구원', 'NNP'),
#    ('안보통일', 'NNP'),
#    ('센터', 'NNG')],
#   9),
#  (('6 개월', 'NNP'), [('6', 'SN'), ('개월', 'NNBC')], 9),
#  (('일 트럼프', 'NNP'), [('일', 'NNBC'), ('트럼프', 'NNG')], 9),
#  (('중단 상태', 'NNP'), [('중단', 'NNG'), ('상태', 'NNG')], 9),
#  (('7 시간', 'NNP'), [('7', 'SN'), ('시간', 'NNBC')], 9),
#  (('년 키리졸브', 'NNP'), [('년', 'NNBC'), ('키리졸브', 'NNP')], 9),
#  (('나라 관계', 'NNP'), [('나라', 'NNG'), ('관계', 'NNG')], 9),
#  (('최재구 기자', 'NNP'), [('최재구', 'NNP'), ('기자', 'NNP')], 9),
#  (('jjaeck 9', 'NNP'), [('jjaeck', 'SL'), ('9', 'SN')], 9),
#  (('종로구 도렴동 외교부', 'NNP'), [('종로구', 'NNP'), ('도렴동', 'NNP'), ('외교부', 'NNP')], 9),
#  (('해양 수산', 'NNP'), [('해양', 'NNG'), ('수산', 'NNG')], 9),
#  ...]
